# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid purple; padding: 15px;">
# Привет, Сергей!
#
# Меня зовут Сергей Комаров, я буду проверять твой проект по теме "Исследовательский анализ данных", постараемся вместе сделать его ещё лучше. Предлагаю обращаться к друг другу на «ты», если для тебя это будет комфортно. Иначе дай знать, и мы сразу перейдём на «вы».
#
# Чтобы тебе было легче найти мои комментарии в тексте, они выделены <font color='green'>зеленым</font>, <font color='gold'>жёлтым</font> и <font color='red'>красным</font> цветами, в зависимости от ситуации:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Так обозначены комментарии к полностью корректным решениям.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Так будут обозначены рекомендации, следуя которым можно улучшить решение.
# </div>
#
#
# <br/>
#
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
# <hr>
# <b>Обрати внимание🤔:</b> Так будут обозначены важные замечания, требующие доработки проекта. Без их устранения проект не может быть принят.
# </div>
#
# <br/>
#
# Попрошу тебя придерживаться некоторых несложных правил, **всё это поможет нам работать над проектом оперативнее и с большей пользой для тебя**:
#
# Если ты вносишь какие-то правки в проект по результатам ревью, отвечаешь на мой комментарий или задаёшь вопрос, обозначай это в тексте любым способом, который тебе понравится, главное, чтобы твои комментарии визуально выделялись и при этом были хорошо отличимы от моих. Например, можешь делать это так:
#
# <br/>
#
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
# <hr>
#     Здесь мог<s>ла быть Ваша реклама</s> быть твой комментарий :)
# </div>
#
# <br/>
#
# Пожалуйста, не удаляй и не перемещай ячейки с моими комментариями, а также не меняй их содержание;
#
# <br/>
#
# Помни, что у нас общая цель — подготовить тебя к дальнейшей успешной работе :)
#
# <br/>
#
# <font color='purple' style='font-size:20px; font-weight:bold'>Резюме по работе</font>
# * Работа очень хорошая. Стоит выделить то, как ты чётко и аргумментировано строишь выводы, хорошо работаешь с описательными статистиками и распределениями, хорошо работаешь с pandas, используешь дополнительные инструменты, в т.ч. и из numpy.
# * Работа хорошо структурирована, поэтому в ней легко ориентироваться, спасибо!
# * Из недостатков стоит выделить аннотацию графиков, обрати своё внимание на этот момент, это важно. Также местами в работе не хватало твоих комментариев и промежуточных выводов.
# * Я жду исправление по одному из выводов исследования (зависимость цены по годам, а промежуточных комментариев там, где я прошу этого в красном комментарии. Это будет необходимо для того, чтобы зачесть твою работу. Исправления не займут у тебя много времени.
# * Если хочешь задать какие-то вопросы, можешь оставить их тут, с радостью отвечу тебе на них.
# * Буду ждать работу с исправлениями на повторное ревью.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Здравствуйте! Постарался устранить все замечания и воспользоваться вашими советами. Отправляю проект на повторную проверку.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Замечания устранены. Работа и так была выполнена на очень высоком уровне, здорово, что у тебя нашлось время и желание учесть и большую часть советов, теперь совсем-совсем здорово (по большей части за счёт промежуточных комментариев и дооформленных графиков).
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Исправление-названий-признаков" data-toc-modified-id="Исправление-названий-признаков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Исправление названий признаков</a></span></li><li><span><a href="#Заполнение-пропусков-и-обработка-выбросов-признака-&quot;ceiling_height&quot;" data-toc-modified-id="Заполнение-пропусков-и-обработка-выбросов-признака-&quot;ceiling_height&quot;-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Заполнение пропусков и обработка выбросов признака "ceiling_height"</a></span></li><li><span><a href="#Заполнение-пропусков-признака-&quot;floors_total&quot;" data-toc-modified-id="Заполнение-пропусков-признака-&quot;floors_total&quot;-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Заполнение пропусков признака "floors_total"</a></span></li><li><span><a href="#Заполнение-пропусков-и-обработка-выбросов-признака-&quot;living_area&quot;" data-toc-modified-id="Заполнение-пропусков-и-обработка-выбросов-признака-&quot;living_area&quot;-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Заполнение пропусков и обработка выбросов признака "living_area"</a></span></li><li><span><a href="#Заполнение-пропусков-признака-&quot;is_apartment&quot;" data-toc-modified-id="Заполнение-пропусков-признака-&quot;is_apartment&quot;-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Заполнение пропусков признака "is_apartment"</a></span></li><li><span><a href="#Заполнение-пропусков-признака-&quot;kitchen_area&quot;" data-toc-modified-id="Заполнение-пропусков-признака-&quot;kitchen_area&quot;-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Заполнение пропусков признака "kitchen_area"</a></span></li><li><span><a href="#Заполнение-пропусков-признака-&quot;balcony&quot;" data-toc-modified-id="Заполнение-пропусков-признака-&quot;balcony&quot;-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Заполнение пропусков признака "balcony"</a></span></li><li><span><a href="#Заполнение-пропусков-и-обработка-дубликатов-признака-&quot;locality_name&quot;" data-toc-modified-id="Заполнение-пропусков-и-обработка-дубликатов-признака-&quot;locality_name&quot;-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Заполнение пропусков и обработка дубликатов признака "locality_name"</a></span></li><li><span><a href="#Заполнение-пропусков-признаков-&quot;airports_nearest&quot;,-&quot;city_centers_nearest&quot;,-&quot;parks_around_3000&quot;,-&quot;parks_nearest&quot;,-&quot;ponds_around_3000&quot;,-&quot;ponds_nearest&quot;." data-toc-modified-id="Заполнение-пропусков-признаков-&quot;airports_nearest&quot;,-&quot;city_centers_nearest&quot;,-&quot;parks_around_3000&quot;,-&quot;parks_nearest&quot;,-&quot;ponds_around_3000&quot;,-&quot;ponds_nearest&quot;.-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Заполнение пропусков признаков "airports_nearest", "city_centers_nearest", "parks_around_3000", "parks_nearest", "ponds_around_3000", "ponds_nearest".</a></span></li><li><span><a href="#Заполнение-пропусков-и-обработка-выбросов-признака-&quot;days_exposition&quot;" data-toc-modified-id="Заполнение-пропусков-и-обработка-выбросов-признака-&quot;days_exposition&quot;-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Заполнение пропусков и обработка выбросов признака "days_exposition"</a></span></li><li><span><a href="#Обработка-выбросов-признака-&quot;last_price&quot;" data-toc-modified-id="Обработка-выбросов-признака-&quot;last_price&quot;-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Обработка выбросов признака "last_price"</a></span></li><li><span><a href="#Обработка-выбросов-признака-&quot;total_area&quot;" data-toc-modified-id="Обработка-выбросов-признака-&quot;total_area&quot;-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Обработка выбросов признака "total_area"</a></span></li><li><span><a href="#Преобразование-признака-&quot;first_day_exposition&quot;" data-toc-modified-id="Преобразование-признака-&quot;first_day_exposition&quot;-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Преобразование признака "first_day_exposition"</a></span></li><li><span><a href="#Прочие-преобразования-типов-данных" data-toc-modified-id="Прочие-преобразования-типов-данных-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Прочие преобразования типов данных</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Расчёт-цены-квадратного-метра" data-toc-modified-id="Расчёт-цены-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Расчёт цены квадратного метра</a></span></li><li><span><a href="#Расчёт-дня-недели-публикации-объявления" data-toc-modified-id="Расчёт-дня-недели-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Расчёт дня недели публикации объявления</a></span></li><li><span><a href="#Расчёт-месяца-публикации-объявления" data-toc-modified-id="Расчёт-месяца-публикации-объявления-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Расчёт месяца публикации объявления</a></span></li><li><span><a href="#Расчёт-года-публикации-объявления" data-toc-modified-id="Расчёт-года-публикации-объявления-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Расчёт года публикации объявления</a></span></li><li><span><a href="#Добавление-типа-этажа" data-toc-modified-id="Добавление-типа-этажа-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Добавление типа этажа</a></span></li><li><span><a href="#Расчёт-соотношения-жилой-и-общей-площади" data-toc-modified-id="Расчёт-соотношения-жилой-и-общей-площади-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Расчёт соотношения жилой и общей площади</a></span></li><li><span><a href="#Расчёт-соотношения-площади-кухни-к-общей-площади" data-toc-modified-id="Расчёт-соотношения-площади-кухни-к-общей-площади-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Расчёт соотношения площади кухни к общей площади</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметров-недвижимости" data-toc-modified-id="Изучение-параметров-недвижимости-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучение параметров недвижимости</a></span><ul class="toc-item"><li><span><a href="#Площадь" data-toc-modified-id="Площадь-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Площадь</a></span></li><li><span><a href="#Цена" data-toc-modified-id="Цена-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Цена</a></span></li><li><span><a href="#Число-комнат" data-toc-modified-id="Число-комнат-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Число комнат</a></span></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Высота потолков</a></span></li></ul></li><li><span><a href="#Время-продажи-квартиры" data-toc-modified-id="Время-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Время продажи квартиры</a></span></li><li><span><a href="#Исключение-редких-и-выбивающихся-значений" data-toc-modified-id="Исключение-редких-и-выбивающихся-значений-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Исключение редких и выбивающихся значений</a></span></li><li><span><a href="#Изучения-факторов,-влияющих-на-цену" data-toc-modified-id="Изучения-факторов,-влияющих-на-цену-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Изучения факторов, влияющих на цену</a></span><ul class="toc-item"><li><span><a href="#Площаль" data-toc-modified-id="Площаль-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Площаль</a></span></li><li><span><a href="#Число-комнат" data-toc-modified-id="Число-комнат-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Число комнат</a></span></li><li><span><a href="#Удалённость-от-центра" data-toc-modified-id="Удалённость-от-центра-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Удалённость от центра</a></span></li><li><span><a href="#Этаж" data-toc-modified-id="Этаж-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Этаж</a></span></li><li><span><a href="#Дата-размещения" data-toc-modified-id="Дата-размещения-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>Дата размещения</a></span><ul class="toc-item"><li><span><a href="#День-недели" data-toc-modified-id="День-недели-4.4.5.1"><span class="toc-item-num">4.4.5.1&nbsp;&nbsp;</span>День недели</a></span></li><li><span><a href="#Месяц" data-toc-modified-id="Месяц-4.4.5.2"><span class="toc-item-num">4.4.5.2&nbsp;&nbsp;</span>Месяц</a></span></li><li><span><a href="#Год" data-toc-modified-id="Год-4.4.5.3"><span class="toc-item-num">4.4.5.3&nbsp;&nbsp;</span>Год</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.4.6"><span class="toc-item-num">4.4.6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#10-населённых-пунктов-с-наибольшим-числом-объявлений" data-toc-modified-id="10-населённых-пунктов-с-наибольшим-числом-объявлений-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>10 населённых пунктов с наибольшим числом объявлений</a></span></li><li><span><a href="#Квартиры-в-Санкт-Петербурге" data-toc-modified-id="Квартиры-в-Санкт-Петербурге-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Квартиры в Санкт-Петербурге</a></span></li><li><span><a href="#Квартиры-в-центре-Санкт-Петербурга" data-toc-modified-id="Квартиры-в-центре-Санкт-Петербурга-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Квартиры в центре Санкт-Петербурга</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Здорово, что в проекте присутствует интерактивное содержание, это довольно удобно и информативно — сразу видно, какого плана ты придерживаешься на пути к решению поставленной задачи.
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
from matplotlib import rcParams

import seaborn as sns

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Правильное решение — собрать все импорты библиотек в начале проекта, так любой другой специалист сразу поймёт, какие инструменты ты будешь использовать в своей работе, и сможет заранее установить отсутствующие библиотеки. Молодец, что сокращаешь названия библиотек, используя общепринятые сокращения, а также, что для <code>matplotlib</code> подключаешь только нужные тебе модули.
# </div>

# %%
df_data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# **Описание данных**
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Данные прочитаны, здорово, что перед началом работы с признаками следует такая лаконичная расшифровка. Это удобно как для тебя, так и для специалиста, не находящегося в контексте задачи, когда он решит посмотреть твой проект. Например, если ты разместишь его у себя в портфолио.
# </div>

# %%
df_data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# **Названия признаков**

# %%
# df_data.columns

list(df_data.columns)
# Out:
# ['total_images',
#  'last_price',
#  'total_area',
#  'first_day_exposition',
#  'rooms',
#  'ceiling_height',
#  'floors_total',
#  'living_area',
#  'floor',
#  'is_apartment',
#  'studio',
#  'open_plan',
#  'kitchen_area',
#  'balcony',
#  'locality_name',
#  'airports_nearest',
#  'cityCenters_nearest',
#  'parks_around3000',
#  'parks_nearest',
#  'ponds_around3000',
#  'ponds_nearest',
#  'days_exposition']

# %% [markdown]
# Количество и названия признаков соответствуют сопроводительной информации.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Согласись, вывод в таком виде, как он представлен сейчас, выглядит не очень презентабельно. Если ты хочешь вывести значения из, скажем, списка, то удобно использовать для этого метод <a href = 'https://pythonru.com/osnovy/python-join'><code>join</code></a>, при этом в качестве строки, к которой метод будет применён, я бы советовал использовать <code>'; \n'</code>.
# <br/>Но, в таком случае, результат вывода станет ну очень похож на вывод следущей ячейки — информация дублируется, поэтому нет смысла выводить названия признаков отдельно.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Здесь мне хотелось отдельно рассмотреть не только правильность записи признаков, но и их соответствие упомянутому ранее описанию, так как я провожу проверку не только для читателя, но и для себя. Исправил вывод, добавив список, получилось более удобно для восприятия. Однако данная информация дублируется, метод <code>.describe()</code> также позволяет оценить названия, поэтому не вижу смысла более делать подобный вывод на экран. Спасибо за совет!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Да, я так и понял. Решение, которое я предлагал, вывело бы названия без кавычек и лишних символов в столбик — так сверяться удобнее, как мне кажется, да и вывод выглядит опрятнее без лишних символов.
# </div>

# %% [markdown]
# **Сводная информация о данных**

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# **Пропуски**

# %%
# df_data.isna().sum()

pd.concat([
    pd.DataFrame(data=df_data.isna().sum(), columns=['Количество пропусков']),
    pd.DataFrame(data=df_data.isna().mean().apply('{:.2%}'.format), columns=['Доля пропусков'])
], axis=1)
# Out:
#                       Количество пропусков Доля пропусков
# total_images                             0          0.00%
# last_price                               0          0.00%
# total_area                               0          0.00%
# first_day_exposition                     0          0.00%
# rooms                                    0          0.00%
# ceiling_height                        9195         38.80%
# floors_total                            86          0.36%
# living_area                           1903          8.03%
# floor                                    0          0.00%
# is_apartment                         20924         88.29%
# studio                                   0          0.00%
# open_plan                                0          0.00%
# kitchen_area                          2278          9.61%
# balcony                              11519         48.61%
# locality_name                           49          0.21%
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Здесь снова дублируется информация. Но соглашусь, что оценивать число пропусков напрямую удобнее, чем высчитывать его с помощью числа действительных значений в столбце. А ещё лучше оценивать сразу <b>долю пропусков</b>, поскольку 1000 пропущенных значений в наборе данных с 10 000 строк и 2 000 строк — в общем случае две совершенно разные ситуации.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Для лучшего понимания сделал здесь вывод и абсолютных чисел, и долей.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Всё отлично, симпатичная таблица. Можно, кстати, ещё отсортировать по убыванию доли пропусков (или их количества, эффект будет один), так получится немного нагляднее.
# </div>

# %% [markdown]
# **Основные статистики**

# %%
# df_data.describe()

df_data.describe(include='all').transpose()
# Out:
#                       count unique                  top   freq         mean  \
# total_images          23699    NaN                  NaN    NaN      9.85848
# last_price            23699    NaN                  NaN    NaN  6.54155e+06
# total_area            23699    NaN                  NaN    NaN      60.3487
# first_day_exposition  23699   1491  2018-02-01T00:00:00    368          NaN
# rooms                 23699    NaN                  NaN    NaN      2.07064
# ceiling_height        14504    NaN                  NaN    NaN       2.7715
# floors_total          23613    NaN                  NaN    NaN      10.6738
# living_area           21796    NaN                  NaN    NaN      34.4579
# floor                 23699    NaN                  NaN    NaN      5.89236
# is_apartment           2775      2                False   2725          NaN
# studio                23699      2                False  23550          NaN
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
#         <b>Совет💡:</b> Молодец, что пользуешься методом <code>describe</code>, верно отмечая, что он выведет основные статистики. В нашей задаче в данных много столбцов, а строк у получившегося при выводе DataFrame сравнительно немного, поэтому таблицу здесь удобно транспонировать или повернуть на прямой угол, т.е. поменять столбцы со строками местами. Для этого можно использовать метод DataFrame'a <a href='https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.transpose.html'><code>transpose</code></a> или атрибут DataFrame'а <code>T</code>.
#         <br/>Советую тебе также обратить внимание на аргумент метода <code>describe</code> <code>include</code>, передав для него при вызове метода значение <code>'all'</code>, ты получишь ещё и полезную информацию для категориальных признаков.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Обалденно, спасибо за совет!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Рад, что ты оценил 🙂
# </div>

# %% [markdown]
# **Распределение значений "last_price"**
#
# Рассмотрим плотность распределения квартир в зависимости от их стоимости.

# %%
plt.title('Плотность распределения квартир в зависимости от стоимости', fontsize=16)
plt.xlabel('Стоимость квартир', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

df_data['last_price'].hist(bins=200, figsize=(15, 5));

# %% [markdown]
# Из-за наличия очень больших значения гистограмма приняла нерепрезентативный вид.
#
# Для лучшего визуального понимания сперва отдельно рассмотрим большинство квартир в начале графика - стоимостью до 50.000.000.

# %%
plt.title('Плотность распределения квартир в зависимости от стоимости, стоимостью до 50.000.000', fontsize=16)
plt.xlabel('Стоимость квартир', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

df_data['last_price'].hist(bins=200, range=(0, 5e+7), figsize=(15, 5));

# %% [markdown]
# Теперь все остальные.

# %%
plt.title('Плотность распределения квартир в зависимости от стоимости, стоимостью более 50.000.000', fontsize=16)
plt.xlabel('Стоимость квартир', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

df_data['last_price'].hist(bins=200, range=(5e+7, 8e+8), figsize=(15, 5));

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b>Правильно, что ты строишь гистограммы для анализа распределений. Молодец, что настраиваешь важные параметры - диапазон значений аргумента, размеры графика и число корзин. Также молодец, что используешь точку с запятой, чтобы не выводить лишнюю для нас информацию.
# <br/>Но тут есть упущение — важно подписывать сами графики, а также оси на них, чтобы любой, кто увидит твой график, всегда мог его корректно интерпритировать. Для гистограмм хотелось бы видеть на изображении подпись графика и аннотированную горизонтальную ось признака, для ящиков с усами — хотя бы подпись названия самого графика на изображении, если это одиночный boxplot, и аннотацию груп для групповых.
#         <a href='https://nsu-programming.github.io/textbook/python/plotting.html'>Хорошая статья</a> по работе с matplotlib в части оформления графиков.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Готово! Добавил подписи осей и описания графиков, а также сопутствующие комментарии.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Роскошные графики, ещё и размер шрифта очень удачно подобран 🙂
#     <details>
# 	<summary>Маленький бонус, надпись кликабельна.</summary>
# 	<a href='https://youtu.be/TydaCoJYfpU'>Весёлое видео</a> про оформление графиков от одного из лучших наставников Практикума, Глеба Михайлова. У него на YouTube-канале много интересного.
# </details>
# </div>

# %% [markdown]
# **Гистограмма плотности распределения и диаграмма размаха признака "total_area"**
#
# Рассмотрим плотность распределения квартир в зависимости от их общей площади.

# %%
df_data['total_area'].hist(bins=200, figsize=(15, 5))

plt.title('Плотность распределения квартир в зависимости от общей площади', fontsize=16)
plt.xlabel('Общая площадь квартир в квадратных метрах', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

plt.xticks(range(0, 950, 50));

# %% [markdown]
# Гистограмма и основные статистики подтверждают, что большинство квартир имеют общую площадь от 30 до 100 квадратных метров. Однако на на горизонтальной оси графика присутствиют значения до 900 метров без видимых столбцов гистограммы. Это говорит о присутствии малочисленных квартир с контрастными большими показателями общей площади.
#
# Для визуализации аномальных квартир построим диаграмму размаха.

# %%
df_data[['total_area']].boxplot(vert=False, figsize=(15, 5))

plt.title('Диаграмма размаха общей площади квартир', fontsize=16)
plt.xlabel('Общая площадь в квадратных метрах', fontsize=14)

plt.xticks(range(0, 1000, 50));

# %% [markdown]
# Диаграмма размаха подтверждает, что большинство квартир сгруппированы около значения ~50 метров. Также диаграмма демонстрирует наличие выбивающихся значений вне интерквартильного интервала: такие значения присутствуют от ~120 метров в большом количестве и постепенно убывают до 900 метров.
#
# Доподлинно неизвестно, являются ли эти значения ошибками или это действительно редкие образцы жилья с нестандартными параметрами. Данные значения следуюет рассматривать отдельно, чтобы избежать искажения основных тенденций в данных.

# %% [markdown]
# **Гистограмма плотности распределения и диаграмма размаха признака "living_area"**
#
# Рассмотрим плотность распределения жилой площади квартир.

# %%
df_data['living_area'].hist(bins=200, figsize=(15, 5))

plt.title('Плотность распределения квартир в зависимости от жилой площади', fontsize=16)
plt.xlabel('Жилая площадь квартир в квадратных метрах', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

plt.xticks(range(0, 450, 25));

# %% [markdown]
# Жилая площадь зависит от общей площади квартир, поэтому здесь наблюдается схожий характер распределения и наличие выбросов. Для оценки последних аналогичным образом прибегнем к диаграмме размаха.

# %%
df_data[['living_area']].boxplot(vert=False, figsize=(15, 5))

plt.title('Диаграмма размаха жилой площади квартир', fontsize=16)
plt.xlabel('Жилая площадь в квадратных метрах', fontsize=14)

plt.xticks(range(0, 450, 25));

# %% [markdown]
# Наблюдается аналогичное наличие подозрительных квартир, что логично, с общей площадью должна увеличиться и жилая.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b>Молодец, ящик с усами — мощный инструмент в руках аналитика.
# <br/>Здесь также замечания по подписям для осей. Хорошо, если подпись к графику будет выводиться на изображении вместе с графиком — картинки можно будет скачать и вставить в презентацию, не подписывая заново каждый график и не разыскивая долго нужный график в большой выгрузке изображений без подписей.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Сделано. Попробовал сохранить как картинку - действительно удобно.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Да, здорово получилось.
# </div>

# %% [markdown]
# **Список уникальных значений "is_apartment"**

# %%
list(df_data['is_apartment'].unique())
# Out:
# [nan, False, True]

# %% [markdown]
# **Список уникальных значений "locality_name"**

# %%
# df_data['locality_name'].unique()

# list(df_data['locality_name'].unique())

print(f'; \n'.join(df_data['locality_name'].unique().astype(str)))
# Out:
# Санкт-Петербург;
# посёлок Шушары;
# городской посёлок Янино-1;
# посёлок Парголово;
# посёлок Мурино;
# Ломоносов;
# Сертолово;
# Петергоф;
# Пушкин;
# деревня Кудрово;
# Коммунар;
# Колпино;
# поселок городского типа Красный Бор;
# Гатчина;
# поселок Мурино;
# деревня Фёдоровское;
# Выборг;
# Кронштадт;
# Кировск;
# деревня Новое Девяткино;
# посёлок Металлострой;
# посёлок городского типа Лебяжье;
# посёлок городского типа Сиверский;
# поселок Молодцово;
# поселок городского типа Кузьмоловский;
# садовое товарищество Новая Ропша;
# Павловск;
# деревня Пикколово;
# Всеволожск;
# Волхов;
# Кингисепп;
# Приозерск;
# Сестрорецк;
# деревня Куттузи;
# посёлок Аннино;
# поселок городского типа Ефимовский;
# посёлок Плодовое;
# деревня Заклинье;
# поселок Торковичи;
# поселок Первомайское;
# Красное Село;
# посёлок Понтонный;
# Сясьстрой;
# деревня Старая;
# деревня Лесколово;
# посёлок Новый Свет;
# Сланцы;
# село Путилово;
# Ивангород;
# Мурино;
# Шлиссельбург;
# Никольское;
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b>Важно оценить уникальные значения категориальных признаков, это верное решение.
# <br/>Здесь тоже можно сделать вывод более привлекательным, используя метод <code>join</code>, как это говорилось ранее. Далее не буду повторяться и обращать твоё внимание на такие места.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Сделал вывод при помощи списка - получилось удобно для восприятия, элементы выводились по одному с новой строки, это заслуга неявной функции <code>display()</code>. Затем решил переделать через метод <code>.join()</code> так как он будет работать более явно, гарантированно выводить элементы по одному с новой строки независимо от среды выполнения.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> А ещё не будет лишних кавычек и скобок. Классный вариант ещё использовать <code>value_counts</code>.
# </div>

# %% [markdown]
# **Гистограмма плотности распределения и диаграмма размаха признака "days_exposition"**

# %%
df_data['days_exposition'].hist(bins=200, figsize=(15, 5))

plt.title('Длительность продажи квартир', fontsize=16)
plt.xlabel('Длительность продажи квартир в днях', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

plt.xticks(range(0, 1700, 100));

# %% [markdown]
# Большинство квартир продаются в первый год. Без учёта резких скачков, наибольшие объёмы продажи наблюдаются в первый месяц и постепенно снижаются с каждым следующим месяцем.
#
# Также на гистограмме присутствуют квартиры, которые продавались чрезвычайно долго, более полутора, двух и даже трёх лет. Прибегнем к диаграмме размаха для оценки этих выделяющихся квартир.

# %%
df_data[['days_exposition']].boxplot(vert=False, figsize=(15, 5))

plt.title('Диаграмма размаха длительности продажи квартир', fontsize=16)
plt.xlabel('Длительность продаж в днях', fontsize=14)

plt.xticks(range(0, 1700, 100));

# %% [markdown]
# Интерквартильный размах покрывает значения от ~50 до ~230 дней - интервал времени, за которое продаются половина среднестатистических квартир. Края статистически значимой выборки заканчиваются на значении чуть более ~500 дней, значения, расположенные далее, сильно отличаются от основной массы. Данные объекты также надлежит подвергнуть изоляции.

# %% [markdown]
# ### Выводы

# %% [markdown]
# Не все названия признаков написаны в стиле "snake_case":
# - cityCenters_nearest;
# - parks_around3000;
# - ponds_around3000.
#
# **Пропуски**
# - ceiling_height, продавцы могли не указать высоту потолков. Пропуски могут быть заполнены медианными значениями, так как скорее всего реальные значения не будут сильно отличаться от значений среднестатистической квартиры;
# - floors_total, продавцы могли не указать количество этажей в доме. Заполнение данного признака затруднительно ввиду невозможности прогноза для каждого объекта: средние и медианные значения не подойдут. В качестве заполнения может быть использован этаж квартиры, что однако также не является лучшим вариантом и может привести к ухудшению информативности. Во избежание последнего пропуски могут быть заполнены аномальными значениями, как индикаторы отсутствия информации;
# - living_area, важный показатель при продаже недвижимости. Маловероятно, что продавец не указал значение, возможно, значения были отброшены из-за технической ошибки или нарушения формата ввода данных. Пропуски могут быть заполнены на основании средних долей живой площади от общей площади;
# - is_apartment, скорее всего данные не были заполнены продавцом или получены от сервисов, где не предполагается наличие подобного поля. С высокой долей вероятности можно считать, что объекты с пропусками не являются апартаментами;
# - kitchen_area, важный признак, пропуски могли возникнуть из-за некорректного ввода. Аналогично жилой площади, пропуски могут быть вычислены как средняя доля от всей площади;
# - balcony, скорее всего пользователи не указывали информацию о количестве балконов при их отсутствии. Таким образом, отсутствие информации можно воспринимать как отсутствии балконов;
# - locality_name, важный признак, без которого продажа квартиры невозможна. Возможно, данные были потеряны из-за технической ошибки или некорректного заполнения форм. Прогнозирование пропущенных значений невозможно, поэтому лучше указать явное отсутствие информации "unknown" или пустой строкой "";
# - airports_nearest, данный признак не мог быть указан продавцами, скорее всего пропуски появились из-за технических ошибок. Возможно, пропуски следует заполнить медианными значениями с группировкой по населённым пунктам;
# - cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest - данные признаки также были получены автоматически на основе картографии. Их пропуски могут быть заполнены медианными значениями с группировкой по населённому пункту, так как недвижимость в одном месте будет иметь схожие показатели удалённости от аэропортов, парков, скверов и центра города;
# - days_exposition, данный признак вероятно получен автоматически от сервиса продажи. Пропуски могут быть заполнены автоматически с группировкой по метражу, стоимости, количеству комнат и т.д. Однако генерация для заполнения пропусков некорректна, так как невозможно подлинно спрогнозировать как долго продавалась конкретная недвижимость. Также стоит заметить, что отсутствие информации о снятии объявление может означать, что на момент сбора данных объявление не было снято и квартира продавалась.
#
# **Аномалии**
# - last_price, признак содержит большие значения, превышающие значение 20 миллионов вплоть до 760 миллионов. Данные значения могут быть как аномалиями (при заполнении цена была указана в копейках, что привело к увеличению в 100 раз), так и принадлежать очень дорогому жилью;
# - total_area, признак содержит значения более 400 метров, что также может свидетельствовать об ошибках;
# - ceiling_height, максимальные значения в районе 100 метров явно свидетельствуют об ошибках;
# - days_exposition, значения более 500 дней могут свидетельствовать об ошибках, однако дорогое жильё действительно может продаваться более года.
#
# **Преобразование данных**
# - first_day_exposition следует привести к типу datetime;
# - is_apartment следует привести к типу bool.
#
# **Дубликаты**
# - locality_name содержит неявные дубликаты: "пос**ё**лок Пансионат Зелёный Бор" и "пос**е**лок Пансионат Зелёный Бор", "пос**ё**лок Лисий Нос" и "пос**е**лок Лисий Нос" и т.д.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Хороший вывод, информация лаконично изложена, молодец, что строишь предположения о причинах возникновения результатов своих наблюдений, сразу предлагая возможные решения для устранения замеченных ошибок.
# <br/>Здорово, что вывод хорошо структурирован.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Кроме небольших замечаний и советов из данного раздела, а также важного замечания касательно оформления графиков, хочу отметить, что хотелось бы увидеть хотя бы небольшие промежуточные пояснения по ходу проекта, логично связывающие шаги между собой. Например, мне была очень интересна твоя логика: почему ты для одних признаков (точнее одного) строишь гистограмму, в то время как для других — диаграммы размаха, как ты при этом рассуждаешь.
#         <br/>Обрати внимание на свою гипотезу о природе пропущенных значений для признака <code>days_exposition</code>, кажется, для этого признака есть довольно логичное объяснение.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Доработал графики, добавил промежуточные сопроводительные пояснения и гистограммы. Добавил в выводы предположение о природе пропусков признака <code>days_exposition</code>.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
#     <b>Верно!👍:</b> Мне кажется, так стало совсем-совсем хорошо! Можешь ещё потом <code>value_counts</code> попробовать разве что для уникальных значений.
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Исправление названий признаков

# %%
# df_data.columns = ['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
#        'ponds_nearest', 'days_exposition']

df_data = df_data.rename(columns={
    'cityCenters_nearest': 'city_centers_nearest',
    'parks_around3000': 'parks_around_3000',
    'ponds_around3000': 'ponds_around_3000'
})

list(df_data.columns)
# Out:
# ['total_images',
#  'last_price',
#  'total_area',
#  'first_day_exposition',
#  'rooms',
#  'ceiling_height',
#  'floors_total',
#  'living_area',
#  'floor',
#  'is_apartment',
#  'studio',
#  'open_plan',
#  'kitchen_area',
#  'balcony',
#  'locality_name',
#  'airports_nearest',
#  'city_centers_nearest',
#  'parks_around_3000',
#  'parks_nearest',
#  'ponds_around_3000',
#  'ponds_nearest',
#  'days_exposition']

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Молодец, имена колонок исправлены. Хочу дать тебе полезный совет, это место можно улучшить. При переименовании колонок таким образом, как ты делаешь это сейчас, должен строго соблюдаться порядок столбцов — если ты поменяешь в списке из правой части команды некоторые элементы местами, то имена столбцов перепутаются. Использование метода <a href='https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html'><code>rename</code></a> защищает тебя от такой ошибки, а также позволяет поменять имена только для определенных столбцов.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Готово, сделал через безопасный метод <code>.rename()</code>.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Ещё и код компактнее.
# </div>

# %% [markdown]
# ### Заполнение пропусков и обработка выбросов признака "ceiling_height"

# %% [markdown]
# Согласно основным статистикам, признак содержит аномальные значения - выбросы, как в нижней границе, так и в верхней.
#
# Построим диаграмму размаха, чтобы оценить выбросы.

# %%
df_data[['ceiling_height']].boxplot(vert=False, figsize=(15, 3))

plt.title('Диаграмма размаха высоты потолков квартир', fontsize=16)
plt.xlabel('Высота потолков в метрах', fontsize=14)

step = 5
plt.xticks(np.arange(0, df_data['ceiling_height'].max() + step, step));

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>При попытке настроить шкалу отменяются настройки размера диаграммы и визуализация страдает.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
#         <b>Совет💡:</b> Сначала создай ящик, потом используй <code>plt.xticks</code> и <code>plt.show()</code> для вывода графика в конце. Так происходит потому, что <code>xticks</code> обращается к последним активным осям.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Волшебство сработало!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> <img src='https://memepedia.ru/wp-content/uploads/2017/03/2bb6dc0db7452e.png'>
# </div>

# %% [markdown]
# Рассмотрим значения в нижней границе подробнее.

# %%
df_data['ceiling_height'].hist(range=(0, 2), bins=50, figsize=(15, 3))

plt.title('Высота потолков квартир, квартиры с высотой потолков до 2 метров', fontsize=16)
plt.xlabel('Высота потолков в метрах', fontsize=14);

# %% [markdown]
# Также рассмотрим значения более 5 метров.

# %%
df_data['ceiling_height'].hist(range=(5, 100), bins=50, figsize=(15, 3))

plt.title('Высота потолков квартир, квартиры с высотой потолков более 5 метров', fontsize=16)
plt.xlabel('Высота потолков в метрах', fontsize=14)

step = 5
plt.xticks(np.arange(0, df_data['ceiling_height'].max() + step, step));

# %% [markdown]
# Обработаем пропуски и аномалии следующим образом:
# - пропуски заменим медианой, чтобы получить минимальную ошибку предположения;
# - значения менее двух метров заменим двумя метрами, таким образом установим минимальный порог;
# - значения от 10 до 20 метров заменим медианой, так как природа возникновения данных аномалий неизвестна;
# - значения более 20 метров уменьшим в десять раз, так как по ошибке они могли быть записаны с лишним нулём.

# %%
ceiling_height_median = df_data['ceiling_height'].median()

df_data['ceiling_height'] = df_data['ceiling_height'].fillna(ceiling_height_median)
df_data['ceiling_height'] = df_data['ceiling_height'].mask(df_data['ceiling_height'] < 2, 2)
df_data['ceiling_height'] = df_data['ceiling_height'].mask(
    (df_data['ceiling_height'] > 10) & (df_data['ceiling_height'] < 20), ceiling_height_median)
df_data['ceiling_height'] = df_data['ceiling_height'].mask(df_data['ceiling_height'] >= 20, df_data['ceiling_height'] / 10)

df_data['ceiling_height'].describe()
# Out:
# count    23699.000000
# mean         2.698005
# std          0.236841
# min          2.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max         10.000000
# Name: ceiling_height, dtype: float64

# %%
print(f'''
Количество пропусков признака "ceiling_height":\t\t{df_data['ceiling_height'].isna().sum()}
''')
# Out:
# Количество пропусков признака "ceiling_height":		0

# %%
df_data['ceiling_height'].hist(bins=100, figsize=(15, 3))

plt.title('Высота потолков квартир после обработки', fontsize=16)
plt.xlabel('Высота потолков в метрах', fontsize=14)

step = 1
plt.xticks(np.arange(2, df_data['ceiling_height'].max() + step, step));

# %% [markdown]
# Готово. Пропуски заполнены, аномалии устранены. Значения более пяти метров также вызывают подозрения, но они в теории могут встречаться в случае с дорогим жильём.

# %%
df_data.query('ceiling_height > 5')[['last_price', 'rooms', 'ceiling_height', 'total_area', 'living_area']]
# Out:
#         last_price  rooms  ceiling_height  total_area  living_area
# 464     66571000.0      6             5.2       280.3        159.5
# 1026   155000000.0      5             5.3       310.0        190.0
# 1388    59800000.0      5             5.6       399.0          NaN
# 3474     1400000.0      1             8.0        30.0         15.3
# 5863     5650000.0      1             8.3        45.0         19.3
# 7578    38000000.0      3             5.5       143.0         83.0
# 12628    3900000.0      1             5.3        50.0          NaN
# 15743    5600000.0      3             8.0        67.0         41.0
# 17442    5350000.0      2             8.0        54.0         29.0
# 20264  119000000.0      4             6.0       187.6        147.0
# 21227    8200000.0      0             5.8        71.0         68.0
# 22869   15000000.0      1            10.0        25.0         14.0

# %% [markdown]
# Нет, маловероятно, что скромные квартиры от 30 до 67 метров обладают такими высокими потолками. Обработаем их тоже.

# %%
df_data['ceiling_height'] = df_data['ceiling_height'].mask(df_data['ceiling_height'] > 6, ceiling_height_median)

df_data.query('ceiling_height > 5')[['last_price', 'rooms', 'ceiling_height', 'total_area', 'living_area']]
# Out:
#         last_price  rooms  ceiling_height  total_area  living_area
# 464     66571000.0      6             5.2       280.3        159.5
# 1026   155000000.0      5             5.3       310.0        190.0
# 1388    59800000.0      5             5.6       399.0          NaN
# 7578    38000000.0      3             5.5       143.0         83.0
# 12628    3900000.0      1             5.3        50.0          NaN
# 20264  119000000.0      4             6.0       187.6        147.0
# 21227    8200000.0      0             5.8        71.0         68.0

# %%
df_data['ceiling_height'].hist(bins=100, figsize=(15, 3))

plt.title('Высота потолков квартир после обработки', fontsize=16)
plt.xlabel('Высота потолков в метрах', fontsize=14)

step = 1
plt.xticks(np.arange(2, df_data['ceiling_height'].max() + step, step));

# %% [markdown]
# Теперь гораздо лучше.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Возможно, следовало создать новый признак-индикатор для объектов подвергшихся предобработке.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Отвечая на твой комментарий, мне кажется, нет большого смысла - таких объектов сравнительно немного в выборке, стоит ли заводить для них отдельный признак? В принципе, можно было бы и удалить все квартиры с выбросами, для возникновения которых ты не можешь найти логичного объяснения или испытываешь сомнения на этот счёт, предварительно проверив, не являются ли эти квартиры какими-то очень характерными по другим признакам (а если они очень выделяющиеся в такой большой выборке, вероятно, что они всё равно не лягут в общую концепцию определения рыночной стоимости/выявления мошеннической активности) или, что тоже будет хорошим решением, заполнишь такие значения явными пропусками с помощью <code>np.nan</code>.
# </div></div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Мне нравится, как ты решаешь задачу, масштабируя гистограммы в разных областях выбросов, внимательно анализируешь полученные результаты, формируешь по результатам предположения и принимаешь решение о дальнейшей обработке, проверяя результаты — настоящий аналитический подход.
#     <br/>Молодец, что углубляешься за пределы программы курса, используя метод <code>mask</code>. Кроме того, вижу, что ты хорошо разбираешься и в материале спринта, например, используя метод <code>query</code> для построения срезов.
# <br/>Я не буду каждый раз указывать тебе в красном комментарии на недочёты в оформлении графиков, которые я уже описывал ранее, их желательно исправить по всей работе.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Привёл графики в порядок. Fixed.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> <input type="checkbox"
#          checked>
# </div>

# %% [markdown]
# ### Заполнение пропусков признака "floors_total"

# %%
# print(f'''
# Количество пропусков признака "floors_total":\t\t{df_data['floors_total'].isna().sum()}
# Доля объектов с пропусками от всех объектов:\t\t{(df_data['floors_total'].isna().sum() / len(df_data)):.2%}
# ''')

print(f'''
Количество пропусков признака "floors_total":\t\t{df_data['floors_total'].isna().sum()}
Доля объектов с пропусками от всех объектов:\t\t{df_data['floors_total'].isna().mean():.2%}
''')
# Out:
# Количество пропусков признака "floors_total":		86
# Доля объектов с пропусками от всех объектов:		0.36%

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Обратил внимание на то, как ты определяешь долю пропущенных значений, тут у меня есть небольшой полезный совет.
# <br/>Есть небольшой популярный трюк, связанный с применением метода <code>mean</code> к столбцу со значениями <code>True/False</code>. True эквивалентно 1, тогда, считая среднее для такого столбца, встречая True-строку, каждый раз мы будем прибавлять единицу к сумме, начав с нуля. Таким образом, фактически мы получим вместо суммы значений количество таких строк, False-строки, будучи нулями, вклад в сумму не принесут. Тогда, разделив сумму на общее число строк, мы получим долю строк, значение которых - True.<br/>
#         Добавлю пример для наглядности: <br/>
#
# <code>animals = pd.Series(['lama', 'cow', 'lama', 'beetle', 'lama']) #создадим столбец с животными, есть повторяющиеся
# <br/>animals.duplicated() #найдём дубликаты</code>
#
# <br/>Получим:
# <br/>
#
# <code>0    False<br/>
# 1    False<br/>
# 2     True<br/>
# 3    False<br/>
# 4     True<br/>
# dtype: bool</code><br/>
#
# Считая средневыборочное методом <code>mean</code>, мы сумму значений делим на количество строк: <br/>
# (False + False + True + False + True) / 5 = (0 + 0 + 1 + 0 + 1) / 5 = 2 / 5 (или 0,4) <br/>
# Именно 2 из 5 животных являются дубликатами (первый раз — оригинал).
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Спасибо, сделал при помощи метода <code>.mean()</code>.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Это популярный приём, надеюсь, теперь и ты будешь его использовать 🙂
# </div>

# %%
# df_data['floors_total'] = df_data['floors_total'].fillna(0)

# print(f'''
# Количество пропусков признака "floors_total":\t\t{df_data['floors_total'].isna().sum()}
# ''')

# %% [markdown]
# Данный способ заполнения признака "floors_total" может вызвать искажение данных при вычислении основных статистик. ~~Однако в данном случае доля нулевых значений пренебрежимо мала, а заполнение позволило избавиться от пропусков без удаления объектов.~~

# %%
df_data['floors_total'].describe()
# Out:
# count    23613.000000
# mean        10.673824
# std          6.597173
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Возможно, в данном случае следовало вообще не заполнять пропуски: явное отсутствие информации более информативно, чем косвенное.
# <br>
# <br><b>UPD:</b> решил оставить пропуски так как их корректное заполнение невозможно, а отсутствие информации - также информация.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Молодец, абсолютно согласен с тобой, мне кажется, что в данном случае это самое подходящее решение. Мой комментарий про признаки-индикаторы, кстати, справедлив и здесь.
# </div>

# %% [markdown]
# ### Заполнение пропусков и обработка выбросов признака "living_area"

# %%
print(f'''
Количество пропусков признака "living_area":\t\t{df_data['living_area'].isna().sum()}
''')
# Out:
# Количество пропусков признака "living_area":		1903

# %%
df_data['living_area'].describe()
# Out:
# count    21796.000000
# mean        34.457852
# std         22.030445
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Заполнение признака "living_area" можно выполнить при помощи значений признака "total_area". Рассмотрим соотношение значений этих признаков.

# %%
(df_data['living_area'] / df_data['total_area']).describe()
# Out:
# count    21796.000000
# mean         0.564766
# std          0.105368
# min          0.021583
# 25%          0.495177
# 50%          0.567860
# 75%          0.637880
# max          1.000000
# dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Отличная идея, оценить описательные статистики для отношения рассматриваемых признаков, которое ты планируешь использовать при заполнении, очень здорово, что ты делаешь такую оценку, перед тем как провести заполнение пропущенных значений.
# </div>

# %% [markdown]
# В большинстве средних квартир (интерквартильный размах) данное соотношение находится в пределах от ~0.495 до ~0.637. Использование медианного соотношения ~0.567 для вычисления "living_area" позволит минимизировать ошибку предположения.

# %%
living_area_part = (df_data['living_area'] / df_data['total_area']).median()

df_data['living_area'] = df_data['living_area'].fillna(df_data['total_area'] * living_area_part)

# %%
print(f'''
Количество пропусков признака "living_area":\t\t{df_data['living_area'].isna().sum()}
''')
# Out:
# Количество пропусков признака "living_area":		0

# %%
df_data['living_area'].describe()
# Out:
# count    23699.000000
# mean        34.578214
# std         22.340665
# min          2.000000
# 25%         19.000000
# 50%         30.000000
# 75%         42.100000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# После заполнения пропусков наблюдается незначительное изменение основных характеристик, следовательно, искажение информации минимально.
#
# Рассмотрим подробнее минимальные значения.

# %%
df_data['living_area'].hist(bins=100, range=(0, 8), figsize=(15, 3))

plt.title('Жилая площадь квартир, значения менее 8 метров', fontsize=16)
plt.xlabel('Жилая площадь квартир в квадратных метрах', fontsize=14);
plt.ylabel('Количество квартир', fontsize=14);

# %%
df_data.query('living_area < 8')[['total_area', 'living_area']]
# Out:
#        total_area  living_area
# 3242         41.0     3.000000
# 13915        52.0     2.000000
# 16431        31.0     6.000000
# 17582        22.0     5.000000
# 17961        13.0     7.382179
# 19251        33.0     6.500000
# 19546        13.0     7.382179
# 19558        13.2     7.495751
# 21758        23.0     2.000000
# 21943        77.6     5.400000
# 23574       139.0     3.000000

# %% [markdown]
# Значения признака "living_area" менее 7 метров выглядят нереалистичными: квартиры с площадью от 23 метров до 139 метров имеют показатели живой площади от 2 до 6.5 метров - подозрительно похоже на ошибки.
#
# Обработаем данные объекты аналогичным образом.

# %%
# df_data.loc[df_data['living_area'] < 7, 'living_area'] = (
#     df_data.loc[df_data['living_area'] < 7, 'total_area'] * living_area_part
# )

df_data['living_area'] = df_data['living_area'].mask(df_data['living_area'] < 7,
                                                    np.round(df_data['total_area'] * living_area_part, 1))

# %%
df_data['living_area'].describe()
# Out:
# count    23699.000000
# mean        34.586856
# std         22.337120
# min          7.382179
# 25%         19.000000
# 50%         30.000000
# 75%         42.100000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Пропуски заполнены, выбросы устранены.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Здесь всё хорошо, особо нечего добавить, кроме того, что я уже выделил, касательно описательных статистик отношения двух столбцов.
# <br/>Обращу твоё внимание на то, что объектов недвижимости с аномально маленькой жилой площадью в данных действительно немного, можно было бы и удалить их или заменить аномальные значения на явные пропуски, но твоё решение для заполнения тут мне тоже нравится и смотрится очень логично.
# </div>

# %% [markdown]
# ### Заполнение пропусков признака "is_apartment"

# %%
print(f'''
Количество пропусков признака "is_apartment":\t\t{df_data['is_apartment'].isna().sum()}
Доля объектов с пропусками от всех объектов:\t\t{(df_data['is_apartment'].isna().sum() / len(df_data)):.2%}
''')
# Out:
# Количество пропусков признака "is_apartment":		20924
# Доля объектов с пропусками от всех объектов:		88.29%

# %%
df_data['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Данный признак практически полностью состоит из пропусков, более 88% процентов. Большинство заполненных значений - "False", не апартаменты.
#
# Пропуски данного признака могут быть заполнены значениями "False" из расчёта, что отсутствие информации об апартаментах - отсутствие принадлежности к апартаментам. Данная стратегия основывается на предположении, что-либо пользователи не указывали данный признак как очевидный для них, либо сервис продаж не содержит соответствующих полей для заполнения, так как торгует только жилой недвижимостью.

# %%
df_data['is_apartment'] = df_data['is_apartment'].fillna(False)

# %%
print(f'''
Количество пропусков признака "is_apartment":\t\t{df_data['is_apartment'].isna().sum()}
''')
# Out:
# Количество пропусков признака "is_apartment":		0

# %%
df_data['is_apartment'].value_counts()
# Out:
# False    23649
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Пропуски заполнены.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Возможно, в данном случае также следовало не заполнять пропуски, чтобы не искажать информацию предположениями.
# <br>Возможно, не помешала бы генерация нового признака-индикатора, что данные значения были заполнены согласно предположению.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Заполнение проведено корректно.
# <br/>Гипотеза о том, что все пропуски здесь имеют логичную интерпритацию, выглядит наиболее подходящей — недвижимость, относящаяся к апартаментам имеет ряд юридических особенностей, поэтому для продавца нет особого смысла умышленно вводить покупателя в заблуждение — факт принадлежности недвижимости к этому классу практически невозможно утаить от покупателя, продавец в таком случае только потеряет своё время. Т.ч., скорее всего, если не указано иное, то недвижимость — не апартаменты.
# <br/>Так как здесь есть логичная интерпритация для пропусков, то нет смысла вводить признак-индикатор наличия пропуска, хотя здесь доля пропущенных значений уже гораздо более ощутимая.
# </div>

# %% [markdown]
# ### Заполнение пропусков признака "kitchen_area"

# %%
print(f'''
Количество пропусков признака "kitchen_area":\t\t{df_data['kitchen_area'].isna().sum()}
''')
# Out:
# Количество пропусков признака "kitchen_area":		2278

# %%
df_data['kitchen_area'].describe()
# Out:
# count    21421.000000
# mean        10.569807
# std          5.905438
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Аналогично "living_area", заполнение признака "kitchen_area" можно выполнить при помощи значений признака "total_area". Рассмотрим соотношение значений этих признаков.

# %%
(df_data['kitchen_area'] / df_data['total_area']).describe()
# Out:
# count    21421.000000
# mean         0.187355
# std          0.072968
# min          0.025381
# 25%          0.133333
# 50%          0.172414
# 75%          0.232416
# max          0.787879
# dtype: float64

# %% [markdown]
# Интерквартильный размах находится в пределах значений ~0.133 и ~0.232, а медианное соотношение равно ~0.172. Данные значения значительно отличаются друг от друга, однако использование медианы позволит минимизировать ошибку предположения.

# %%
kitchen_area_part = (df_data['kitchen_area'] / df_data['total_area']).median()

df_data['kitchen_area'] = df_data['kitchen_area'].fillna(df_data['total_area'] * kitchen_area_part)

# %%
print(f'''
Количество пропусков признака "kitchen_area":\t\t{df_data['kitchen_area'].isna().sum()}
''')
# Out:
# Количество пропусков признака "kitchen_area":		0

# %% [markdown]
# Проверим, не превышают ли площадь кухни и жилая площадь общую площадь квартиры.

# %%
df_data.query('living_area + kitchen_area > total_area')[['living_area', 'kitchen_area', 'total_area']].describe()
# Out:
#        living_area  kitchen_area  total_area
# count   118.000000    118.000000  118.000000
# mean     41.117221     13.551686   49.469661
# std      28.873679     10.325181   32.095307
# min      10.000000      2.068966   12.000000
# 25%      25.000000      6.050000   30.400000
# 50%      34.149369     10.250000   40.540000
# 75%      52.125000     17.590517   61.600000
# max     220.000000     53.000000  230.000000

# %% [markdown]
# Обнаружились 118 квартир, где наблюдается подобное логическое нарушение.
#
# Округлим в меньшую сторону площадь кухни и жилую площадь для данных квартир, чтобы минимизировать погрешности вычислений.

# %%
index = df_data.query('living_area + kitchen_area > total_area').index

df_data.loc[index, 'living_area'] = np.floor(df_data.loc[index, 'living_area'])
df_data.loc[index, 'kitchen_area'] = np.floor(df_data.loc[index, 'kitchen_area'])

df_data.query('living_area + kitchen_area > total_area')[['living_area', 'kitchen_area', 'total_area']].describe()
# Out:
#        living_area  kitchen_area  total_area
# count    98.000000     98.000000   98.000000
# mean     43.459184     14.224490   51.967449
# std      30.439451     10.704591   33.716821
# min      14.000000      3.000000   17.600000
# 25%      27.000000      7.250000   32.502500
# 50%      35.000000     11.000000   42.000000
# 75%      53.750000     18.000000   62.150000
# max     220.000000     53.000000  230.000000

# %% [markdown]
# Удалось исправить 20 объектов. Для оставшихся 98 объектов потребуются более решительные коррекции.
#
# Будем уменьшать площадь кухни и жилую площадь на 5% пока они "не влезут" в общую площадь квартиры. Проведём 10 итераций.

# %%
for _ in range(10):
    index = df_data.query('living_area + kitchen_area > total_area').index
    
    df_data.loc[index, 'living_area'] = np.floor(df_data.loc[index, 'living_area'] * 0.95)
    df_data.loc[index, 'kitchen_area'] = np.floor(df_data.loc[index, 'kitchen_area'] * 0.95)

df_data.query('living_area + kitchen_area > total_area')[['living_area', 'kitchen_area', 'total_area']].describe()
# Out:
#        living_area  kitchen_area  total_area
# count          0.0           0.0         0.0
# mean           NaN           NaN         NaN
# std            NaN           NaN         NaN
# min            NaN           NaN         NaN
# 25%            NaN           NaN         NaN
# 50%            NaN           NaN         NaN
# 75%            NaN           NaN         NaN
# max            NaN           NaN         NaN

# %% [markdown]
# Все квартиры исправлены.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Здесь ты действуешь аналогично ситуации с пропусками для жилой площади, это логичное решение.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Как тебе кажется, могла ли при таком заполнении возникнуть ситуация, когда площадь кухни и жилая площадь вместе больше общей площади объекта недвижимости?
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Провёл соответствующую проверку и обнаружил 118 квартир с искажением пространства. Затем исправил аномалии.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Классный цикл для корректировки возникших в результате расчёта аномалий.
#     <br/>Используя <a href='https://pythontutor.ru/lessons/while/'>эту</a> конструкцию для цикла, можно его ещё немного улучшить.
# </div>

# %% [markdown]
# ### Заполнение пропусков признака "balcony"

# %%
print(f'''
Количество пропусков признака "balcony":\t\t{df_data['balcony'].isna().sum()}
Доля объектов с пропусками от всех объектов:\t\t{(df_data['balcony'].isna().sum() / len(df_data)):.2%}
''')
# Out:
# Количество пропусков признака "balcony":		11519
# Доля объектов с пропусками от всех объектов:		48.61%

# %%
df_data['balcony'].describe()
# Out:
# count    12180.000000
# mean         1.150082
# std          1.071300
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          5.000000
# Name: balcony, dtype: float64

# %% [markdown]
# В данном случае отсутствие информации о балконах - отсутствие балконов.

# %%
df_data['balcony'] = df_data['balcony'].fillna(0)

# %%
print(f'''
Количество пропусков признака "balcony":\t\t{df_data['balcony'].isna().sum()}
''')
# Out:
# Количество пропусков признака "balcony":		0

# %%
df_data['balcony'].describe()
# Out:
# count    23699.000000
# mean         0.591080
# std          0.959298
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          5.000000
# Name: balcony, dtype: float64

# %% [markdown]
# Пропуски заполнены. Из-за большой доли пропусков, около половины от всех записей, основные статистики значительно изменились.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Заполнение проведено корректно.
# <br/>Если в квартире есть балкон, то продавцу стоит упомянуть об этом в объявлении, дополнительное уличное пространство в квартире может привлечь покупателей.
# </div>

# %% [markdown]
# ### Заполнение пропусков и обработка дубликатов признака "locality_name"

# %%
print(f'''
Количество пропусков признака "locality_name":\t\t{df_data['locality_name'].isna().sum()}
''')
# Out:
# Количество пропусков признака "locality_name":		49

# %% [markdown]
# Данный признак содержит пропуски, заполнение которых невозможно без запроса дополнительных данных. ~~Чтобы не удалять объекты с пропусками, заполним их значениями "unknown".~~

# %%
# df_data['locality_name'] = df_data['locality_name'].fillna('unknown')

# %%
# print(f'''
# Количество пропусков признака "locality_name":\t\t{df_data['locality_name'].isna().sum()}
# ''')

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# <br><b>UPD:</b> здесь также решил оставить пропуски так как их корректное заполнение невозможно, а отсутствие информации - также информация.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Всё верно, полностью одобряю такой подход, тем более, что пропусков в данных не слишком много. Если объектов с пропусками в такой ситуации было бы сравнительно много, так, чтобы их число перекрывало размер какой-то очень характерной группы по текущему или какому-то другому признаку, который необходимо сгруппировать по текущему, то есть вероятность полностью  потерять важную для исследования информацию.
# </div>

# %% [markdown]
# ~~Пропуски заполнены.~~
#
# Также данный признак содержит неявные дубликаты. Попробуем стандартизировать данные, оставив только название населённого пункта.

# %%
# df_data['locality_name'].unique()

print(f'Список уникальных значений признака "locality_name":')
print(f'; \n'.join(df_data['locality_name'].unique().astype(str)))
# Out:
# Список уникальных значений признака "locality_name":
# Санкт-Петербург;
# посёлок Шушары;
# городской посёлок Янино-1;
# посёлок Парголово;
# посёлок Мурино;
# Ломоносов;
# Сертолово;
# Петергоф;
# Пушкин;
# деревня Кудрово;
# Коммунар;
# Колпино;
# поселок городского типа Красный Бор;
# Гатчина;
# поселок Мурино;
# деревня Фёдоровское;
# Выборг;
# Кронштадт;
# Кировск;
# деревня Новое Девяткино;
# посёлок Металлострой;
# посёлок городского типа Лебяжье;
# посёлок городского типа Сиверский;
# поселок Молодцово;
# поселок городского типа Кузьмоловский;
# садовое товарищество Новая Ропша;
# Павловск;
# деревня Пикколово;
# Всеволожск;
# Волхов;
# Кингисепп;
# Приозерск;
# Сестрорецк;
# деревня Куттузи;
# посёлок Аннино;
# поселок городского типа Ефимовский;
# посёлок Плодовое;
# деревня Заклинье;
# поселок Торковичи;
# поселок Первомайское;
# Красное Село;
# посёлок Понтонный;
# Сясьстрой;
# деревня Старая;
# деревня Лесколово;
# посёлок Новый Свет;
# Сланцы;
# село Путилово;
# ...

# %%
print(f'''
Количество уникальных значений признака "locality_name":\t\t{len(df_data['locality_name'].unique())}
''')
# Out:
# Количество уникальных значений признака "locality_name":		365

# %% [markdown]
# Перед обработкой дубликаков создадим новый признак "locality_type", чтобы не потерять информацию о типе населённого пункта.

# %%
dict_locality_type = {
    'Санкт-Петербург': 'город',
    'поселок': 'поселок',
    'посёлок': 'поселок',
    'деревня': 'деревня',
    'село': 'село',
    'товарищество': 'товарищество',
}

df_data['locality_type'] = np.nan

for key, value in dict_locality_type.items():
    df_data['locality_type'] = df_data['locality_type'].mask(df_data['locality_name'].str.contains(key, na=False), value)

print(f'Список уникальных значений признака "locality_type":')
print(f'; \n'.join(df_data['locality_type'].unique().astype(str)))
# Out:
# Список уникальных значений признака "locality_type":
# город;
# поселок;
# nan;
# деревня;
# село;
# товарищество

# %%
df_data[['locality_name', 'locality_type']].head()
# Out:
#      locality_name locality_type
# 0  Санкт-Петербург         город
# 1   посёлок Шушары       поселок
# 2  Санкт-Петербург         город
# 3  Санкт-Петербург         город
# 4  Санкт-Петербург         город

# %% [markdown]
# Новый признак создан, теперь можно выполнять предобработку признака "locality_name".

# %%
df_data['locality_name'] = (
    df_data['locality_name']
    .str
    .replace('ё', 'е')
    .str
    .replace('городской поселок ', '')
    .str
    .replace('поселок городского типа ', '')
    .str
    .replace('поселок при железнодорожной станции ', '')
    .str
    .replace('поселок станции ', '')
    .str
    .replace('коттеджный поселок ', '')
    .str
    .replace('садоводческое некоммерческое товарищество ', '')
    .str
    .replace('садовое товарищество ', '')
    .str
    .replace('поселок ', '')
    .str
    .replace('деревня ', '')
    .str
    .replace('село ', '')
)

# %%
# df_data['locality_name'].unique()

print(f'Список уникальных значений признака "locality_name":')
print(f'; \n'.join(df_data['locality_name'].unique().astype(str)))
# Out:
# Список уникальных значений признака "locality_name":
# Санкт-Петербург;
# Шушары;
# Янино-1;
# Парголово;
# Мурино;
# Ломоносов;
# Сертолово;
# Петергоф;
# Пушкин;
# Кудрово;
# Коммунар;
# Колпино;
# Красный Бор;
# Гатчина;
# Федоровское;
# Выборг;
# Кронштадт;
# Кировск;
# Новое Девяткино;
# Металлострой;
# Лебяжье;
# Сиверский;
# Молодцово;
# Кузьмоловский;
# Новая Ропша;
# Павловск;
# Пикколово;
# Всеволожск;
# Волхов;
# Кингисепп;
# Приозерск;
# Сестрорецк;
# Куттузи;
# Аннино;
# Ефимовский;
# Плодовое;
# Заклинье;
# Торковичи;
# Первомайское;
# Красное Село;
# Понтонный;
# Сясьстрой;
# Старая;
# Лесколово;
# Новый Свет;
# Сланцы;
# Путилово;
# Ивангород;
# Шлиссельбург;
# Никольское;
# Зеленогорск;
# Сосновый Бор;
# Оржицы;
# Кальтино;
# Романовка;
# Бугры;
# Рощино;
# Кириши;
# Луга;
# Волосово;
# Отрадное;
# Павлово;
# Оредеж;
# Копорье;
# Молодежное;
# Тихвин;
# Победа;
# Нурма;
# Синявино;
# Тосно;
# Стрельна;
# Бокситогорск;
# Александровская;
# Лопухинка;
# Пикалево;
# ...

# %%
print(f'''
Количество уникальных значений признака "locality_name":\t\t{len(df_data['locality_name'].unique())}
''')
# Out:
# Количество уникальных значений признака "locality_name":		306

# %% [markdown]
# Количество уникальных значений признака "locality_name" уменьшилось с 365 до 306. Таким образом, удалось устранить 59 неявных дубликатов.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Возможно, следует создать новый признак "тип поселения", где можно было бы разместить удалённую информацию (посёлок/село/...).
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
#     <b>Верно!👍:</b> Молодец, тебе удалось удалить явные неявные дубликаты в данных. Правильное решение использовать перенос по строкам для команды, выполняющей замену, так код удобно читать и корректировать.
# <br/>Согласен с твоим комментарием про признак, учитывающий тип поселения, вероятно, он бы позволил обнаружить новые зависимости, которые бы могли быть интересны бизнесу, или повысить качество моделей машинного обучения, если заказчик будет обучать их на обработанных данных.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Создал новый признак <code>locality_type</code> с информацией о типе населённого пункта.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Это уже настоящий feature-engineering 🙂
# </div>

# %% [markdown]
# ### Заполнение пропусков признаков "airports_nearest", "city_centers_nearest", "parks_around_3000", "parks_nearest", "ponds_around_3000", "ponds_nearest".

# %%
df_data[["airports_nearest", "city_centers_nearest", "parks_around_3000", "parks_nearest", "ponds_around_3000",
         "ponds_nearest"]].isna().sum()
# Out:
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# dtype: int64

# %% [markdown]
# Рассматриваемые признаки имеют общий характер происхождения - они были получены автоматически на основе картографических данных. Данная особенность происхождения признаков позволяет заполнить их пропуски медианными значениями с группировкой по населённым пунктам.
#
# Логично предположить, что недвижимость из одного поселения будет иметь схожие показатели расстояния до центра, ближайшего парка, аэропорта и т.д.
#
# ~~Единственной проблемой данной стратегии являются записи со значениями признака "locality_name" - "unknown". Эта недвижимость может находиться в совершенно разных частях Ленинградской области. Идеальным решением проблемы является перезапрос данных о населённом пункте, что невозможно в данной ситуации. Таким образом, при заполнении пропусков объектов со значениями "unknown" информация может быть сильно искажена, поэтому их рассмотрение в дальнейшем должно учитывать высокие риски погрешности.~~

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# <br><b>UPD:</b> "unknown" объекты более не актуальны.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
#     <b>Верно!👍:</b><s>Нет <code>'unknown'</code> — нет проблем 🙂</s>
# </div>

# %%
# len(df_data.query('locality_name == "unknown"'))

# %%
# df_data.query('locality_name == "unknown"')[["airports_nearest", "city_centers_nearest", "parks_around_3000", "parks_nearest",
#                                              "ponds_around_3000", "ponds_nearest"]].isna().sum()

# %%
df_data[["airports_nearest", "city_centers_nearest", "parks_around_3000", "parks_nearest", "ponds_around_3000",
         "ponds_nearest"]].describe()
# Out:
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# count      18157.000000          18180.000000       18181.000000
# mean       28793.672193          14191.277833           0.611408
# std        12630.880622           8608.386210           0.802074
# min            0.000000            181.000000           0.000000
# 25%        18585.000000           9238.000000           0.000000
# 50%        26726.000000          13098.500000           0.000000
# 75%        37273.000000          16293.000000           1.000000
# max        84869.000000          65968.000000           3.000000
#
#        parks_nearest  ponds_around_3000  ponds_nearest
# count    8079.000000       18181.000000    9110.000000
# mean      490.804555           0.770255     517.980900
# std       342.317995           0.938346     277.720643
# min         1.000000           0.000000      13.000000
# 25%       288.000000           0.000000     294.000000
# ...

# %% [markdown]
# Приступим к заполнению пропусков медианными значениями с группировкой по "locality_name".

# %%
list_features_to_fill = ["airports_nearest", "city_centers_nearest", "parks_around_3000", "parks_nearest", "ponds_around_3000",
                         "ponds_nearest"]

for feature in list_features_to_fill:
    df_data[feature] = df_data[feature].fillna(
        df_data.groupby(by='locality_name')[feature].transform('median')
    )

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
#     <b>Верно!👍:</b> Молодец, правильная реализация заполнения пропущенных значений медианными значениями с группировкой. Правильная мысль использовать здесь метод <code>transform</code>.
# <br/> Молодец, что используешь в работе автоматизацию, перебирая столбцы в цикле.
# </div>

# %%
df_data[["airports_nearest", "city_centers_nearest", "parks_around_3000", "parks_nearest", "ponds_around_3000",
         "ponds_nearest"]].isna().sum()
# Out:
# airports_nearest        4837
# city_centers_nearest    4837
# parks_around_3000       4837
# parks_nearest           6032
# ponds_around_3000       4837
# ponds_nearest           4962
# dtype: int64

# %% [markdown]
# **Часть значений всё равно оказалась незаполнена. Рассмотрим их подробнее.**

# %%
df_data[df_data['airports_nearest'].isna()].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 5             10   2890000.0        30.4  2018-09-10T00:00:00      1
# 12            10   3890000.0        54.0  2016-06-30T00:00:00      2
# 22            20   5000000.0        58.0  2017-04-24T00:00:00      2
# 30            12   2200000.0        32.8  2018-02-19T00:00:00      1
# 37            10   1990000.0        45.8  2017-10-28T00:00:00      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 5             2.65          12.0    14.400000      5         False  ...
# 12            2.65           5.0    30.000000      5         False  ...
# 22            2.75          25.0    30.000000     15         False  ...
# 30            2.65           9.0    18.625805      2         False  ...
# 37            2.50           5.0    26.007983      1         False  ...
#
#     balcony  locality_name  airports_nearest  city_centers_nearest  \
# ...

# %%
df_data[df_data['airports_nearest'].isna()].query('locality_name == "Янино-1"').head()
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 5               10   2890000.0       30.40  2018-09-10T00:00:00      1
# 158             15   3100000.0       47.30  2017-11-07T00:00:00      2
# 529              2   5790000.0       78.89  2017-11-26T00:00:00      3
# 746              7   2160000.0       36.00  2018-10-25T00:00:00      1
# 1121            13   3000000.0       50.40  2018-02-07T00:00:00      2
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 5               2.65          12.0         14.4      5         False  ...
# 158             2.65           5.0         27.5      2         False  ...
# 529             2.65          12.0         44.5      3         False  ...
# 746             2.65          12.0         16.0      8         False  ...
# 1121            2.55           5.0         30.7      1         False  ...
#
#       balcony  locality_name  airports_nearest  city_centers_nearest  \
# ...

# %%
len(df_data[df_data['airports_nearest'].isna()].query('locality_name == "Янино-1"'))
# Out:
# 68

# %%
(
    df_data[df_data['airports_nearest'].isna()]
        .query('locality_name == "Янино-1"')
        [["airports_nearest", "city_centers_nearest", "parks_around_3000",
          "parks_nearest", "ponds_around_3000", "ponds_nearest"]].isna().sum()
)
# Out:
# airports_nearest        68
# city_centers_nearest    68
# parks_around_3000       68
# parks_nearest           68
# ponds_around_3000       68
# ponds_nearest           68
# dtype: int64

# %% [markdown]
# Очевидно, что для некоторых населённых пунктов значения рассматриваемых признаков отсутствуют полностью, что не позволяет их заполнить при помощи группировки. А заполнение иными способами может привести к серьёзному искажению информации. Таким образом, оставшиеся пропуски лучше не трогать, так как отсутствие информации - тоже информация.

# %%
df_data[["airports_nearest", "city_centers_nearest", "parks_around_3000", "parks_nearest", "ponds_around_3000",
         "ponds_nearest"]].describe()
# Out:
#        airports_nearest  city_centers_nearest  parks_around_3000  \
# count      18862.000000          18862.000000       18862.000000
# mean       29534.608101          14458.422967           0.589439
# std        13063.734447           8596.964755           0.795733
# min            0.000000            181.000000           0.000000
# 25%        18846.750000           9488.000000           0.000000
# 50%        27179.000000          13266.000000           0.000000
# 75%        38755.500000          16771.000000           1.000000
# max        84869.000000          65968.000000           3.000000
#
#        parks_nearest  ponds_around_3000  ponds_nearest
# count   17667.000000       18862.000000   18737.000000
# mean      475.966972           0.808239     498.223035
# std       235.604308           0.946347     207.477420
# min         1.000000           0.000000      13.000000
# 25%       428.500000           0.000000     441.000000
# ...

# %% [markdown]
# После заполнения пропусков основные характеристики изменились незначительно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Заполнение выполнено корректно. Отличное наблюдение про полное отсутствие действительных значений признаков из группы, связанной с геолокацией, для некоторых населённых пунктов. Правильное решение оставить пропуски для таких населённых пунктов «как есть», сложно подобрать адекватные значения под замену в данном случае.
# </div>

# %% [markdown]
# ### Заполнение пропусков и обработка выбросов признака "days_exposition"

# %% [markdown]
# Оценим количество и долю пропусков признака "days_exposition".

# %%
print(f'''
Количество пропусков признака "days_exposition":\t{df_data['days_exposition'].isna().sum()}
Доля пропусков признака "days_exposition":\t\t{df_data['days_exposition'].isna().mean():.2%}
''')
# Out:
# Количество пропусков признака "days_exposition":	3181
# Доля пропусков признака "days_exposition":		13.42%

# %% [markdown]
# Девятая часть от всей выборки не имеет данных о длительности продажи квартиры, а точнее информации на какой день объявление было снято.
#
# Рассмотрим плотность распределения признака.

# %%
df_data['days_exposition'].hist(bins=200, figsize=(15, 5))

plt.title('Длительность продажи квартир', fontsize=16)
plt.xlabel('Длительность продажи квартир в днях', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

plt.xticks(range(0, 1700, 100));

# %% [markdown]
# Большинство квартир продавались за первый год, причём заметно чаще в первую половину года.
#
# Рассмотрим подробнее вторую половину графика с наибольшими значениями.

# %%
df_data['days_exposition'].hist(bins=100, range=(800, 1600), figsize=(15, 5))

plt.title('Длительность продажи квартир, длительность более 800 дней', fontsize=16)
plt.xlabel('Длительность продажи квартир в днях', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

plt.xticks(range(800, 1700, 100));

# %% [markdown]
# Вертикальная шкала графика имеет гораздо меньший масштаб - плотность квартир здесь гораздо меньше. Более 800 дней продавалось совсем немного квартир, счёт идёт даже не на десятки для большинства столбцов.
#
# Также визуализируем диаграмму разброса.

# %%
df_data.plot(kind='scatter', x='days_exposition', y='last_price', figsize=(15, 5))

plt.title('Длительность продажи квартир, длительность более 800 дней', fontsize=16)
plt.xlabel('Длительность продажи квартир в днях', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

plt.xticks(range(0, 1700, 100));

# %% [markdown]
# Здесь прослеживаются теже тенденции, что и на гистограмме, однако также заметно, что в определённые дни происходили скачки объёмов продаж квартир. Это особенно интересно, так как отсчёт ведётся с момента публикации объявления, и для каждой квартиры он разный. Возможно, это случайность, а может быть и нет - торговые площадки могли стимулировать продажу недвижимости на определённый день, если клиенты теряли интерес к конкретному экземпляру.
#
# Рассмотрим основные статистики признака.

# %%
df_data['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Три объявления из четёрых закрывались менее чем за год, примерно до 8 месяцев.
#
# Подробнее рассмотрим квартиры из второй части гистограммы, с длительностью продажи более 800 дней.

# %%
df_data.query('days_exposition > 800').head()
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 42             13  22000000.0       161.8  2015-07-08T00:00:00      4
# 98             11  11700000.0        80.0  2014-12-10T00:00:00      3
# 109             2   7497600.0        62.5  2015-12-08T00:00:00      2
# 145             6   8290000.0        77.0  2015-09-21T00:00:00      2
# 201             5  10880000.0       123.1  2015-11-12T00:00:00      6
#
#      ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 42             2.80           4.0         80.9      2         False  ...
# 98             2.65           5.0         55.1      3         False  ...
# 109            2.65           5.0         35.5      5         False  ...
# 145            2.77          16.0         40.0      5         False  ...
# 201            3.20           5.0         89.0      2         False  ...
#
#      balcony    locality_name  airports_nearest  city_centers_nearest  \
# ...

# %%
df_data.query('days_exposition > 800').describe().transpose()
# Out:
#                       count          mean           std            min  \
# total_images          591.0  8.703892e+00  5.460983e+00       0.000000
# last_price            591.0  9.312231e+06  1.497251e+07  630000.000000
# total_area            591.0  7.558477e+01  4.923065e+01      20.500000
# rooms                 591.0  2.426396e+00  1.370728e+00       0.000000
# ceiling_height        591.0  2.768274e+00  2.933652e-01       2.500000
# floors_total          588.0  1.027551e+01  6.362872e+00       2.000000
# living_area           591.0  4.351861e+01  3.136455e+01      10.700000
# floor                 591.0  5.563452e+00  4.794660e+00       1.000000
# kitchen_area          591.0  1.262281e+01  8.174745e+00       3.534483
# balcony               591.0  5.143824e-01  8.749119e-01       0.000000
# airports_nearest      495.0  2.854680e+04  1.178439e+04    6949.000000
# city_centers_nearest  495.0  1.255544e+04  9.756540e+03     318.000000
# ...

# %% [markdown]
# Разнообразные предложения, каких-то отличительных особенностей явно не наблюдается, кроме длительности продажи.

# %%
# len(df_data.query('days_exposition > 800'))

print(f'''
Количество квартир, которые продавались более 800 дней:\t\t{len(df_data.query('days_exposition > 800'))}
Доля квартир, которые продавались более 800 дней:\t\t{(len(df_data.query('days_exposition > 800')) / len(df_data)):.2%}
''')
# Out:
# Количество квартир, которые продавались более 800 дней:		591
# Доля квартир, которые продавались более 800 дней:		2.49%

# %% [markdown]
# Доля таких квартир крайне мала, так что их можно исключать из дальнейшего анализа.
#
# Рассмотрим количество квартир с пропусками данного признака с распределением по годам.

# %%
pd.to_datetime(df_data[df_data['days_exposition'].isna()]['first_day_exposition'], format='%Y-%m-%d').dt.year.value_counts()
# Out:
# 2019    1796
# 2018     959
# 2017     271
# 2015      70
# 2016      67
# 2014      18
# Name: first_day_exposition, dtype: int64

# %% [markdown]
# Большинство значений пропущены в ближайшем 2019 году, далее по убывающей идут предыдущие года. Гистограмма распределения показала, что большинство квартир продаются сразу, а затем значения идут по убывающей.
#
# Данные два факта позволяют предположить, что пропущенные значения соответствуют квартирам, которые находились в продаже в момент сбора данных. Таким образом, данные пропуски заполнять некорректно, их наличие может сигнализировать об актуальности объявлений.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
# <hr>
# <b>Обрати внимание🤔:</b> Здесь снова сильно не хватает промежуточных комментариев, а для графиков нет вообще никаких подписей, даже в тексте. Для того, чтобы разобраться с визуализацией, нужно погружаться в код. Теперь представь, например, что ты оформляешь презентацию и нужно подписать графики — предстоит ещё больше попотеть, разбирая что это за график уже не просто по тексту, а в коде визуализации.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Согласен, уже сейчас пришлось разбираться с кодом, чтобы восстановить собственный ход мыслей. Подписал графики, добавил сопроводительные пояснения.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Получилось очень хорошо!
# </div>

# %% [markdown]
# Генерация для заполнения пропусков некорректна, так как невозможно подлинно спрогнозировать как долго продавалась конкретная недвижимость.
#
# Также нельзя однозначно утверждать, что длительная продажа является аномалией. Независимо от стоимости часть квартир продавалась несколько лет.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Твое решение верное и хорошо аргумментировано, радует, что для принятия решения ты используешь разные инструменты в процессе исследования, в т.ч. и scatter-plot.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Есть ещё идеи касательно логичного объяснения таких пропусков? Можно, например, взглянуть на распределение таких значений по году создания объявления.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Добавил предположение, что на момент среза данных эти объявления не имели даты закрытия - то есть были актуальны.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
#     <b>Верно!👍:</b> Скорее всего так и есть, здесь для <code>last_price</code> формулировка не самая удачная в задании, как мне кажется.
# </div>

# %% [markdown]
# ### Обработка выбросов признака "last_price"

# %%
df_data['last_price'].hist(bins=50, figsize=(15, 5))

plt.title('Стоимость квартиры на момент снятия публикации', fontsize=16)
plt.xlabel('Стоимость квартиры', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14);

# %% [markdown]
# Верхняя граница гистограммы находится в районе значений порядка 100.000.000 - это значит, что в данных присутствуют аномально большие значения.
#
# Рассмотрим их подробнее.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Здорово, что e-формат для чисел не вызывает для тебя затруднений, молодец.
# </div>

# %%
df_data.query('last_price > 1e8').head()
# Out:
#       total_images   last_price  total_area first_day_exposition  rooms  \
# 793             20  135000000.0       310.0  2018-05-22T00:00:00      4
# 1026            20  155000000.0       310.0  2018-10-12T00:00:00      5
# 1188            20  118000000.0       290.6  2018-06-01T00:00:00      6
# 1300            14  120000000.0       280.0  2018-07-12T00:00:00      5
# 1436            19  330000000.0       190.0  2018-04-04T00:00:00      3
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 793             3.30           5.0        250.0      2         False  ...
# 1026            5.30           3.0        190.0      3         False  ...
# 1188            3.82           6.0        188.7      3         False  ...
# 1300            4.70           4.0        162.0      3         False  ...
# 1436            3.50           7.0         95.0      5         False  ...
#
#       balcony    locality_name  airports_nearest  city_centers_nearest  \
# ...

# %%
df_data.query('last_price > 1e8')['last_price'].hist(bins=50, figsize=(15, 5))

plt.title('Стоимость квартиры на момент снятия публикации, значения более 100 миллионов', fontsize=16)
plt.xlabel('Стоимость квартиры', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14);

# %%
df_data.query('last_price > 1e8').describe().transpose()
# Out:
#                       count          mean           std           min  \
# total_images           37.0  1.575676e+01  4.603172e+00  3.000000e+00
# last_price             37.0  1.920268e+08  1.244244e+08  1.154900e+08
# total_area             37.0  3.293297e+02  1.612133e+02  1.245000e+02
# rooms                  37.0  5.216216e+00  1.857943e+00  2.000000e+00
# ceiling_height         37.0  3.372973e+00  8.017234e-01  2.650000e+00
# floors_total           37.0  6.864865e+00  3.513167e+00  3.000000e+00
# living_area            37.0  1.836349e+02  8.224514e+01  3.600000e+01
# floor                  37.0  5.459459e+00  3.927075e+00  1.000000e+00
# kitchen_area           37.0  4.275717e+01  2.202998e+01  1.200000e+01
# balcony                37.0  4.864865e-01  1.070348e+00  0.000000e+00
# airports_nearest       37.0  2.642750e+04  4.225099e+03  2.039900e+04
# city_centers_nearest   37.0  4.456986e+03  2.459190e+03  4.360000e+02
# ...

# %% [markdown]
# В выборке действительно присутствуют квартиры со стоимостью более 100 миллионов. Данные квартиры отличаются большой площадью, количеством комнат, удалённостью от центра.
#
# Возможно, при указании цены была допущена ошибка (добавлен лишний нуль). Или данная недвижимость действительно продаётся за очень большие деньги (продавец может указать любую цену). В текущих условиях проверка аномальных значений невозможна, поэтому их удаление или изменение недопустимо. Однако в дальнейшем данные объекты следует рассматривать отдельно, чтобы их значения не искажали общую тенденцию.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Да, аномальные объекты стоит отделить при проведении исследования, верное замечание.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Как квартиры могут выделять своей ценой ещё? Вспомни, что в будущем предполагается выделять еще и мошенническую деятельность.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Возможно, мошенники намеренно создают фейковые объявления, чтобы повлиять на средние показатели рынка? Например, данные объявления с аномально высокой ценой призваны увеличить расчётную среднюю стоимость квадратного метра.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Интересное предположение, это может обмануть рекоммендательные системы для цен на площадках. Недавно в рунете была похожая ситуация с видеокартами, люди пытались бороться со спекулянтами, использующими дефицит на рынке, размещая объявления с реальной ценой и пометкой «не для продажи».
# </div>

# %% [markdown]
# ### Обработка выбросов признака "total_area"

# %% [markdown]
# Рассмотрим плотность распредения значений признака полная площадь квартиры.

# %%
df_data['total_area'].hist(bins=50, figsize=(15, 5))

plt.title('Общая площадь квартир', fontsize=16)
plt.xlabel('Общая площадь квартир в квадратных метрах', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

plt.xticks(range(0, 950, 50));

# %% [markdown]
# В записях присутствуют немногочисленные данные о квартирах с площалью более 200 метров, рассмотрим их подробнее.

# %%
df_data.query('total_area > 200').head()
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 155             8  96000000.0       317.0  2017-07-07T00:00:00      4
# 464            15  66571000.0       280.3  2015-06-11T00:00:00      6
# 492            18  95000000.0       216.0  2017-12-05T00:00:00      4
# 509             5  90000000.0       225.0  2016-06-26T00:00:00      6
# 521            20  25717300.0       230.1  2015-01-21T00:00:00      3
#
#      ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 155            3.50           3.0        183.0      3         False  ...
# 464            5.20           8.0        159.5      7         False  ...
# 492            3.00           5.0         86.0      4         False  ...
# 509            2.65           4.0        134.0      2         False  ...
# 521            2.65           3.0        130.0      1         False  ...
#
#      balcony    locality_name  airports_nearest  city_centers_nearest  \
# ...

# %%
df_data.query('total_area > 200')['total_area'].hist(bins=50, figsize=(15, 5))

plt.title('Общая площадь квартир, квартиры с общей площадью более 200 квадратных метров', fontsize=16)
plt.xlabel('Общая площадь квартир в квадратных метрах', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

plt.xticks(range(200, 1000, 100));

# %%
df_data.query('total_area > 550')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 3117             19  140000000.0       631.0  2019-03-30T00:00:00      7
# 5358             20   65000000.0       590.0  2019-02-14T00:00:00     15
# 12859            20  140000000.0       631.2  2019-04-09T00:00:00      7
# 15651            20  300000000.0       618.0  2017-12-18T00:00:00      7
# 19540             8  420000000.0       900.0  2017-12-06T00:00:00     12
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 3117             2.65           5.0   358.319596      5         False  ...
# 5358             3.50           6.0   409.000000      3         False  ...
# 12859            3.90           4.0   322.300000      4         False  ...
# 15651            3.40           7.0   258.000000      5         False  ...
# 19540            2.80          25.0   409.700000     25         False  ...
#
#        balcony    locality_name  airports_nearest  city_centers_nearest  \
# ...

# %% [markdown]
# Данные записи также имеют право на существование, их удалять нельзя. Это может быть элитная недвижимость в частном секторе или лофт.
#
# Также рассмотрим показатели в области нижнего порога - квартиры наименьшей площади, менее 30 квадратных метров.

# %%
df_data.query('total_area < 30')['total_area'].hist(bins=50, figsize=(15, 5))

plt.title('Общая площадь квартир, квартиры с общей площадью менее 30 квадратных метров', fontsize=16)
plt.xlabel('Общая площадь квартир в квадратных метрах', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

plt.xticks(range(10, 32, 2));

# %%
df_data.query('total_area < 20')['rooms'].describe()
# Out:
# count    27.000000
# mean      0.703704
# std       0.465322
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: rooms, dtype: float64

# %% [markdown]
# На первый взгляд, малочисленная недвижимость с площадью менее 20 квадратных метров может показаться подозрительной. Однако значения признака количество комнат помогают найти объяснения. Это могут быть небольшие квартиры-студии или одиночные комнаты, продаваемые в общежитиях. Данные предложения также имеют право на существование, бюджетное жильё всегда пользуется спросом и поэтому важно для анализа.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Согласен, такие объекты недвижимости действительно могут существовать и продаваться.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b>Интересно было бы также посмотреть на гистограмму в области минимальных значений признака.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Добавил анализ объектов из области нижней границы признака.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Классное заключение по очень маленьким объектам недвижимости, тем более, что Питерские коммуналки, можно сказать, культурное являение.
# </div>

# %% [markdown]
# ### Преобразование признака "first_day_exposition"

# %%
df_data['first_day_exposition'].head()
# Out:
# 0    2019-03-07T00:00:00
# 1    2018-12-04T00:00:00
# 2    2015-08-20T00:00:00
# 3    2015-07-24T00:00:00
# 4    2018-06-19T00:00:00
# Name: first_day_exposition, dtype: object

# %% [markdown]
# Данный признак записан в формате строки, что может вызвать неудобства при оперировании датами. Выполним преобразование в соответствующий формат, причём сохраним только год, месяц и день, так как остальная информация не критична.

# %%
df_data['first_day_exposition'] = pd.to_datetime(df_data['first_day_exposition'], format='%Y-%m-%d')

# %%
df_data['first_day_exposition'].head()
# Out:
# 0   2019-03-07
# 1   2018-12-04
# 2   2015-08-20
# 3   2015-07-24
# 4   2018-06-19
# Name: first_day_exposition, dtype: datetime64[ns]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> У тебя получилось преобразовать тип данных для временной переменной, это действительно поможет избежать неудобств при оперировании датами, которое нам потреубется провести в дальнейшем — верное замечание.
# </div>

# %% [markdown]
# ### Прочие преобразования типов данных

# %% [markdown]
# Преобразуем признаки "balcony" и "last_price" к целочисленному типу для удобства оперирования данными и оптимизации объёма потребляемой памяти.
#
# Вероятно, количество балконов должно быть всё же дискретной величиной.
#
# А копейки не оказывают значимого влияния на стоимость жилья.

# %%
df_data['balcony'] = df_data['balcony'].astype(int)
df_data['last_price'] = df_data['last_price'].astype(int)

# %% [markdown]
# ### Выводы

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 23 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null int64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null datetime64[ns]
# rooms                   23699 non-null int64
# ceiling_height          23699 non-null float64
# floors_total            23613 non-null float64
# living_area             23699 non-null float64
# floor                   23699 non-null int64
# is_apartment            23699 non-null bool
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            23699 non-null float64
# balcony                 23699 non-null int64
# locality_name           23650 non-null object
# airports_nearest        18862 non-null float64
# city_centers_nearest    18862 non-null float64
# parks_around_3000       18862 non-null float64
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
#         <b>Совет💡:</b> Обрати внимание тут на тип данных для <code>last_price</code> и <code>balcony</code>.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Признак <code>balcony</code> имел тип <code>float</code> из-за наличия <code>np.nan</code> в прошлом. Признак <code>last_price</code> нуждался в дробной части для хранения информации о копейках, но видимо всё было тщетно. Преобразовал типы.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> NaN-ы заполнили, а копейки бесконечно малы в масштабе цен на недвижимость.
# </div>

# %% [markdown]
# В результате предобработки данных:
# - были заполнены пропуски, где это оказалось возможно и корректно;
# - были устранены аномальные значения, где они явно сигнализировали о наличии ошибок;
# - были устранены неявные дубликаты;
# - были преобразованы типы данных для удобства анализа и оперирования.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Предобработка прошла успешно, тебе хорошо удаётся обнаружить ошибки, предполагать возможные причины их возникновения и, исходя из этого и других нюансов, предлагать способы исправления и применять их.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
# <hr>
# <b>Обрати внимание🤔:</b>
# Внимание стоит обратить на некоторые места, где не хватает твоих комментариев — идут сплошные срезы и графики без пояснений к ним и переходам между ними. Также оформление графиков можно улучшить в часте аннотаций осей и заголовков.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Доработал графики и добавил сопутствующие комментарии.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Отлично!
# </div>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### Расчёт цены квадратного метра

# %%
# df_data['square_price'] = np.round(df_data['last_price'] / df_data['total_area'])

df_data['square_price'] = (df_data['last_price'] // df_data['total_area']).astype(int)

# %%
df_data['square_price'].head()
# Out:
# 0    120370
# 1     82920
# 2     92785
# 3    408176
# 4    100000
# Name: square_price, dtype: int64

# %%
df_data['square_price'].describe().apply('{0:.2f}'.format)
# Out:
# count      23699.00
# mean       99421.21
# std        50306.81
# min          111.00
# 25%        76585.00
# 50%        95000.00
# 75%       114256.00
# max      1907500.00
# Name: square_price, dtype: object

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Цена квадратного метра успешно посчитана. Мне кажется, что можно использовать деление нацело <code> // </code> так как копейки здесь мало значимы — цена квадратного метра недвижимости, к сожалению, на порядки больше копеек.
#     <br/>Классное форматирование для вывода метода <code>describe</code>, молодец.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Сделал признак целочисленным.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Хорошо.
# </div>

# %% [markdown]
# ### Расчёт дня недели публикации объявления

# %% [markdown]
# Определим новый признак - день недели публикации объявления.

# %%
dict_weekday_replace = {
    '0': 'Monday',
    '1': 'Tuesday',
    '2': 'Wednesday',
    '3': 'Thursday',
    '4': 'Friday',
    '5': 'Saturday',
    '6': 'Sunday'
}

df_data['weekday'] = df_data['first_day_exposition'].dt.weekday.astype(str)

for key, value in dict_weekday_replace.items():
    df_data['weekday'] = df_data['weekday'].str.replace(key, value)

# %% [markdown]
# Проверим значения нового признака: первые пять строк, количество значений и построим график.

# %%
df_data['weekday'].head()
# Out:
# 0    Thursday
# 1     Tuesday
# 2    Thursday
# 3      Friday
# 4     Tuesday
# Name: weekday, dtype: object

# %%
df_data['weekday'].value_counts()
# Out:
# Thursday     4295
# Tuesday      4183
# Friday       4000
# Wednesday    3974
# Monday       3612
# Saturday     1936
# Sunday       1699
# Name: weekday, dtype: int64

# %%
day_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

df_data['weekday'].value_counts().loc[day_order].plot(kind='bar', figsize=(15, 5), grid=True)

plt.title('Публикации объявлений в зависимости от дня недели', fontsize=16)
plt.xlabel('День недели', fontsize=14)
plt.ylabel('Количество объявлений', fontsize=14);

# %% [markdown]
# Визуальный анализ плотности распределения публикаций объявлений в зависимости от дня недели показывает, что в будни публикуется гораздо больше объявлений, чем в выходные. В понедельник наблюдается чуть меньшая активность, чем в остальные будние дни. Данное явление может быть объяснено тем, что большинство рекламных агентств активны в течение рабочей недели и в это время публикуют объявления.

# %% [markdown]
# ### Расчёт месяца публикации объявления

# %% [markdown]
# Выполним аналогичные преобразования и проверки теперь для месяца даты публикации объявлений.

# %%
dict_month_replace = {
    '12': 'December',
    '11': 'November',
    '10': 'October',
    '9': 'September',
    '8': 'August',
    '7': 'July',
    '6': 'June',
    '5': 'May',
    '4': 'April',
    '3': 'March',
    '2': 'February',
    '1': 'January'
}

df_data['month'] = df_data['first_day_exposition'].dt.month.astype(str)

for key, value in dict_month_replace.items():
    df_data['month'] = df_data['month'].str.replace(key, value)

# %%
df_data['month'].head()
# Out:
# 0       March
# 1    December
# 2      August
# 3        July
# 4        June
# Name: month, dtype: object

# %%
df_data['month'].value_counts()
# Out:
# February     2640
# March        2587
# April        2379
# November     2371
# October      2127
# September    1981
# June         1760
# August       1744
# July         1695
# December     1641
# January      1500
# May          1274
# Name: month, dtype: int64

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November',
               'December']

df_data['month'].value_counts().loc[month_order].plot(kind='bar', figsize=(15, 5), grid=True)

plt.title('Публикации объявлений в зависимости от месяца', fontsize=16)
plt.xlabel('Месяц', fontsize=14)
plt.ylabel('Количество объявлений', fontsize=14)

plt.xticks(ticks=range(0, 12, 1), labels=month_order);

# %% [markdown]
# Плотность продаж в зависимости от месяца неравномерна:
# - в мае, декабре и январе налюдаются резкие снижения объёмов публикаций;
# - с февраля по апрель наблюдается наибольший пик, резкий подъём после спада в январе;
# - с июня по ноябрь наблюдается рост.
#
# Здесь также необходимо заметить, что это данные не за один год, а за несколько. То есть это не непрерывная тенденция в течение одного интервала времени.

# %% [markdown]
# ### Расчёт года публикации объявления

# %% [markdown]
# Теперь рассмотрим даты в масштабе годов.

# %%
df_data['year'] = df_data['first_day_exposition'].dt.year

# %%
df_data['year'].head()
# Out:
# 0    2019
# 1    2018
# 2    2015
# 3    2015
# 4    2018
# Name: year, dtype: int64

# %%
df_data['year'].value_counts()
# Out:
# 2018    8519
# 2017    8190
# 2019    2879
# 2016    2783
# 2015    1191
# 2014     137
# Name: year, dtype: int64

# %%
df_data['year'].value_counts().loc[range(2014, 2020, 1)].plot(figsize=(15, 5), grid=True)

plt.title('Публикации объявлений в зависимости от года', fontsize=16)
plt.xlabel('Год', fontsize=14)
plt.ylabel('Количество объявлений', fontsize=14)

plt.xticks(range(2014, 2020, 1))
plt.yticks(range(0, 10000, 1000));

# %% [markdown]
# С 2014 года, практически с нулевых объёмов публикаций, наблюдается стабильный рост числа объявлений до 2017. В 2017 и 2018 годах объёмы старта продаж стабильны, а в 2019 году - резкий спад. Данный спад может быть объяснён тем, что в 2019 данные были собраны не в конце года. Проверим эту гипотезу.

# %%
df_data['first_day_exposition'].max()
# Out:
# Timestamp('2019-05-03 00:00:00')

# %% [markdown]
# Гипотеза подтвердилась:
# - в 2019 года наблюдаются около 3000 объявление, а в предыдущем 2018 году около 8500, то есть разница чуть менее трёх раз;
# - в 2019 году последняя дата зафиксирована в начале мая, то есть присутствуют данные за первые четыре месяца - за первую треть года.
#
# Таким образом, спад 2019 может быть обяъснён тем, что данные были получены не за весь, только за первую треть года. Экстраполируя объёмы публикаций в 2019 году можо предположить, что 2019 будет иметь значения сопоставимые с предыдущими 2018 и 2017 годами.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Выводы по расчётам с временными признаками будут едиными, так как замечания будут одинаковыми. Тут всё верно, классные циклы по словарю там, где это нужно, верные результаты расчётов.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> В каждом подпункте не хватает промежуточных комментариев, хотя бы к результатам вывода последних ячеек с числом уникальных значений.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Добавил комментарии и более детальный разбор с выводами. Для признаков день недели и месяц публикации решил использовать столбчатые диаграммы, так как это распределения разных интервалов времени, а не непрерывных величин.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Хороший выбор! Выбрать подходящую визуализацию тоже маленькое искусство.
# </div>

# %% [markdown]
# ### Добавление типа этажа

# %%
df_data['floor_type'] = np.nan

df_data['floor_type'] = np.where(df_data['floor'] == 1, 'first', 'other')
df_data['floor_type'] = df_data['floor_type'].mask(df_data['floor'] == df_data['floors_total'], 'last')

# %%
df_data[['floor', 'floors_total', 'floor_type']].head()
# Out:
#    floor  floors_total floor_type
# 0      8          16.0      other
# 1      1          11.0      first
# 2      4           5.0      other
# 3      9          14.0      other
# 4     13          14.0      other

# %%
df_data['floor_type'].value_counts(normalize=True).apply('{0:.2%}'.format)
# Out:
# other    73.61%
# last     14.18%
# first    12.20%
# Name: floor_type, dtype: object

# %% [markdown]
# Основное большинство квартир расположено на промежуточных этажах, почти каждые три квартиры из четырёх. Около 14% и 12% квартир расположены на последнем и первом этажах соответственно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Отличный код. Про ситуацию с твоими промежуточными комментариями, думаю, ты уже понимаешь.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Добавил локальный вывод.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> <input type="checkbox" checked>
# </div>

# %% [markdown]
# ### Расчёт соотношения жилой и общей площади

# %%
df_data['living_area_part'] = np.round(df_data['living_area'] / df_data['total_area'], 2)

# %%
df_data['living_area_part'].head()
# Out:
# 0    0.47
# 1    0.46
# 2    0.61
# 3    0.57
# 4    0.32
# Name: living_area_part, dtype: float64

# %%
df_data['living_area_part'].describe()
# Out:
# count    23699.000000
# mean         0.564886
# std          0.099806
# min          0.130000
# 25%          0.500000
# 50%          0.570000
# 75%          0.630000
# max          0.910000
# Name: living_area_part, dtype: float64

# %% [markdown]
# У основного большинства квартир жилая площадь занимает от половины до 63% от всей площади. Предельные минимальные и максимальные значения выглядят подорительно.

# %% [markdown]
# ### Расчёт соотношения площади кухни к общей площади

# %%
df_data['kitchen_area_part'] = np.round(df_data['kitchen_area'] / df_data['total_area'], 2)

# %%
df_data['kitchen_area_part'].head()
# Out:
# 0    0.23
# 1    0.27
# 2    0.15
# 3    0.17
# 4    0.41
# Name: kitchen_area_part, dtype: float64

# %%
df_data['kitchen_area_part'].describe()
# Out:
# count    23699.000000
# mean         0.185390
# std          0.069104
# min          0.030000
# 25%          0.140000
# 50%          0.170000
# 75%          0.220000
# max          0.720000
# Name: kitchen_area_part, dtype: float64

# %% [markdown]
# Площадь кухни чаще всего занимает от почти четверти до одной седьмой всей площади, предельные значения также вызывают подозрения.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
#     <b>Верно!👍:</b> Здорово, что владеешь <code>np.round</code> и округляешь результаты вычислений. Отношения определены верно.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Промежуточные комментарии и выводы — выводишь описательные статистики, сделай небольшой вывод по полученным наблюдениям.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Добавил выводы.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Сильно повторяться не буду, с выводами работа стала ещё лучше, выводы в основном корректные и хорошо аргумментированные, оставлю комментарии там, где есть что добавить.
# </div>

# %% [markdown]
# ### Выводы

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 30 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null int64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null datetime64[ns]
# rooms                   23699 non-null int64
# ceiling_height          23699 non-null float64
# floors_total            23613 non-null float64
# living_area             23699 non-null float64
# floor                   23699 non-null int64
# is_apartment            23699 non-null bool
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            23699 non-null float64
# balcony                 23699 non-null int64
# locality_name           23650 non-null object
# airports_nearest        18862 non-null float64
# city_centers_nearest    18862 non-null float64
# parks_around_3000       18862 non-null float64
# ...

# %% [markdown]
# Добавлены новые признаки в таблицу:
# - удельная стоимость квадратного метра;
# - день недели, месяц и год публикации объявления;
# - тип этажа: первый, последний или другой;
# - доля жилой площади от всей площади;
# - доля площади кухни от всей площади.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Видно, что новые признаки действительно появились в нашем DataFrame, молодец.
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучение параметров недвижимости

# %% [markdown]
# #### Площадь

# %%
df_data['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %%
df_data['total_area'].hist(bins=200, figsize=(15, 5))

plt.axvline(x=df_data['total_area'].median(), color='red', linestyle='--', label='Median', linewidth=3)
plt.axvline(x=df_data['total_area'].mean(), color='orange', linestyle=':', label='Mean', linewidth=3)
plt.legend(prop={'size': 16})

plt.title('Общая площадь квартир', fontsize=16)
plt.xlabel('Общая площадь квартир в квадратных метрах', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

step = 30
plt.xticks(np.arange(0, df_data['total_area'].max() + step, step));

# %% [markdown]
# Для лучшей визуализации рассмотрим отдельно квартиры площадью до 150 квадратных метров и более.

# %%
df_data['total_area'].hist(bins=200, range=(0, 150), figsize=(15, 5))

plt.axvline(x=df_data['total_area'].median(), color='red', linestyle='--', label='Median', linewidth=3)
plt.axvline(x=df_data['total_area'].mean(), color='orange', linestyle=':', label='Mean', linewidth=3)
plt.legend(prop={'size': 16})

plt.title('Общая площадь квартир, квартиры площадью более 150 квадратных метров', fontsize=16)
plt.xlabel('Общая площадь квартир в квадратных метрах', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

step = 10
plt.xticks(np.arange(0, 150 + step, step));

# %%
df_data['total_area'].hist(bins=200, range=(150, df_data['total_area'].max()), figsize=(15, 5))

plt.title('Общая площадь квартир, квартиры площадью до 150 квадратных метров', fontsize=16)
plt.xlabel('Общая площадь квартир в квадратных метрах', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

step = 50
plt.xticks(np.arange(150, df_data['total_area'].max() + step, step));

# %% [markdown]
# Согласно построенным гистограммам, абсолютное большинство значений расположилось в интервале от 20 до 140 квадратных метров.
#
# Медиана находится на отметке 52 метра, среднее смещено вправо из-за наличия больших значений - 60 метров.
#
# Самым распространённым метражом являются значения от ~30 до ~50 метров, далее плотность распределения начинает плавно убывать.
#
# Также на графике присутствует длинный тонкий "хвост" от 140 и вплоть до 900 метров.
#
# Минимальные значения выглядят вполне типично для студий, комнат общежитий и другого бюджетного жилья.
#
# Рассмотрим подробнее максимальные значения.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Хорошие выводы. Молодец, что визуализируешь среднее и медиану.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Числа на шкале смотрится кучновато, тут бы хорошо подошёл приём с масштабированием, который ты используешь в работе. Можно показать общую картину с большим шагом, а затем укрупненно в области большинства значений с меньшим, захватывая медиану и среднее выборочное.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Добавил две гистограммы чтобы подробнее пронаблюдать значения в областях минимальных и максимальных значений.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Так стало ещё нагляднее, отлично.
# </div>

# %%
print(f'Значение 99-той перцентили признака "total_area":\t{(df_data["total_area"].quantile(q=0.99)):.5}')
# Out:
# Значение 99-той перцентили признака "total_area":	197.21

# %% [markdown]
# Экстремально большие значения немногочисленны, но оказывают влияние на основные статистики.
#
# Таким образом, значения более 200 метров следует исключить при дальнейшем анализе или рассматривать отдельно чтобы избежать искажения основных тенденций.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Молодец, что рассматриваешь 99-ую перцентиль, используя для этого метод <code>quantile</code>, это позволяет тебе сделать правильный и качественный вывод, аргумментировано подать его.
# </div>

# %% [markdown]
# #### Цена

# %% [markdown]
# Рассмотрим основные статистики и плотность распределения цен недвижимости.

# %%
df_data['last_price'].describe().apply('{0:.2f}'.format)
# Out:
# count        23699.00
# mean       6541548.77
# std       10887013.27
# min          12190.00
# 25%        3400000.00
# 50%        4650000.00
# 75%        6800000.00
# max      763000000.00
# Name: last_price, dtype: object

# %%
df_data['last_price'].hist(bins=200, figsize=(16, 5))

plt.title('Стоимость квартиры на момент снятия публикации', fontsize=16)
plt.xlabel('Стоимость квартиры', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14);

# %%
print(f'Значение 99-той перцентили признака "last_price":\t{(df_data["last_price"].quantile(q=0.99)):.10}')
# Out:
# Значение 99-той перцентили признака "last_price":	36000000.0

# %% [markdown]
# Аномально большие значения не позволяют визуально оценить распределение.
#
# Рассмотрим две выборки раздельно: до 99-той перцентили и после.

# %%
df_data['last_price'].hist(range=(0, df_data["last_price"].quantile(q=0.99)), bins=200, figsize=(16, 5))

plt.axvline(x=df_data['last_price'].median(), color='red', linestyle='--', label='Median', linewidth=3)
plt.axvline(x=df_data['last_price'].mean(), color='orange', linestyle=':', label='Mean', linewidth=3)
plt.legend(prop={'size': 16})

plt.title('Стоимость квартиры на момент снятия публикации, квартиры стоимостью до 99-той перцентили', fontsize=16)
plt.xlabel('Стоимость квартиры', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14);

# %% [markdown]
# Большинство значений признака "last_price" расположено в пределах 10 миллионов и напоминает нормальное распределение c небольшим отклонением влево.
#
# Плотность значения более 10 миллионов равномерно убывает вплоть до 36 миллионов - 99-той перцентили, что делает распределение визуально похожим на распределение Пуассона.
#
# Медиана находится на значении 4.650.000, при этом среднее сильно смещено вправо из-за аномально больших значений - 6.541.548.
#
# Рассмотрим значения после 99-той перцентили.

# %%
df_data['last_price'].hist(range=(df_data["last_price"].quantile(q=0.99), df_data["last_price"].max()),
                           bins=200, figsize=(16, 5))

plt.title('Стоимость квартиры на момент снятия публикации, квартиры стоимостью более 99-той перцентили', fontsize=16)
plt.xlabel('Стоимость квартиры', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14);

# %% [markdown]
# Последний процент значений крайне велик: от 36 миллионов до 763 миллионов. Данные могут исказить основную тенденцию данных, поэтому при дальнейшем анализе их следует рассматривать отдельно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Здесь ты действуешь аналогично предыдущему пункту, поэтому добавить особа нечего. Выводы тоже получаются корректными. Добавлю, что распределения цен на рынке часто ведут себя логарифмически нормально, в частности, цен на недвижимость.
# </div>

# %% [markdown]
# #### Число комнат

# %%
df_data['rooms'].describe()
# Out:
# count    23699.000000
# mean         2.070636
# std          1.078405
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
df_data['rooms'].hist(bins=38, figsize=(16, 5))

plt.title('Число комнат', fontsize=16)
plt.xlabel('Число комнат', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14)

step = 1
plt.xticks(np.arange(0, df_data['rooms'].max() + step, step));

# %% [markdown]
# Подавляющее большинство квартир имеют от 1 до 3 комнат, что в действительности правдоподобно: такие квартиры наиболее распространены.
#
# Присутствует небольшой процент квартир с 0 комнат, что может соответствовать квартирам-студиям.
#
# С увеличением числа комнат от 4 и более жильё становится более редким, что также похоже на действительность: данная недвижимость менее востребована из-за большей стоимости и, как следствие, менее распространена.
#
# Рассмотрим характеристики квартир-студий подробнее.

# %%
df_data.query('rooms == 0')['total_area'].describe()
# Out:
# count    197.000000
# mean      29.279746
# std       25.855264
# min       15.500000
# 25%       24.050000
# 50%       26.050000
# 75%       28.400000
# max      371.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Данный тип жилья имеет меньшую квадратуру, что может соответствовать квартирам-студиям.
#
# Рассмотрим квартиры с количеством комнат от 4.

# %%
df_data.query('rooms >= 4')[['rooms', 'total_area']].describe()
# Out:
#              rooms   total_area
# count  1701.000000  1701.000000
# mean      4.528513   132.801434
# std       1.125602    75.035180
# min       4.000000    40.000000
# 25%       4.000000    87.000000
# 50%       4.000000   113.200000
# 75%       5.000000   155.300000
# max      19.000000   900.000000

# %% [markdown]
# Наблюдается тенденция увеличения площади при увеличении количества комнат, что правдоподобно.

# %%
df_data[['rooms', 'total_area']].corr()
# Out:
#                rooms  total_area
# rooms       1.000000    0.758344
# total_area  0.758344    1.000000

# %% [markdown]
# Признаки действительно достаточно сильно коррелируют.
#
# Отдельно рассмотрим квартиры с количеством комнат от 8 и более.

# %%
df_data.query('rooms >= 8')[['rooms', 'total_area']].describe()
# Out:
#            rooms  total_area
# count  31.000000    31.00000
# mean   10.000000   305.10000
# std     2.804758   140.49869
# min     8.000000   150.00000
# 25%     8.000000   232.50000
# 50%     9.000000   270.00000
# 75%    10.500000   347.25000
# max    19.000000   900.00000

# %% [markdown]
# Данное жильё также не вызывает подозрений, так как это могут быть квартиры премиум класса. Однако данный сегмент жилья немногочисленный и в дальнейшем анализе может быть проигнорирован, чтобы избежать искажения основных тенденций данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Классные выводы и промежуточные комментарии, здорово, что оцениваешь линейную зависимость количества комнат и общей площади объекта недвижимости, хорошее наблюдение. Тут бы к месту был бы ещё и scatterplot для этих признаков, он позволяет выявить и более сложные зависимости.
# </div>

# %% [markdown]
# #### Высота потолков

# %%
df_data['ceiling_height'].describe()
# Out:
# count    23699.000000
# mean         2.696780
# std          0.221268
# min          2.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          6.000000
# Name: ceiling_height, dtype: float64

# %%
df_data['ceiling_height'].hist(bins=100, figsize=(16, 5))

plt.title('Высота потолков', fontsize=16)
plt.xlabel('Высота потолков', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14);

# %%
df_data[['ceiling_height']].boxplot(vert=False, figsize=(15, 3))

plt.title('Диаграмма размаха высоты потолков', fontsize=16)
plt.xlabel('Высота потолков', fontsize=14);

# %% [markdown]
# Данный признак прошёл предобработку и теперь не содержит пропусков и аномалий.
#
# Большинство значений находятся в интервале от 2.5 до 3 метров, что не вызывает подозрений.
#
# Присутствуют пограничные значения в районах 2 и 6 метров, что может быть объяснено наличием бюджетного и дорогого жилья соответственно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b>Хороший вывод — не всё что находится за пределами усов ящика является выбросами, здесь их действительно можно объяснить, хотя двухметровый потолок, честно говоря, кажется ну уж очень бюджетным решением 🙂
# </div>

# %% [markdown]
# ### Время продажи квартиры

# %%
df_data['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
df_data['days_exposition'].hist(bins=100, figsize=(15, 3))

plt.title('Время продажи квартиры', fontsize=16)
plt.xlabel('Время продажи квартиры в днях', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14);

# %% [markdown]
# Медианное количество дней продажи квартиры - 95, а среднее - ~180. Данная разница может быть объяснена тем, что на среднее повлиял "хвост" гистограммы - квартиры, которые продавались необычайно долго, дольше года или даже нескольких лет.
#
# Также, согласно основным характеристикам, присутствуют и быстрые продажи квартир, менее месяца.
#
# Условимся, что быстрые продажи происходят в первый месяц размещения объявления, а медленные - более года размещения. Если квартира продалась очень быстро, то это может говорить о её исключительных характеристиках, так же как и медленная продажа более года сигнализирует о наличии отталкивающих факторов. Построим гистограмму ещё раз уже без учёта быстрых и медленных продаж.

# %%
df_data['days_exposition'].hist(bins=100, range=(30, 365), figsize=(15, 3))

plt.title('Время продажи квартиры, значения от 30 до 365 дней', fontsize=16)
plt.xlabel('Время продажи квартиры в днях', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14);

# %% [markdown]
# Гистограмма стала более равномерной за исключением нескольких скачков в областях 40, 60 и 90 дней.
#
# В целом наблюдается тенденция, что большинство квартир продаётся быстро и с увлечением срока размещения количество квартир снижается.
#
# Рассмотрим значения до 30 дней.

# %%
df_data['days_exposition'].hist(bins=31, range=(0, 30), figsize=(15, 3))

plt.title('Время продажи квартиры, значения от 0 до 30 дней', fontsize=16)
plt.xlabel('Время продажи квартиры в днях', fontsize=14)
plt.ylabel('Количество квартир', fontsize=14);

# %% [markdown]
# В первый месяц, начиная с третьего дня, квартиры продаются относительно равномерно. Только на 7 и 30 дни наблюдаются почти двукратные скачки. Однако продажи в целом в первый месяц достаточно равномерны, так что эти значения не похожи на аномальные и могут быть использованы в дальнейшем.
#
# Таким образом, если не брать во внимание немногочисленные скачки, скорость продажи квартир напоминает распределение Пуассона с длинным продолжением до значений 1580 дней. Однако квартиры, продающиеся более года, могут быть подозрительными, так как не столь привлекательны для клиентов.
#
# Однозначно назвать время продажи квартиры нельзя, большинство квартир продаются от 3 дней до года, но при этом вероятность продажи в первую половину года всё же выше.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Класс, очень хороший пункт, нравится, как ты делишь продажи на быстрые и медленные, это хорошо соотносится с графиками.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Попробую подтолкнуть тебя к интересной мысли: что снизило бы значимость отталкивающих факторов при выборе недвижимости для большинства потенциальных покупателей на твой взгляд?
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Самое очевидное предположение - цена или факторы связанные с ней. То есть в дни скачков продаж агентства по продаже могли устраивать акции с более выгодными условиями, скидки, льготная ипотека и т.д.
# <br>
# <br>Также возможно предположить, что скачки на графиках могут отражать массовые закрытия фейковых объявлений.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Интересные выводы по скачкам 🙂 Я вообще хотел подвести тебя к идее, что слишком продолжительная продажа свидетельствует об отклонении цены от рыночной для недвижимости с данными параметрами, спрос на такие объекты появится только при снижении цены.
# </div>

# %% [markdown]
# ### Исключение редких и выбивающихся значений

# %% [markdown]
# Создадим новую таблицу-срез без редких и выбивающихся значений.

# %%
df_filtered = (
    df_data
    .loc[df_data['last_price'] <= df_data['last_price'].quantile(q=0.99), :]
    .loc[df_data['total_area'] <= 140, :]
    .loc[df_data['days_exposition'] >= 3, :]
    .loc[df_data['days_exposition'] <= 365, :]
    .loc[df_data['rooms'] <= 7, :]
)

# %%
df_filtered.describe().transpose()
# Out:
#                         count          mean           std           min  \
# total_images          17088.0  9.652505e+00  5.643444e+00      0.000000
# last_price            17088.0  5.228655e+06  3.304356e+06  12190.000000
# total_area            17088.0  5.410841e+01  2.059802e+01     12.000000
# rooms                 17088.0  1.925211e+00  9.153439e-01      0.000000
# ceiling_height        17088.0  2.676128e+00  1.846165e-01      2.000000
# floors_total          17022.0  1.104905e+01  6.697006e+00      1.000000
# living_area           17088.0  3.080584e+01  1.387776e+01      7.382179
# floor                 17088.0  6.069113e+00  4.978689e+00      1.000000
# kitchen_area          17088.0  9.754683e+00  4.326984e+00      2.000000
# balcony               17088.0  6.029963e-01  9.483263e-01      0.000000
# airports_nearest      13643.0  2.982255e+04  1.340864e+04      0.000000
# city_centers_nearest  13643.0  1.497938e+04  8.350173e+03    208.000000
# ...

# %% [markdown]
# В результате исключения редких и выбивающихся значений были отбракованы 6611 объектов или чуть менее ~28% всей выборки. Были исключены квартиры с аномально высокой ценой, большой площадью и большим количеством комнат, а также предельными сроками продажи.
#
# Исключённая недвижимость сильно контрастировала на фоне большинства предложений о продаже и могла исказить основные статистики и тенденции в данных при дальнейшем анализе. Рассмотрение отфильтрованного набора данных позволит выявить и сформировать закономерности справедливые для основного большинства объявлений на рынке.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Согласно заданию, необходимо описать особенности, которые были обнаружены при удалении редких и выбивающихся значений. Не понимаю, на какие особенности необходимо обратить внимание в процессе фильтрации.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Тут всё хорошо, аномальные объекты недвижимости были исключены.
# <br/>Отвечая на твой комментарий, скажу, что ты обнаруживаешь какие-то особенности в процессе рассмотрения данных — например, слишком высокие потолки, а потом обрабатываешь соответствуюшие значения. Тобой уже отмечены особенности — ты начинаешь это делать с этапа предобработки, а здесь резюмируешь, т.ч. с этим пунктом задания точно всё отлично.
# </div>

# %% [markdown]
# ### Изучения факторов, влияющих на цену

# %% [markdown]
# #### Площаль

# %%
df_filtered.plot(kind='scatter', x='total_area', y='last_price', figsize=(8, 8))

plt.title('График разброса стоимости квартиры в зависимости от всей площади', fontsize=16, pad=20)
plt.xlabel('Площадь квартиры', fontsize=14)
plt.ylabel('Стоимость квартиры', fontsize=14);

# %%
df_filtered.plot(kind='hexbin', x='total_area', y='last_price', figsize=(10, 8), gridsize=25)

plt.title('Гексагональный график стоимости квартиры в зависимости от всей площади', fontsize=16, pad=20)
plt.xlabel('Площадь квартиры', fontsize=14)
plt.ylabel('Стоимость квартиры', fontsize=14);

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Очень удачный график, молодец!
# </div>

# %%
df_filtered[['total_area', 'last_price']].corr()
# Out:
#             total_area  last_price
# total_area    1.000000    0.732527
# last_price    0.732527    1.000000

# %% [markdown]
# Согласно графикам и матрице корреляций наблюдается зависимость: чем больше площадь, тем выше цена.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Верное наблюдение, которое вяжется со знакомой нам логикой рынка.
# </div>

# %% [markdown]
# #### Число комнат

# %%
df_filtered.plot(kind='scatter', x='rooms', y='last_price', figsize=(8, 8))

plt.title('График разброса стоимости квартиры в зависимости от количества комнат', fontsize=16, pad=20)
plt.xlabel('Количество комнат', fontsize=14)
plt.ylabel('Стоимость квартиры', fontsize=14);

# %%
df_filtered[['rooms', 'last_price']].corr()
# Out:
#                rooms  last_price
# rooms       1.000000    0.442182
# last_price  0.442182    1.000000

# %% [markdown]
# Число комнат - дискретный признак, поэтому не совсем корректно визуализировать его на диаграмме разброса и строить матрицу корреляций. Однако диаграмма содержит полезную информацию:
# - комнаты-студии имеют самый низкий диапазон цен;
# - обычные квартиры с числом комнат от 1 до 4 присутствуют во всех ценовых диапазонах, видимо оказывают влияние и других факторы;
# - квартиры с пятью комнатами присутствуют только в первой половине всего диапазона цен, однако таких квартир гораздо меньше, чем первых двух категорий. Здесь также стоит заметить, что начиная с этой категории минимальная цена начинает увеличиваться;
# - квартиры с шестью и семью комнатами малочисленны, но демонстрируют тенденцию, что дешёвого жилья среди них нет.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Тут всё хорошо. Смотри, если ты получаешь полезные выводы из визуализации, то, кажется, она всё-таки подходит 🙂 Диаграмму разброса можно строить для дискретных признаков, просто она будет «полосатой» по дискретной оси, но если есть какая-то чёткая зависимость, ты её заметишь и это не помешает тебе. Кроме того, сразу хорошо видно, что признак дискретный и можно оценить частоту дискретизации этого признака в данных.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Интересно, спасибо.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Рад, что удалось тебя заинтересовать. Вообще pairplot, или матрица диаграмм рассеяния, очень информативный инструмент.
# </div>

# %% [markdown]
# #### Удалённость от центра

# %%
df_filtered.plot(kind='scatter', x='city_centers_nearest', y='last_price', figsize=(8, 8))

plt.title('График разброса стоимости квартиры в зависимости от удалённости от центра', fontsize=16, pad=20)
plt.xlabel('Удалённость от центра в метрах', fontsize=14)
plt.ylabel('Стоимость квартиры', fontsize=14);

# %%
df_filtered.plot(kind='hexbin', x='city_centers_nearest', y='last_price', figsize=(10, 8), gridsize=50)

plt.title('Гексагональный график стоимости квартиры в зависимости от удалённости от центра', fontsize=16, pad=20)
plt.xlabel('Удалённость от центра в метрах', fontsize=14)
plt.ylabel('Стоимость квартиры', fontsize=14);

# %%
df_filtered[['city_centers_nearest', 'last_price']].corr()
# Out:
#                       city_centers_nearest  last_price
# city_centers_nearest              1.000000   -0.346669
# last_price                       -0.346669    1.000000

# %% [markdown]
# Здесь наблюдаются интересные закономерности:
# - дорогое жильё встречается только близко к центру, но при этом близко к центру встречаются и все остальные ценовые категории;
# - с удалением от центра максимальная стоимость жилья уменьшается;
# - вдали от центра встречается только дешёвое жильё.
#
# Таким образом, обратная зависимость между удалённостью и стоимостью жилья есть: тенденция снижения максимальной цены при удалении.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Супер! 🙂 Хорошие наблюдения.
# </div>

# %% [markdown]
# #### Этаж

# %%
df_filtered.plot(kind='scatter', x='floor', y='last_price', figsize=(8, 8))

plt.title('График разброса стоимости квартиры в зависимости от этажа', fontsize=16, pad=20)
plt.xlabel('Этаж', fontsize=14)
plt.ylabel('Стоимость квартиры', fontsize=14);

# %%
sns.catplot(x='floor_type', y='last_price', data=df_filtered, height=6)

plt.title('График разброса стоимости квартиры в зависимости от этажа', fontsize=16, pad=20)
plt.xlabel('Этаж', fontsize=14)
plt.ylabel('Стоимость квартиры', fontsize=14);

# %% [markdown]
# Согласно графикам, более дорогое жильё располагается до седьмого этажа. Также среди квартир на первом и последнем этажах реже встречаются дорогие экземпляры.

# %%
df_filtered[['floor']].boxplot(vert=False, figsize=(15, 3))

plt.title('Диаграмма размаха номеров этажей, на которых располагаются квартиры', fontsize=16)
plt.xlabel('Этаж', fontsize=14)

plt.xticks(range(0, df_filtered['floor'].max() + 1, 1));

# %% [markdown]
# Медиана равна 5, вокруг неё сгруппирована половина наиболее типичных квартир, располагающихся в интервале от 2 до 8 этажа. Нижняя граница доверительного интервала ограничена минимальным значением - 1 этаж. Верхняя граница интереснее, она располагается в районе 17 этажа, выше неё присутствуют значения, равномерно убывающие до 33 этажа. Данные значения не являются выбросами, хоть они и малочисленны и контрастируют на фоне средних показателей. Квартиры могут располагаться на этажах более 17 в высотных домах, а их небольшая доля может быть объяснена небольшим числом высотной недвижимости в Санкт-Петербурге.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Хорошие выводы.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Тут и дальше бы было полезно построить boxplot, чтобы можно было качественно сравнить распределения, всё-таки на текущем графике не совсем понятно, где у нас медиана и среднее для каждой категории.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Добавил диаграмму размаха.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Тут можно построить диаграмму размаха подобную той, как в <a href='https://nagornyy.me/it/vizualizatsiia-dannykh-v-seaborn/'>этой</a> статье для чаевых по дням недели. Также сгруппировать по категориям этажа — первый, последний, другой. Вообще статья полезная, сам по ней начинал знакомство с Seaborn 🙂
# </div>

# %% [markdown]
# #### Дата размещения

# %% [markdown]
# ##### День недели

# %%
sns.catplot(x='weekday', y='last_price', data=df_filtered, height=6, aspect=1.5, order=day_order)

plt.title('График разброса стоимости квартиры в зависимости от дня недели', fontsize=16, pad=20)
plt.xlabel('День недели', fontsize=14)
plt.ylabel('Стоимость квартиры', fontsize=14);

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Сперва не получалось увеличить размеры графика и он выглядел нерепрезентативно. Теперь не получается убрать второй пустой график.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
#         <b>Совет💡:</b> Тебе не нужны <code>subplots</code> здесь, проблема отсюда, используй аргумент <code>height</code> функции <code>catplot</code>, <a href='https://drawingfromdata.com/pandas/seaborn/matplotlib/visualization/setting-figure-size-matplotlib-seaborn.html'>статья по теме</a>, там есть твой случай.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Благодарю! Поправил размеры графика, расположил столбцы в порядке дней недели.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Красота. Можно ещё похожий график сделать с усатыми ящиками по дням недели.
# </div>

# %%
df_filtered.groupby(by='weekday')['last_price'].describe()
# Out:
#             count          mean           std       min        25%        50%  \
# weekday
# Friday     2995.0  5.254679e+06  3.343515e+06  450000.0  3350000.0  4360000.0
# Monday     2524.0  5.176962e+06  3.165772e+06  450000.0  3346750.0  4399153.5
# Saturday   1418.0  5.213048e+06  3.398191e+06  550000.0  3300000.0  4492500.0
# Sunday     1252.0  5.095065e+06  3.238334e+06  470000.0  3300000.0  4345500.0
# Thursday   3086.0  5.257620e+06  3.315652e+06  450000.0  3350000.0  4400000.0
# Tuesday    3014.0  5.278167e+06  3.287776e+06  430000.0  3350000.0  4450000.0
# Wednesday  2799.0  5.229836e+06  3.371529e+06   12190.0  3300000.0  4400000.0
#
#                   75%         max
# weekday
# Friday     6200000.00  34000000.0
# Monday     5990000.00  31750000.0
# Saturday   6200000.00  35000000.0
# Sunday     5872750.00  36000000.0
# Thursday   6200000.00  35107000.0
# Tuesday    6140519.75  35000000.0
# Wednesday  6100000.00  36000000.0

# %% [markdown]
# Визуально и согласно таблице значительных отличий не наблюдается.
#
# Таким образом, день недели размещения объявления не оказывает влияния на стоимость продажи.

# %% [markdown]
# ##### Месяц

# %%
sns.catplot(x='month', y='last_price', data=df_filtered, height=8, aspect=1.5, order=month_order)

plt.title('График разброса стоимости квартиры в зависимости от месяца', fontsize=16, pad=20)
plt.xlabel('Месяц', fontsize=14)
plt.ylabel('Стоимость квартиры', fontsize=14);

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Аналогично, появился второй пустой график.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Совет смотри выше.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Исправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Оформление исправлено
# </div>

# %%
df_filtered.groupby(by='month')['last_price'].describe()
# Out:
#             count          mean           std       min        25%        50%  \
# month
# April      1236.0  5.225059e+06  3.144393e+06  550000.0  3350000.0  4470000.0
# August     1384.0  5.322485e+06  3.401640e+06  450000.0  3385000.0  4500000.0
# December   1166.0  5.092126e+06  3.194549e+06  490000.0  3200000.0  4385000.0
# February   1955.0  5.200812e+06  3.337489e+06  450000.0  3300000.0  4400000.0
# January    1073.0  5.244262e+06  3.484146e+06  480000.0  3350000.0  4400000.0
# July       1313.0  5.189535e+06  3.096778e+06  440000.0  3400000.0  4400000.0
# June       1370.0  5.238171e+06  3.814377e+06  430000.0  3250000.0  4245000.0
# March      1617.0  5.154938e+06  3.169732e+06   12190.0  3300000.0  4350000.0
# May         904.0  5.293610e+06  3.391029e+06  600000.0  3400000.0  4400000.0
# November   1838.0  5.291508e+06  3.265536e+06  560000.0  3400000.0  4500000.0
# October    1654.0  5.082841e+06  2.976876e+06  600000.0  3400000.0  4362500.0
# ...

# %% [markdown]
# В целом существенных отличий между месяцами не наблюдается. Только в марте было выставлено на продажу жильё со значительно более низкой ценой, а также в октябре, сентябре и июле максимальная стоимость жилья была ниже. В октябре наблюдался наименьший разброс стоимости жилья, а в мае было выставлено меньше всего позиций. В остальных случаях основные статистики менялись не так значительно.
#
# Таким образом, месяц размещения объявления не оказывает влияния на стоимость продажи.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Согласен, вывод подкреплён наблюдениями.
# </div>

# %% [markdown]
# ##### Год

# %%
step = 1
xticks = np.arange(df_filtered['year'].min(), df_filtered['year'].max() + step, step)

df_filtered.plot(kind='scatter', x='year', y='last_price', figsize=(15, 5), xticks=xticks)

plt.title('График разброса стоимости квартиры в зависимости от года', fontsize=16, pad=20)
plt.xlabel('День недели', fontsize=14)
plt.ylabel('Стоимость квартиры', fontsize=14);

# %%
df_filtered.groupby(by='year')['last_price'].describe()
# Out:
#        count          mean           std        min        25%        50%  \
# year
# 2015   239.0  5.423497e+06  2.904414e+06  1200000.0  3700000.0  4900000.0
# 2016  1695.0  5.429644e+06  3.716657e+06   600000.0  3350000.0  4400000.0
# 2017  6754.0  5.220089e+06  3.311923e+06   450000.0  3300000.0  4300000.0
# 2018  7341.0  5.168803e+06  3.268709e+06   430000.0  3300000.0  4400000.0
# 2019  1059.0  5.332512e+06  2.842587e+06    12190.0  3610000.0  4700000.0
#
#             75%         max
# year
# 2015  6312500.0  25398000.0
# 2016  6400000.0  35107000.0
# 2017  6078750.0  35900000.0
# 2018  6000000.0  36000000.0
# 2019  6365000.0  29000000.0

# %% [markdown]
# Визуально может показаться, что стоимости продаж значительно отличаются по годам. Например, что в 2015 продавалось более дешёвое жильё. Основные статистики подтверждают, что максимальная стоимость продаж действительно отличается. Значения квартилей показывают минимальные отличии внутри интерквартильного интервала для 2016, 2017 и 2018 годов, только в 2016 года третья квартиль заметно выше. В 2015 и 2019 года основные статистики отличаются от аналогичных показателей упомянутых ранее годов. Здесь и медианы, и квартили имеют более высокие значения. Также стоит добавить, что значения 2015 года крайне малочисленны, а за 2019 год представлены данные только за первые три месяца.
#
# Таким образом, год размещения объявления оказывает влияния на стоимость продажи.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
# <hr>
# <b>Обрати внимание🤔:</b> Относительная разница медиан по годам может достигать около 10 процентов (даже чуть больше), это заметная разница на промежутке одного года.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Понял.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Класс!
# </div>

# %% [markdown]
# #### Выводы

# %% [markdown]
# Наибольшее влияние на стоимость жилья оказывает площадь. Здесь наблюдается практически прямая линейная зависимость с коэффициентом корреляции ~0.73: чем больше площадь, тем выше цена.
#
# Число комнат, удалённость от центра и этаж также оказывают влияние на стоимость, но уже менее выраженную.
#
# Так например квартиры-студии с числом комнат 0 находятся в наиболее доступном ценовом сегменте. Диапазон стоимости однокомнатных квартир уже гораздо шире, а двухкомнатные и более квартиры встречаются во всех ценовых сегментах. Здесь также стоит учитывать, что с ростом числа комнат увеличивается и площадь квартиры, что оказывает более существенное влияние на стоимость.
#
# Удалённость от центра выражена другой тенденцией: дорогое жильё встречается только близко к центру, но при этом все ценовые категории также встречаются близко к центру. С увеличением расстояния от центра верхняя граница разброса цен снижается, то в среднем квартиры становятся дешевле.
#
# Строгой зависимости от номера этажа нет, но есть зависимость от расположения на первом или последнем этажах: там дорогое и средней ценовой категории жильё встречается реже. Доступное жильё встречается часто везде.
#
# Какой-либо явной зависимости стоимости жилья от дня недели, месяца начала торгов не было выявлено. Значения цен имеют схожие распределения вне зависимости от значения других признаков. Однако количество объектов в разных группах отличались, то есть продажи были неравномерны в течение всего года, дней недели и рассматриваемых лет. Лишь в зависимости от года основные статистики стоимости жилья менялись: в 2015 и 2019 года все показатели были выше, чем в 2016, 2017, 2018 года.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Отличный вывод.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
# <hr>
# <b>Обрати внимание🤔:</b>  Но обрати внимание на комментарий о зависимости стоимости по годам.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Провёл более детальный анализ зависимости стоимости жилья от года размещения объявления и исправил вывод.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Получился очень интересный анализ.
# </div>

# %% [markdown]
# ### 10 населённых пунктов с наибольшим числом объявлений

# %% [markdown]
# Определим 10 населённых пунктов с наибольшим числов объявлений.

# %%
locality_top_10 = df_filtered['locality_name'].value_counts().head(10)

locality_top_10
# Out:
# Санкт-Петербург    11215
# Мурино               493
# Кудрово              391
# Шушары               363
# Всеволожск           285
# Колпино              274
# Парголово            262
# Пушкин               256
# Гатчина              221
# Выборг               178
# Name: locality_name, dtype: int64

# %% [markdown]
# Рассчитаем среднюю стоимость квадратного метра.

# %%
(
    df_filtered
    .loc[df_filtered['locality_name'].isin(locality_top_10.index)]
    .groupby(by='locality_name')['square_price']
    .describe()
    .reset_index()
    .sort_values(by='mean', ascending=False)
)
# Out:
#      locality_name    count           mean           std      min       25%  \
# 8  Санкт-Петербург  11215.0  108463.287205  30532.389342    111.0  90000.00
# 7           Пушкин    256.0  101607.230469  21282.460856  59836.0  89120.75
# 4          Кудрово    391.0   94639.800512  12942.241359  54160.0  85437.50
# 6        Парголово    262.0   89080.629771  16804.181945  48405.0  78484.25
# 5           Мурино    493.0   86074.056795  14467.501173  50000.0  76650.00
# 9           Шушары    363.0   78290.931129  14254.704661  47833.0  68211.50
# 3          Колпино    274.0   74503.766423  12253.043176  47957.0  65763.25
# 0       Всеволожск    285.0   69217.515789  36183.579962  31400.0  58704.00
# 2          Гатчина    221.0   68209.366516  13674.333201  10507.0  60169.00
# 1           Выборг    178.0   57258.764045  11448.955822  18750.0  49860.50
#
#         50%        75%       max
# 8  102555.0  119808.00  600000.0
# 7   97725.5  108074.25  256521.0
# ...

# %% [markdown]
# Самая высокая стоимость жилья, ожидаемо, в Санкт-Петербурге. В среднем квадратный метр стоит здесь около 108 с половиной тысяч рублей. Интерквартильный размах находится в пределах 90 тысяч и чуть менее 120 тысяч, что говорит о высокой стоимости квадратного метра центральной выборки квартир. При этом здесь же и наблюдается наибольшее стандартное отклонение, закономерно. При этом стоит заметить, что данная группа самая многочисленная и занимает около половины всей выборки объявлений.
#
# Самая дешёвая удельная стоимость жилья в Выборге. Квадратный метр в среднем стоит чуть более 57 тысяч, что почти в два раза ниже аналогичного показателя лидера. Границы интерквартильного размаха также почти в два раза ниже, а стандартное отклонение - почти в три раза ниже, то есть цены здесь более равномерны. Рассматриваемая группа значительно меньше, менее 1% от всей выборки.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
#     <b>Верно!👍:</b> Блестяще, молодец, что используешь здесь метод <code>describe</code>
# </div>

# %% [markdown]
# ### Квартиры в Санкт-Петербурге

# %% [markdown]
# Создадим новую таблицу-срез с квартирами из Санкт-Петербурга.

# %%
df_spb = df_filtered.query('locality_name == "Санкт-Петербург"').copy()

df_spb.head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 4              2    10000000       100.0           2018-06-19      2
# 9             18     5400000        61.0           2017-02-26      3
# 10             5     5050000        39.6           2017-11-16      1
# 15            16     4650000        39.0           2017-11-18      1
# 18             8     3250000        31.0           2017-01-27      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 4             3.03          14.0         32.0     13         False  ...
# 9             2.50           9.0         43.6      7         False  ...
# 10            2.67          12.0         20.3      3         False  ...
# 15            2.65          14.0         20.5      5         False  ...
# 18            2.50           5.0         19.4      2         False  ...
#
#     ponds_nearest  days_exposition  locality_type  square_price   weekday  \
# ...

# %% [markdown]
# Генерация нового признака "расстояние до центра в цилометрах".

# %%
df_spb['city_centers_nearest_km'] = (df_spb['city_centers_nearest'] / 1000).astype(int)

df_spb[['city_centers_nearest', 'city_centers_nearest_km']].head()
# Out:
#     city_centers_nearest  city_centers_nearest_km
# 4                 8098.0                        8
# 9                15008.0                       15
# 10               13878.0                       13
# 15               14259.0                       14
# 18               10842.0                       10

# %% [markdown]
# Расчёт средней стоимости квадратного метра в зависимости от километра.

# %%
df_spb_km = (
    df_spb
    .groupby(by='city_centers_nearest_km')['square_price']
    .describe()
    .reset_index()
)

df_spb_km.head(10)
# Out:
#    city_centers_nearest_km  count           mean           std      min  \
# 0                        0   45.0  129461.533333  41237.946906  68000.0
# 1                        1  113.0  138472.097345  54435.079081  72392.0
# 2                        2  167.0  122571.658683  38884.819473  62126.0
# 3                        3  288.0  116871.031250  36445.067340  63524.0
# 4                        4  500.0  132787.434000  49412.226463  15861.0
# 5                        5  440.0  131069.277273  44591.846026  15345.0
# 6                        6  289.0  131014.737024  48329.199237  37234.0
# 7                        7  271.0  128585.221402  42313.325587  41911.0
# 8                        8  460.0  116728.028261  38178.186759  64983.0
# 9                        9  525.0  108199.085714  26139.617203    111.0
#
#          25%       50%       75%       max
# 0  101639.00  116263.0  157597.0  239583.0
# 1  102727.00  123529.0  154516.0  387096.0
# 2   95864.50  116119.0  134435.0  285714.0
# ...

# %% [markdown]
# Построим график зависимости средней стоимости квадратного метра от удалённости от центра.

# %%
step = 1
xticks = range(df_spb_km['city_centers_nearest_km'].min(), df_spb_km['city_centers_nearest_km'].max() + step, step)

df_spb_km.plot(x='city_centers_nearest_km', y='mean', figsize=(15, 5), grid=True, xticks=xticks)

plt.title('График зависимости стоимости недвижимости от удалённости от центра', fontsize=16)
plt.xlabel('Расстояние от центра в километрах', fontsize=14)
plt.ylabel('Средняя стоимость квадратного метра', fontsize=14);

# %% [markdown]
# Хоть на графике и наблюдается основная тенденция снижения стоимости квадратного метра с увеличением расстояние от центра, но также присутствуют скачки. В 2 и 3 километрах от центра наблюдается снижение цены, а в 20 и особенно 27 километрах - скачки вверх.
#
# Визуально можно заметить, что квартиры до 7 километров включительно имеют более высокую стоимость квадратного метра. Их примем за центр города.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
#     <b>Верно!👍:</b> Удачное решение использовать метод <code>describe</code> для сгруппированной по расстояниям от центра таблице.
#     С выводами согласен, после отметки в 7 км наклон кривой заметно меняется — квартиры дешевеют стремительнее с ростом расстояния, похоже, что здесь заканчивается центр.
# </div>

# %% [markdown]
# ### Квартиры в центре Санкт-Петербурга

# %% [markdown]
# Рассмотрим квартиры в центре Санкт-Петербурга.

# %%
list_features = ['last_price', 'total_area', 'rooms', 'ceiling_height', 'floor', 'floor_type', 'city_centers_nearest',
                 'first_day_exposition']

# %%
df_spb.query('city_centers_nearest_km <= 7')[list_features].describe()
# Out:
#          last_price   total_area        rooms  ceiling_height        floor  \
# count  2.113000e+03  2113.000000  2113.000000     2113.000000  2113.000000
# mean   9.100856e+06    70.859082     2.403691        2.872901     4.258874
# std    5.085358e+06    26.285589     1.039616        0.329726     3.110451
# min    1.600000e+06    12.000000     0.000000        2.400000     1.000000
# 25%    5.900000e+06    50.000000     2.000000        2.650000     2.000000
# 50%    7.750000e+06    68.000000     2.000000        2.700000     4.000000
# 75%    1.080000e+07    88.700000     3.000000        3.000000     5.000000
# max    3.600000e+07   140.000000     7.000000        5.800000    23.000000
#
#        city_centers_nearest
# count           2113.000000
# mean            4823.699006
# std             1759.324039
# min              208.000000
# 25%             3723.000000
# 50%             4870.000000
# 75%             6055.000000
# max             7998.000000

# %% [markdown]
# Сравним с общими данными.

# %%
df_filtered[list_features].describe()
# Out:
#          last_price    total_area         rooms  ceiling_height         floor  \
# count  1.708800e+04  17088.000000  17088.000000    17088.000000  17088.000000
# mean   5.228655e+06     54.108406      1.925211        2.676128      6.069113
# std    3.304356e+06     20.598024      0.915344        0.184617      4.978689
# min    1.219000e+04     12.000000      0.000000        2.000000      1.000000
# 25%    3.350000e+06     39.000000      1.000000        2.600000      2.000000
# 50%    4.400000e+06     49.000000      2.000000        2.650000      5.000000
# 75%    6.100000e+06     64.485000      3.000000        2.700000      8.000000
# max    3.600000e+07    140.000000      7.000000        5.800000     33.000000
#
#        city_centers_nearest
# count          13643.000000
# mean           14979.379352
# std             8350.172548
# min              208.000000
# 25%            10562.000000
# 50%            13673.000000
# 75%            16995.000000
# max            64857.000000

# %% [markdown]
# **Отличие квартир в центре Санкт-Петербурга от всех квартир:**
# - средняя и медианные стоимости продажи почти в два раза выше;
# - средняя и медианные площади почти в полтора раза выше;
# - среднее количество комнат больше, преобладают двухкомнатные квартиры;
# - высота потолков выше в среднем на 20 сантиметров;
# - в среднем квартиры в центре расположены на этаж ниже, чем в квартиры в общем.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b>Всё верно, занятные последние два наблюдения 🙂
# </div>

# %%
df_spb.query('city_centers_nearest_km <= 7')['floor_type'].value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# other    71.08%
# last     16.75%
# first    12.16%
# Name: floor_type, dtype: object

# %%
df_filtered['floor_type'].value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# other    74.99%
# last     13.37%
# first    11.64%
# Name: floor_type, dtype: object

# %% [markdown]
# Распределение по этажам примерно одинаково, в Санкт-Петербурге продаётся чуть больше квартир на последнем этаже и чуть меньше на этажах, не являющихся крайними.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Можно отметить, что в центре Питера продаётся меньше недвижимости на этажах, не являющихся крайними.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Сделано, заметил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Интересно, является ли такая разница статистически важной? В т.ч. об этом будет следующий спринт.
# </div>

# %%
df_spb.query('city_centers_nearest_km <= 7')['first_day_exposition'].value_counts().head(10)
# Out:
# 2018-02-01    37
# 2017-11-10    31
# 2017-06-29    18
# 2018-07-10    16
# 2018-03-15    16
# 2017-09-27    15
# 2017-09-26    15
# 2017-10-13    11
# 2017-08-08    11
# 2017-09-25    11
# Name: first_day_exposition, dtype: int64

# %%
df_filtered['first_day_exposition'].value_counts().head(10)
# Out:
# 2018-02-01    330
# 2017-11-10    219
# 2017-10-13    109
# 2017-09-27     93
# 2018-07-10     88
# 2018-03-26     74
# 2018-03-06     66
# 2018-03-23     63
# 2017-09-28     63
# 2017-09-26     62
# Name: first_day_exposition, dtype: int64

# %% [markdown]
# Временные рамки продажи квартир в целом похожи.

# %%
list_features = ['last_price', 'total_area', 'rooms', 'ceiling_height', 'floor', 'city_centers_nearest']

pd.plotting.scatter_matrix(df_spb.query('city_centers_nearest_km <= 7')[list_features], figsize=(15, 15))

# plt.title('Матрица графиков разброса основных характеристик квартир в Санкт-Петербурге', fontsize=16);
print("\033[1m" + 'Матрица графиков разброса основных характеристик квартир в Санкт-Петербурге' + "\033[0m")
# Out:
# Матрица графиков разброса основных характеристик квартир в Санкт-Петербурге

# %% [markdown]
# Наиболее заметное влияние на стоимость жилья в центре Санкт-Петербурга оказывает размер площади. Затем идёт количество комнат, которое косвенно связано с площадью.
#
# Также рассмотрим матрицу корреляций основных характеристик данных квартир.

# %%
sns.set(rc = {'figure.figsize':(15, 8)})

corr_matrix = df_spb.query('city_centers_nearest_km <= 7')[list_features].corr()
corr_matrix = corr_matrix.mask(corr_matrix < 0.2, 0)

sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, linewidths=0.5)

plt.title('Матрица корреляций основных характеристик квартир в Санкт-Петербурге', fontsize=16);

# %% [markdown]
# Как было замечено ранее, стоимость недвижимости имеет довольно сильную корреляцию от общей площади. Коэффициент корреляции ~0.67, что довольно близки к линейной зависимости.
#
# Также наблюдается сильная зависимость, практически линейная, количества комнат от общей площади, коэффициент корреляции ~0.77. Это значит, что количество комнат также оказывает влияние на стоимость квартир, хоть и менее явную, коэффициент корреляции ~0.36.

# %% [markdown]
# ### Выводы

# %% [markdown]
# Результаты исследовательского анализа данных:
# - изучены основные параметры квартир и их влияние на стоимость;
# - определены аномальные значения, наличие которых может исказить характеристики данных, создан отфильтрованный набор данных;
# - выделены и рассмотрены десять наиболее распространённых населённых пунктов;
# - также отдельно рассмотрены предложения в Санкт-Петербурге и центре Санкт-Петербурга.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Совет💡:</b> Всё верно, тут можно добавить пару слов о характере выявленных зависимостей, а также оценить к-ты корреляции для центра Питера.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Добавил матрицу корреляций, описал обнаруженные зависимости.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Здорово!
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Первое изучение данных показало наличие пропусков и аномалий, что затрудняло качественный анализ данных.
#
# Для заполнения пропусков были использованы следующие подходы:
# - заполнение медианными значениями с группировкой по общим признакам. Данный подход был справедлив для данных, имеющих природу происхождения на основе автоматического анализа карт;
# - заполнение вычислением средних пропорций. Такой подход был применён для получения жилой площади и площади кухни от всей площади;
# - интерпретация пропусков как информация была применена для характеристик балконов и принадлежности жилья к апартаментам;
# - один из признаков, высота потолков, был заполнен медианными значениями для минимизации ошибки предположения. То есть, были использованы наиболее типичные значения, отличия от которых в действительности наименее вероятны;
# - пропуски некоторых признаков не были заполнены, так как это было некорректно с точки зрения предположения или наличие пропусков было информативно. Такие пропуски были оставлены нетронутыми для названия населённого пункта и количества этажей в здании, а также для географических признаков, где населённый пункт был неизвестен.
#
# Для исправления аномалий были использованы два метода:
# - исправление значений на основе предположения, что была допущена ошибка. Например, для высоты потолков более 20 метров значения были разделены на 10 из предположения, что был дописан лишний 0 в конце;
# - часть объектов с аномальными значениями была исключена из дальнейшего рассмотрения, так как доподлинно установить достоверность информации было невозможно, а присутствие данных объектов могло исказить данные. Например, при изучении факторов, влияющих на стоимость жилья, не рассматривались квартиры с аномально большими ценами и площадями жилья.
#
# Для удобства выполнения анализа были преобразованы типы данных и сгенерированы новые признаки:
# - дата размещения объявления была переведена в тип datetime, также отдельно были сформированы признаки день недели, месяц и год публикации;
# - был определён тип этажа квартиры, первый, последний или иной;
# - были вычислены стоимость квадратного метра, доля жилой площади и площади кухни.
#
# Предобработка данных позволила выполнить исследовательский анализ данных в результате чего стали известны следующие зависимости и особенности:
# - были рассмотрены основные характеристики жилья и установлены наиболее важные для формирования стоимости. Наибольшее влияние оказывает площадь жилья, наблюдается практически прямая линейная зависимость. Далее идёт количество комнат, однако этот признак косвенно связан с площадью жилья. Удалённость от центра и этаж квартиры также оказывают влиянии, но уже менее выраженное. Наиболее дорогое жильё встречается в центре города и не на первых и не последних этажах. Зависимости стоимости от дня недели и месяца размещения объявления не были выявлены, однако было обнаружено влияние года публикации;
# - при рассмотрении десяти населённых пунктов с наибольшим числом объявлений была выявлена зависимость стоимости квадратного метра от населённого пункта. Самая дорогая недвижимость, ожидаемо, находится в Санкт-Петербурге - в среднем около 102.5 тысяч за квадратный метр. Самая дешёвая из десяти в Выборге - около 57 тысяч за квадратный метр. Также было установлено, что в Санкт-Петербурге продаётся почти половина всей недвижимости из набора данных;
# - был выявлен наиболее дорогой сегмент квартир в центре Санкт-Петербурга, менее 7 километров от центра. Данные квартиры отличаются не только стоимостью и удалённостью, но и в целом имеют большую квадратуру, как следствие, число комнат, более высокие потолки, чем остальные квартиры во всех объявлениях.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> Отличное завершение проекта — резюме об особенностях данных и проделанной работе, связанной с этими особенностями и сами результаты исследований.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
# <hr>
# <b>Обрати внимание🤔:</b>  Когда поправишь зависимость цен по годам, не забудь поправить итоговый вывод.
# </div></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Указал, что год публикации также оказывает влияние на стоимость недвижимости.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
# <hr>
# <b>Верно!👍:</b> С радостью принимаю работу, ты большой молодец. Учти, что критичные не все замечания, если будут гореть дедлайны, то можно не уделять внимание неблокирующим комментариям. Удачи в дальнейшей учёбе :)
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
