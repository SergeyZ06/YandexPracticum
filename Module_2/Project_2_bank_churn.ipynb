# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера</b>
#
#
# Привет, Сергей! Давай знакомиться! Меня зовут Дмитрий Махортов, и я буду проверять твой проект. Сразу предлагаю общение на «ты» 🙂, но если тебе это не комфортно, то дай знать, и мы перейдем на «вы».
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе погрузиться в увлекательный мир работы с данными и вырасти в крепкого профи. Это отдаленная цель. А ближайшая - сделать твою работу еще лучше )).
#
#
# Все ключевые этапы в работе выполнены, и я вижу что с проектом ты справшяешься. Есть моменты, которые нужно доработать, но я уверен, у тебя все получится.
#
# Есть несколько аспектов, которые потребуют твоего внимания. Комментарии по ним выделены <span style='background-color:#F7B3A4'> красным цветом </span> и обозначены значком 🛑. После их доработки проект будет принят. Осталось совсем немного, буду ждать твою работу на повторное ревью 🙂
#
#
# <span style='background-color:#B7EBA7'> Зеленым цветом </span> и значком ✅ отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. Или советы «со звездочкой», которые помогут тебе в будущем.
#
# <span style='background-color:#F9EDA6'>Жёлтым цветом </span> и значком ⚠️ выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Здравствуйте!
# <br>Постарался исправить все замечания и воспользоваться всеми советами, интересно, спасибо!
# <br>Также у меня были мысли о более углублённом изучении модели. Например, выполнения прогноза методом <code>predict_proba()</code> и подбора наилучшего порога. В конечном итоге решил не переусложнять проект и соблюсти баланс объёма и удобства восприятия для читателя.
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера</b>
#
# Согласен, нужен баланс между сложностью и удобством восприятия.
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-к-выполнению-проекта" data-toc-modified-id="Подготовка-к-выполнению-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка к выполнению проекта</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импорт библиотек</a></span></li><li><span><a href="#Глобальные-настройки" data-toc-modified-id="Глобальные-настройки-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Глобальные настройки</a></span></li><li><span><a href="#Импорт-данных" data-toc-modified-id="Импорт-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Импорт данных</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Исследование-данных" data-toc-modified-id="Исследование-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование данных</a></span><ul class="toc-item"><li><span><a href="#Общая-оценка-данных" data-toc-modified-id="Общая-оценка-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Общая оценка данных</a></span></li><li><span><a href="#Исследование-признака-&quot;Geography&quot;" data-toc-modified-id="Исследование-признака-&quot;Geography&quot;-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Исследование признака "Geography"</a></span></li><li><span><a href="#Исследование-признака-&quot;Gender&quot;" data-toc-modified-id="Исследование-признака-&quot;Gender&quot;-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследование признака "Gender"</a></span></li><li><span><a href="#Исследование-признака-&quot;Tenure&quot;" data-toc-modified-id="Исследование-признака-&quot;Tenure&quot;-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Исследование признака "Tenure"</a></span></li><li><span><a href="#Исследование-признака-&quot;NumOfProducts&quot;" data-toc-modified-id="Исследование-признака-&quot;NumOfProducts&quot;-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Исследование признака "NumOfProducts"</a></span></li><li><span><a href="#Исследование-признака-&quot;HasCrCard&quot;" data-toc-modified-id="Исследование-признака-&quot;HasCrCard&quot;-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Исследование признака "HasCrCard"</a></span></li><li><span><a href="#Исследование-признака-&quot;IsActiveMember&quot;" data-toc-modified-id="Исследование-признака-&quot;IsActiveMember&quot;-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Исследование признака "IsActiveMember"</a></span></li><li><span><a href="#Исследование-целевой-переменной-&quot;Exited&quot;" data-toc-modified-id="Исследование-целевой-переменной-&quot;Exited&quot;-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Исследование целевой переменной "Exited"</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Стратегия-подготовки-данных" data-toc-modified-id="Стратегия-подготовки-данных-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Стратегия подготовки данных</a></span><ul class="toc-item"><li><span><a href="#Определение-признаков-и-целевой-переменной" data-toc-modified-id="Определение-признаков-и-целевой-переменной-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Определение признаков и целевой переменной</a></span></li><li><span><a href="#Разбиение-данных" data-toc-modified-id="Разбиение-данных-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Разбиение данных</a></span></li><li><span><a href="#Стандартизация-данных" data-toc-modified-id="Стандартизация-данных-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Стандартизация данных</a></span></li><li><span><a href="#Кодирование-признаков" data-toc-modified-id="Кодирование-признаков-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Кодирование признаков</a></span></li></ul></li><li><span><a href="#Стратегия-1" data-toc-modified-id="Стратегия-1-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Стратегия 1</a></span><ul class="toc-item"><li><span><a href="#Заполнение-пропусков-признака-&quot;Tenure&quot;" data-toc-modified-id="Заполнение-пропусков-признака-&quot;Tenure&quot;-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Заполнение пропусков признака "Tenure"</a></span></li><li><span><a href="#Стандартизация-признака-&quot;Tenure&quot;" data-toc-modified-id="Стандартизация-признака-&quot;Tenure&quot;-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Стандартизация признака "Tenure"</a></span></li><li><span><a href="#Проверка" data-toc-modified-id="Проверка-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Проверка</a></span></li></ul></li><li><span><a href="#Стратегия-2" data-toc-modified-id="Стратегия-2-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Стратегия 2</a></span><ul class="toc-item"><li><span><a href="#Кодирование-признака-&quot;Tenure&quot;" data-toc-modified-id="Кодирование-признака-&quot;Tenure&quot;-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Кодирование признака "Tenure"</a></span></li><li><span><a href="#Обработка-dummy-ловушки" data-toc-modified-id="Обработка-dummy-ловушки-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Обработка dummy-ловушки</a></span></li><li><span><a href="#Проверка" data-toc-modified-id="Проверка-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Проверка</a></span></li></ul></li><li><span><a href="#Стратегия-3" data-toc-modified-id="Стратегия-3-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Стратегия 3</a></span><ul class="toc-item"><li><span><a href="#Кодирование-признака-&quot;Tenure&quot;" data-toc-modified-id="Кодирование-признака-&quot;Tenure&quot;-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Кодирование признака "Tenure"</a></span></li><li><span><a href="#Проверка" data-toc-modified-id="Проверка-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Проверка</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span><ul class="toc-item"><li><span><a href="#Проверка-модели-на-первом-наборе-данных" data-toc-modified-id="Проверка-модели-на-первом-наборе-данных-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Проверка модели на первом наборе данных</a></span></li><li><span><a href="#Проверка-модели-на-втором-наборе-данных" data-toc-modified-id="Проверка-модели-на-втором-наборе-данных-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Проверка модели на втором наборе данных</a></span></li><li><span><a href="#Проверка-модели-на-третьем-наборе-данных" data-toc-modified-id="Проверка-модели-на-третьем-наборе-данных-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Проверка модели на третьем наборе данных</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Дерево решений</a></span><ul class="toc-item"><li><span><a href="#Проверка-модели-на-первом-наборе-данных" data-toc-modified-id="Проверка-модели-на-первом-наборе-данных-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Проверка модели на первом наборе данных</a></span></li><li><span><a href="#Проверка-модели-на-втором-наборе-данных" data-toc-modified-id="Проверка-модели-на-втором-наборе-данных-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Проверка модели на втором наборе данных</a></span></li><li><span><a href="#Проверка-модели-на-третьем-наборе-данных" data-toc-modified-id="Проверка-модели-на-третьем-наборе-данных-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Проверка модели на третьем наборе данных</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Случайный лес</a></span><ul class="toc-item"><li><span><a href="#Проверка-модели-на-первом-наборе-данных" data-toc-modified-id="Проверка-модели-на-первом-наборе-данных-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Проверка модели на первом наборе данных</a></span></li><li><span><a href="#Проверка-модели-на-втором-наборе-данных" data-toc-modified-id="Проверка-модели-на-втором-наборе-данных-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Проверка модели на втором наборе данных</a></span></li><li><span><a href="#Проверка-модели-на-третьем-наборе-данных" data-toc-modified-id="Проверка-модели-на-третьем-наборе-данных-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Проверка модели на третьем наборе данных</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Выбор-модели-и-набора-данных" data-toc-modified-id="Выбор-модели-и-набора-данных-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Выбор модели и набора данных</a></span></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Настройка-весов-моделей" data-toc-modified-id="Настройка-весов-моделей-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Настройка весов моделей</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Техника-&quot;upsampling&quot;" data-toc-modified-id="Техника-&quot;upsampling&quot;-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Техника "upsampling"</a></span><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-5.2.4"><span class="toc-item-num">5.2.4&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Техника-&quot;downsampling&quot;" data-toc-modified-id="Техника-&quot;downsampling&quot;-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Техника "downsampling"</a></span><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-5.3.4"><span class="toc-item-num">5.3.4&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Финальная-настройка-и-тестирование-модели" data-toc-modified-id="Финальная-настройка-и-тестирование-модели-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Финальная настройка и тестирование модели</a></span><ul class="toc-item"><li><span><a href="#Оценка-модели" data-toc-modified-id="Оценка-модели-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Оценка модели</a></span><ul class="toc-item"><li><span><a href="#Обучение-базовой-модели" data-toc-modified-id="Обучение-базовой-модели-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Обучение базовой модели</a></span></li><li><span><a href="#Оценка-метрик-качества" data-toc-modified-id="Оценка-метрик-качества-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Оценка метрик качества</a></span></li><li><span><a href="#Анализ-метрик-качества" data-toc-modified-id="Анализ-метрик-качества-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>Анализ метрик качества</a></span></li></ul></li><li><span><a href="#Настройка-модели" data-toc-modified-id="Настройка-модели-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Настройка модели</a></span><ul class="toc-item"><li><span><a href="#Подбор-гиперпараметров" data-toc-modified-id="Подбор-гиперпараметров-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Подбор гиперпараметров</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Финальная-оценка-модели" data-toc-modified-id="Финальная-оценка-модели-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Финальная оценка модели</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Вам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Постройте модель с предельно большим значением *F1*-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59. Проверьте *F1*-меру на тестовой выборке самостоятельно.
#
# Дополнительно измеряйте *AUC-ROC*, сравнивайте её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# ## Подготовка к выполнению проекта

# %% [markdown]
# ### Импорт библиотек

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

from sklearn.impute import SimpleImputer

from sklearn.linear_model import LogisticRegression

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score

from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, все нужные библиотеки импортированы в начале ноутбука.Это хорошая практика.</div>

# %% [markdown]
# ### Глобальные настройки

# %%
random_state_global = 0

# %% [markdown]
# ### Импорт данных

# %%
PATH_DATA = r'/datasets/Churn.csv'

# %% [markdown]
# ### Описание данных

# %% [markdown]
# **Признаки**
# - RowNumber — индекс строки в данных
# - CustomerId — уникальный идентификатор клиента
# - Surname — фамилия
# - CreditScore — кредитный рейтинг
# - Geography — страна проживания
# - Gender — пол
# - Age — возраст
# - Tenure — сколько лет человек является клиентом банка
# - Balance — баланс на счёте
# - NumOfProducts — количество продуктов банка, используемых клиентом
# - HasCrCard — наличие кредитной карты
# - IsActiveMember — активность клиента
# - EstimatedSalary — предполагаемая зарплата
#
# **Целевой признак**
# - Exited — факт ухода клиента

# %% [markdown]
# ## Исследование данных

# %% [markdown]
# ### Общая оценка данных

# %%
# Загрузка данных.
df_data = pd.read_csv(PATH_DATA)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 👍 Данные загружены </div>

# %%
# Вывод первых пяти строк таблицы для визуального анализа.
df_data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0   83807.86              1          0               1
# 2     8.0  159660.80              3          1               0
# 3     1.0       0.00              2          0               0
# 4     2.0  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
# Вывод основной информации о данных.
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
# Вывод основных статистик признаков.
df_data.describe(include='all').T
# Out:
#                    count unique     top  freq           mean           std  \
# RowNumber        10000.0    NaN     NaN   NaN         5000.5    2886.89568
# CustomerId       10000.0    NaN     NaN   NaN  15690940.5694  71936.186123
# Surname            10000   2932   Smith    32            NaN           NaN
# CreditScore      10000.0    NaN     NaN   NaN       650.5288     96.653299
# Geography          10000      3  France  5014            NaN           NaN
# Gender             10000      2    Male  5457            NaN           NaN
# Age              10000.0    NaN     NaN   NaN        38.9218     10.487806
# Tenure            9091.0    NaN     NaN   NaN        4.99769      2.894723
# Balance          10000.0    NaN     NaN   NaN   76485.889288  62397.405202
# NumOfProducts    10000.0    NaN     NaN   NaN         1.5302      0.581654
# HasCrCard        10000.0    NaN     NaN   NaN         0.7055       0.45584
# ...

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#
# Лучше отдельно вывести статистику для числовых колонок используя ```df.describe()```
# и в другой командой посмотреть статистику по категориальным с помощью ```df.describe(include=['O'])```
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Попробовал, интересно, спасибо.
# </div>

# %%
# Вывод основных статистик непрерывных переменных.
df_data.describe().T
# Out:
#                    count          mean           std          min  \
# RowNumber        10000.0  5.000500e+03   2886.895680         1.00
# CustomerId       10000.0  1.569094e+07  71936.186123  15565701.00
# CreditScore      10000.0  6.505288e+02     96.653299       350.00
# Age              10000.0  3.892180e+01     10.487806        18.00
# Tenure            9091.0  4.997690e+00      2.894723         0.00
# Balance          10000.0  7.648589e+04  62397.405202         0.00
# NumOfProducts    10000.0  1.530200e+00      0.581654         1.00
# HasCrCard        10000.0  7.055000e-01      0.455840         0.00
# IsActiveMember   10000.0  5.151000e-01      0.499797         0.00
# EstimatedSalary  10000.0  1.000902e+05  57510.492818        11.58
# Exited           10000.0  2.037000e-01      0.402769         0.00
#
#                          25%           50%           75%          max
# RowNumber            2500.75  5.000500e+03  7.500250e+03     10000.00
# ...

# %%
# Вывод основных статистик категориальных переменных.
df_data.describe(include='O').T
# Out:
#            count unique     top  freq
# Surname    10000   2932   Smith    32
# Geography  10000      3  France  5014
# Gender     10000      2    Male  5457

# %%
# Оценка долей пропусков в данных.
df_data.isna().mean().sort_values(ascending=False).apply('{:.2%}'.format)
# Out:
# Tenure             9.09%
# RowNumber          0.00%
# CustomerId         0.00%
# Surname            0.00%
# CreditScore        0.00%
# Geography          0.00%
# Gender             0.00%
# Age                0.00%
# Balance            0.00%
# NumOfProducts      0.00%
# HasCrCard          0.00%
# IsActiveMember     0.00%
# EstimatedSalary    0.00%
# Exited             0.00%
# dtype: object

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#
# Есть предварительное знакомство с даными, на очереди подробное.
#
# </div>

# %% [markdown]
# ### Исследование признака "Geography"

# %%
# Вывод уникальных значений признака "Geography".
df_data['Geography'].value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# France     50.14%
# Germany    25.09%
# Spain      24.77%
# Name: Geography, dtype: object

# %% [markdown]
# ### Исследование признака "Gender"

# %%
# Вывод уникальных значений признака "Gender".
df_data['Gender'].value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# Male      54.57%
# Female    45.43%
# Name: Gender, dtype: object

# %% [markdown]
# ### Исследование признака "Tenure"

# %%
# Вывод доли пропусков признака "Tenure".
print(f'Доля пропусков признака "Tenure":\t{(df_data["Tenure"].isna().mean()):.2%}')
# Out:
# Доля пропусков признака "Tenure":	9.09%

# %%
# Вывод уникальных значений признака "Tenure".
df_data['Tenure'].value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# 1.0     10.47%
# 2.0     10.45%
# 8.0     10.26%
# 3.0     10.21%
# 5.0     10.20%
# 7.0     10.17%
# 4.0      9.73%
# 9.0      9.70%
# 6.0      9.69%
# 10.0     4.91%
# 0.0      4.20%
# Name: Tenure, dtype: object

# %% [markdown]
# ### Исследование признака "NumOfProducts"

# %%
# Вывод уникальных значений признака "NumOfProducts".
df_data['NumOfProducts'].value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# 1    50.84%
# 2    45.90%
# 3     2.66%
# 4     0.60%
# Name: NumOfProducts, dtype: object

# %% [markdown]
# ### Исследование признака "HasCrCard"

# %%
# Вывод уникальных значений признака "HasCrCard".
df_data['HasCrCard'].value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# 1    70.55%
# 0    29.45%
# Name: HasCrCard, dtype: object

# %% [markdown]
# ### Исследование признака "IsActiveMember"

# %%
# Вывод уникальных значений признака "IsActiveMember".
df_data['IsActiveMember'].value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# 1    51.51%
# 0    48.49%
# Name: IsActiveMember, dtype: object

# %% [markdown]
# ### Исследование целевой переменной "Exited"

# %%
# Вывод уникальных значений целевой переменной "Exited".
df_data['Exited'].value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# 0    79.63%
# 1    20.37%
# Name: Exited, dtype: object

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Баланс классов исследован, но  можно дополнительно проиллюстрировать баланс классов с помощью графика (хорошо подойдет столбчатая диаграмма) или таблицы.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Сделал.
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>v2</b> 👍 </div>

# %%
# Визуализация распределения значений целевой переменной.
plt.figure(figsize=(10, 5))

df_data['Exited'].value_counts().plot(kind='bar')

plt.grid()

plt.title('Гистограмма значений целевой переменной', fontdict={'fontsize': 16})
plt.xlabel('Классы целевой переменной', fontdict={'fontsize': 14})
plt.ylabel('Количество объектов', fontdict={'fontsize': 14})

plt.xticks(rotation=0);

# %% [markdown]
# ### Выводы

# %% [markdown]
# Исследование данных позволило установить следующие особенности:
# - структура данных соответствует сопроводительной документации;
# - названия признаков не соответствуют стилю <code>snake_case</code>;
# - признаки <code>RowNumber</code>, <code>CustomerId</code>, <code>Surname</code> не являются информативными для прогноза целевой переменной, так как необходимо выявление общих тенденций, а не для конкретных пользователей;
# - признаки <code>CreditScore</code>, <code>Balance</code>, <code>EstimatedSalary</code> являются непрерывными и не содержат пропусков. Для лучшей работы линейных моделей данные признаки могут быть подвергнуты стандартизации;
# - признак <code>Age</code> может рассматриваться как непрерывный, также может быть переведён в категориальный;
# - признаки <code>Geography</code> и <code>Gender</code> являются категориальными и должны быть обработаны алгоритмами <code>OHE</code> или <code>OrdinalEncoder</code> для соответствующих моделей;
# - признак <code>Tenure</code> содержит около ~9% пропусков и может рассматриваться как непрерывный признак, так и как дискретный. В случае рассмотрения признака <code>Tenure</code> как непрерывной величины, его пропуски могут быть интерпретированы как отсутствие информации о пребывании клиента в банке и заполнены нулями. В случае категориальной интерпретации признака и кодировании <code>OrdinalEncoder</code> пропуски будут выражены нулевым вектором для новых признаков после разбиения <code>Tenure</code> на категории;
# - наблюдается существенный дисбаланс классов целевой переменной <code>Exited</code> в соотношении ~80:20.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 👍 Подробные выводы, очень хорошо</div>

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Стратегия подготовки данных

# %% [markdown]
# В ходе исследования данных было установлено, что для построения моделей возможны различные подходы к подготовке данных:
# 1. Признак <code>Tenure</code> может быть рассмотрен как непрерывный с заполнением пропусков нулями.
# 2. Признак <code>Tenure</code> может быть рассмотрен как категориальный с использованием кодирования <code>OHE</code>. Согласно теории текущего курса, следует применить параметр <code>drop='first'</code>.
# 3. Признак "Tenure" может быть рассмотрен как категориальный с использованием кодирования <code>OHE</code>. Без параметра <code>drop='first'</code>, так как дополнительные категории могут быть информативны. Например, линейная модель может вычислить различные веса значением <code>Male</code> и <code>Female</code> признака <code>Gender</code>.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 👍Ух...</div>

# %% [markdown]
# #### Определение признаков и целевой переменной

# %%
# Определение целевой переменной.
y = df_data['Exited'].copy()

# Проверка.
y.shape
# Out:
# (10000,)

# %%
# Определение набора признаков.
X = df_data.drop(columns=['RowNumber', 'CustomerId', 'Surname', 'Exited']).copy()

# Проверка.
X.shape
# Out:
# (10000, 10)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 👍 Неинформативные колонки  'RowNumber', 'CustomerId', 'Surname' удалены
# </div>

# %% [markdown]
# #### Разбиение данных

# %% [markdown]
# Для обучения и проверки моделей выполним разбиение данных на обучающую, валидационную и тестовую выборки в соотношении 3:1:1 соответственно.

# %%
# Разбиение выборки на обучающую и тестовую.
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.4,
                                                    random_state=random_state_global,
                                                    stratify=y)

# Проверка.
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((6000, 10), (4000, 10), (6000,), (4000,))

# %%
# Разбиение выборки на валидационную и тестовую.
X_valid, X_test, y_valid, y_test = train_test_split(X_test,
                                                    y_test,
                                                    test_size=0.5,
                                                    random_state=random_state_global,
                                                    stratify=y_test)

# Проверка.
X_valid.shape, X_test.shape, y_valid.shape, y_test.shape
# Out:
# ((2000, 10), (2000, 10), (2000,), (2000,))

# %%
# Проверка стратификации обучающей выборки.
y_train.value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# 0    79.63%
# 1    20.37%
# Name: Exited, dtype: object

# %%
# Проверка стратификации валидационной выборки.
y_valid.value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# 0    79.60%
# 1    20.40%
# Name: Exited, dtype: object

# %%
# Проверка стратификации тестовой выборки.
y_test.value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# 0    79.65%
# 1    20.35%
# Name: Exited, dtype: object

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Молодец, корректно разделил данные на три выборки.
# Классно, что используешь стратификацию. И что проверил результат.
# </div>

# %% [markdown]
# #### Стандартизация данных

# %%
# Инициализация инструмента стандартизации.
ss = StandardScaler()

# Список признаков для стандартизации.
features_to_scale = ['CreditScore', 'Balance', 'EstimatedSalary', 'Age']

# Стандартизация.
X_train[features_to_scale] = ss.fit_transform(X_train[features_to_scale])
X_valid[features_to_scale] = ss.transform(X_valid[features_to_scale])
X_test[features_to_scale] = ss.transform(X_test[features_to_scale])
# Out:
# /tmp/ipykernel_106/1904801310.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[features_to_scale] = ss.fit_transform(X_train[features_to_scale])
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#
# Молодец, совершенно верный порядок действий. Вначале разбиение на выборки, затем обучение scaler на обучающей выборке и применение  его к остальным выборкам.
# </div>

# %%
# Проверка.
X_train.head()
# Out:
#       CreditScore Geography  Gender       Age  Tenure   Balance  \
# 9814    -0.187815    France    Male -0.277642     1.0 -1.226819
# 1127    -1.032899   Germany  Female  0.588035     3.0  1.083962
# 8504    -0.259956    France    Male  0.299476     3.0  1.106813
# 2749    -0.517604    France    Male -1.335692     6.0  0.708560
# 5468    -0.600051    France    Male  0.588035     5.0 -1.226819
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 9814              2          0               0         0.576531
# 1127              2          1               1        -0.062816
# 8504              1          1               0        -0.484577
# 2749              1          1               1        -1.307180
# 5468              2          1               1         0.965524

# %% [markdown]
# #### Кодирование признаков

# %%
# Список признаков для кодирования.
features_to_encode = ['Geography', 'Gender']

# Кодирование.
X_train = pd.get_dummies(X_train, columns=features_to_encode)
X_valid = pd.get_dummies(X_valid, columns=features_to_encode)
X_test = pd.get_dummies(X_test, columns=features_to_encode)

# %%
# Проверка.
X_train.head()
# Out:
#       CreditScore       Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 9814    -0.187815 -0.277642     1.0 -1.226819              2          0
# 1127    -1.032899  0.588035     3.0  1.083962              2          1
# 8504    -0.259956  0.299476     3.0  1.106813              1          1
# 2749    -0.517604 -1.335692     6.0  0.708560              1          1
# 5468    -0.600051  0.588035     5.0 -1.226819              2          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 9814               0         0.576531                 1                  0
# 1127               1        -0.062816                 0                  1
# 8504               0        -0.484577                 1                  0
# 2749               1        -1.307180                 1                  0
# 5468               1         0.965524                 1                  0
#
#       Geography_Spain  Gender_Female  Gender_Male
# ...

# %% [markdown]
# ### Стратегия 1

# %%
# Создание копий наборов признаков для дальнейшей обработки.
X_train_1 = X_train.copy()
X_valid_1 = X_valid.copy()
X_test_1 = X_test.copy()

# %% [markdown]
# #### Заполнение пропусков признака "Tenure"

# %%
# Проверка.
print(f'Доля пропусков признака "Tenure", обучающая выборка:\t{(X_train_1["Tenure"].isna().mean()):.2%}')
print(f'Доля пропусков признака "Tenure", валидационная выбока:\t{(X_valid_1["Tenure"].isna().mean()):.2%}')
print(f'Доля пропусков признака "Tenure", тестовая выборка:\t{(X_test_1["Tenure"].isna().mean()):.2%}')
# Out:
# Доля пропусков признака "Tenure", обучающая выборка:	9.25%
# Доля пропусков признака "Tenure", валидационная выбока:	9.40%
# Доля пропусков признака "Tenure", тестовая выборка:	8.30%

# %%
# Инициализация инструмента заполнения пропусков признака "Tenure":
# заполнение пропусков нулями.
si_tenure = SimpleImputer(strategy='constant', fill_value=0)

# Заполнение пропуской признака "Tenure".
X_train_1[['Tenure']] = si_tenure.fit_transform(X_train_1[['Tenure']])
X_valid_1[['Tenure']] = si_tenure.transform(X_valid_1[['Tenure']])
X_test_1[['Tenure']] = si_tenure.transform(X_test_1[['Tenure']])

# Проверка.
print(f'Доля пропусков признака "Tenure", обучающая выборка:\t{(X_train_1["Tenure"].isna().mean()):.2%}')
print(f'Доля пропусков признака "Tenure", валидационная выбока:\t{(X_valid_1["Tenure"].isna().mean()):.2%}')
print(f'Доля пропусков признака "Tenure", тестовая выборка:\t{(X_test_1["Tenure"].isna().mean()):.2%}')
# Out:
# Доля пропусков признака "Tenure", обучающая выборка:	0.00%
# Доля пропусков признака "Tenure", валидационная выбока:	0.00%
# Доля пропусков признака "Tenure", тестовая выборка:	0.00%

# %% [markdown]
# #### Стандартизация признака "Tenure"

# %%
# Инициализация инструмента стандартизации.
ss_1 = StandardScaler()

# Стандартизация.
X_train_1[['Tenure']] = ss_1.fit_transform(X_train_1[['Tenure']])
X_valid_1[['Tenure']] = ss_1.transform(X_valid_1[['Tenure']])
X_test_1[['Tenure']] = ss_1.transform(X_test_1[['Tenure']])

# %% [markdown]
# #### Проверка

# %%
# Проверка.
X_train_1.head()
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 9814    -0.187815 -0.277642 -1.128861 -1.226819              2          0
# 1127    -1.032899  0.588035 -0.484135  1.083962              2          1
# 8504    -0.259956  0.299476 -0.484135  1.106813              1          1
# 2749    -0.517604 -1.335692  0.482953  0.708560              1          1
# 5468    -0.600051  0.588035  0.160590 -1.226819              2          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 9814               0         0.576531                 1                  0
# 1127               1        -0.062816                 0                  1
# 8504               0        -0.484577                 1                  0
# 2749               1        -1.307180                 1                  0
# 5468               1         0.965524                 1                  0
#
#       Geography_Spain  Gender_Female  Gender_Male
# ...

# %%
# Проверка.
X_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6000 entries, 9814 to 8389
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CreditScore        6000 non-null   float64
#  1   Age                6000 non-null   float64
#  2   Tenure             6000 non-null   float64
#  3   Balance            6000 non-null   float64
#  4   NumOfProducts      6000 non-null   int64
#  5   HasCrCard          6000 non-null   int64
#  6   IsActiveMember     6000 non-null   int64
#  7   EstimatedSalary    6000 non-null   float64
#  8   Geography_France   6000 non-null   uint8
#  9   Geography_Germany  6000 non-null   uint8
#  10  Geography_Spain    6000 non-null   uint8
#  11  Gender_Female      6000 non-null   uint8
#  12  Gender_Male        6000 non-null   uint8
# dtypes: float64(5), int64(3), uint8(5)
# memory usage: 451.2 KB

# %% [markdown]
# ### Стратегия 2

# %%
# Создание копий наборов признаков для дальнейшей обработки.
X_train_2 = X_train.copy()
X_valid_2 = X_valid.copy()
X_test_2 = X_test.copy()

# %% [markdown]
# #### Кодирование признака "Tenure"

# %%
# Кодирование.
X_train_2 = pd.get_dummies(X_train_2, columns=['Tenure'], drop_first=True)
X_valid_2 = pd.get_dummies(X_valid_2, columns=['Tenure'], drop_first=True)
X_test_2 = pd.get_dummies(X_test_2, columns=['Tenure'], drop_first=True)

# %% [markdown]
# #### Обработка dummy-ловушки

# %%
# Список признаков для удаление.
features_to_drop = ['Geography_France', 'Gender_Female']

# Удаление избыточных признаков.
X_train_2 = X_train_2.drop(columns=features_to_drop)
X_valid_2 = X_valid_2.drop(columns=features_to_drop)
X_test_2 = X_test_2.drop(columns=features_to_drop)

# %% [markdown]
# #### Проверка

# %%
# Проверка.
X_train_2.head()
# Out:
#       CreditScore       Age   Balance  NumOfProducts  HasCrCard  \
# 9814    -0.187815 -0.277642 -1.226819              2          0
# 1127    -1.032899  0.588035  1.083962              2          1
# 8504    -0.259956  0.299476  1.106813              1          1
# 2749    -0.517604 -1.335692  0.708560              1          1
# 5468    -0.600051  0.588035 -1.226819              2          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 9814               0         0.576531                  0                0
# 1127               1        -0.062816                  1                0
# 8504               0        -0.484577                  0                0
# 2749               1        -1.307180                  0                0
# 5468               1         0.965524                  0                0
#
#       Gender_Male  Tenure_1.0  Tenure_2.0  Tenure_3.0  Tenure_4.0  Tenure_5.0  \
# ...

# %%
# Проверка.
X_train_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6000 entries, 9814 to 8389
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CreditScore        6000 non-null   float64
#  1   Age                6000 non-null   float64
#  2   Balance            6000 non-null   float64
#  3   NumOfProducts      6000 non-null   int64
#  4   HasCrCard          6000 non-null   int64
#  5   IsActiveMember     6000 non-null   int64
#  6   EstimatedSalary    6000 non-null   float64
#  7   Geography_Germany  6000 non-null   uint8
#  8   Geography_Spain    6000 non-null   uint8
#  9   Gender_Male        6000 non-null   uint8
#  10  Tenure_1.0         6000 non-null   uint8
#  11  Tenure_2.0         6000 non-null   uint8
#  12  Tenure_3.0         6000 non-null   uint8
#  13  Tenure_4.0         6000 non-null   uint8
#  14  Tenure_5.0         6000 non-null   uint8
#  15  Tenure_6.0         6000 non-null   uint8
# ...

# %% [markdown]
# ### Стратегия 3

# %%
# Создание копий наборов признаков для дальнейшей обработки.
X_train_3 = X_train.copy()
X_valid_3 = X_valid.copy()
X_test_3 = X_test.copy()

# %% [markdown]
# #### Кодирование признака "Tenure"

# %%
# Кодирование.
X_train_3 = pd.get_dummies(X_train_3, columns=['Tenure'])
X_valid_3 = pd.get_dummies(X_valid_3, columns=['Tenure'])
X_test_3 = pd.get_dummies(X_test_3, columns=['Tenure'])

# %% [markdown]
# #### Проверка

# %%
# Проверка.
X_train_3.head()
# Out:
#       CreditScore       Age   Balance  NumOfProducts  HasCrCard  \
# 9814    -0.187815 -0.277642 -1.226819              2          0
# 1127    -1.032899  0.588035  1.083962              2          1
# 8504    -0.259956  0.299476  1.106813              1          1
# 2749    -0.517604 -1.335692  0.708560              1          1
# 5468    -0.600051  0.588035 -1.226819              2          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 9814               0         0.576531                 1                  0
# 1127               1        -0.062816                 0                  1
# 8504               0        -0.484577                 1                  0
# 2749               1        -1.307180                 1                  0
# 5468               1         0.965524                 1                  0
#
#       Geography_Spain  ...  Tenure_1.0  Tenure_2.0  Tenure_3.0  Tenure_4.0  \
# ...

# %%
# Проверка.
X_train_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6000 entries, 9814 to 8389
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CreditScore        6000 non-null   float64
#  1   Age                6000 non-null   float64
#  2   Balance            6000 non-null   float64
#  3   NumOfProducts      6000 non-null   int64
#  4   HasCrCard          6000 non-null   int64
#  5   IsActiveMember     6000 non-null   int64
#  6   EstimatedSalary    6000 non-null   float64
#  7   Geography_France   6000 non-null   uint8
#  8   Geography_Germany  6000 non-null   uint8
#  9   Geography_Spain    6000 non-null   uint8
#  10  Gender_Female      6000 non-null   uint8
#  11  Gender_Male        6000 non-null   uint8
#  12  Tenure_0.0         6000 non-null   uint8
#  13  Tenure_1.0         6000 non-null   uint8
#  14  Tenure_2.0         6000 non-null   uint8
#  15  Tenure_3.0         6000 non-null   uint8
# ...

# %% [markdown]
# ### Выводы

# %% [markdown]
# В ходе подготовки данных были произведены категоризация и стандартизация признаков. Также были реализованы три подхода:
# 1. Пропуски признака <code>Tenure</code> были заполнены нулями, затем значения признака были стандартизированы.
# 2. Признак <code>Tenure</code> был кодирован как категориальный. Затем для всех категориальных признаков были удалены все избыточные первые столбцы.
# 3. Признак <code>Tenure</code> был кодирован как категориальный без удаления избыточных столбцов.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Насколько я вижу ты совершенно корректно выполнил грандиозную цель и подготовил признаки используя три стратгии.</div>

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# Обучим несколько моделей для оценки решения задачи:
# - логистическую регрессию;
# - дерево решений;
# - случайный лес.

# %%
# Таблица для записи метрик.
df_metrics = pd.DataFrame(columns=['X_valid_1', 'X_valid_2', 'X_valid_3'])

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отличная находка с хранением результатов в Датафрейме. Без этого в коде можно заблудиться.</div>

# %% [markdown]
# ### Логистическая регрессия

# %% [markdown]
# #### Проверка модели на первом наборе данных

# %%
# %%time

# Инициализация модели.
lr = LogisticRegression(random_state=random_state_global)

# Обучение модели.
lr.fit(X_train_1, y_train)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = lr.predict(X_train_1)
y_pred_valid = lr.predict(X_valid_1)
# Out:
# CPU times: user 79.9 ms, sys: 176 ms, total: 256 ms
# Wall time: 265 ms

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Хороший стиль, твой код легко читать.</div>

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89      4778
#            1       0.61      0.21      0.31      1222
#
#     accuracy                           0.81      6000
#    macro avg       0.72      0.59      0.60      6000
# weighted avg       0.78      0.81      0.77      6000

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89      1592
#            1       0.63      0.23      0.33       408
#
#     accuracy                           0.82      2000
#    macro avg       0.73      0.60      0.61      2000
# weighted avg       0.79      0.82      0.78      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(lr, X_valid_1, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(lr, X_valid_1, y_valid);

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Молодец, исследуешь библиотеки и используешь функции, за пределами курса.  Обрати внимание, что plot_roc_curve deprecated в будущих пакетах рекомендованно пользоваться RocCurveDisplay.from_estimator. Но в среде яндекс практикум сейчас может  не работать. </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Да, видел, спасибо. Продолжаю пользоваться пока не появляются предупреждения об отключении.
# </div>

# %%
# Вычисление метрики.
df_metrics.loc['LogisticRegression', 'X_valid_1'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                    X_valid_1 X_valid_2 X_valid_3
# LogisticRegression  0.332731       NaN       NaN

# %% [markdown]
# #### Проверка модели на втором наборе данных

# %%
# %%time

# Обучение модели.
lr.fit(X_train_2, y_train)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = lr.predict(X_train_2)
y_pred_valid = lr.predict(X_valid_2)
# Out:
# CPU times: user 113 ms, sys: 109 ms, total: 221 ms
# Wall time: 194 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89      4778
#            1       0.61      0.21      0.31      1222
#
#     accuracy                           0.81      6000
#    macro avg       0.72      0.59      0.60      6000
# weighted avg       0.78      0.81      0.77      6000

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89      1592
#            1       0.64      0.24      0.34       408
#
#     accuracy                           0.82      2000
#    macro avg       0.74      0.60      0.62      2000
# weighted avg       0.79      0.82      0.78      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(lr, X_valid_2, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(lr, X_valid_2, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['LogisticRegression', 'X_valid_2'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                    X_valid_1 X_valid_2 X_valid_3
# LogisticRegression  0.332731  0.344704       NaN

# %% [markdown]
# #### Проверка модели на третьем наборе данных

# %%
# %%time

# Обучение модели.
lr.fit(X_train_3, y_train)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = lr.predict(X_train_3)
y_pred_valid = lr.predict(X_valid_3)
# Out:
# CPU times: user 135 ms, sys: 294 ms, total: 428 ms
# Wall time: 425 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89      4778
#            1       0.61      0.21      0.31      1222
#
#     accuracy                           0.81      6000
#    macro avg       0.72      0.59      0.60      6000
# weighted avg       0.78      0.81      0.77      6000

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89      1592
#            1       0.64      0.23      0.34       408
#
#     accuracy                           0.82      2000
#    macro avg       0.74      0.60      0.62      2000
# weighted avg       0.79      0.82      0.78      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(lr, X_valid_3, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(lr, X_valid_3, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['LogisticRegression', 'X_valid_3'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                    X_valid_1 X_valid_2 X_valid_3
# LogisticRegression  0.332731  0.344704  0.341727

# %% [markdown]
# #### Выводы

# %% [markdown]
# Выводы:
# - метрики качества схожи на обучающих и тестовых выборках - модель не переобучилась;
# - модель крайне плохо справилась с прогнозом наименьшего класса;
# - наилучшее качество модель продемонстрировала на втором наборе данных.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Логистическая регрессия исследована корректно. Выведены все уместные метрики и графики.</div>

# %% [markdown]
# ### Дерево решений

# %% [markdown]
# #### Проверка модели на первом наборе данных

# %%
# %%time

# Инициализация модели.
dtc = DecisionTreeClassifier(random_state=random_state_global)

# Обучение модели.
dtc.fit(X_train_1, y_train)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = dtc.predict(X_train_1)
y_pred_valid = dtc.predict(X_valid_1)
# Out:
# CPU times: user 27 ms, sys: 897 µs, total: 27.9 ms
# Wall time: 27.4 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4778
#            1       1.00      1.00      1.00      1222
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      1592
#            1       0.51      0.51      0.51       408
#
#     accuracy                           0.80      2000
#    macro avg       0.69      0.69      0.69      2000
# weighted avg       0.80      0.80      0.80      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(dtc, X_valid_1, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(dtc, X_valid_1, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['DecisionTreeClassifier', 'X_valid_1'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3
# LogisticRegression      0.332731  0.344704  0.341727
# DecisionTreeClassifier  0.512821       NaN       NaN

# %% [markdown]
# #### Проверка модели на втором наборе данных

# %%
# %%time

# Обучение модели.
dtc.fit(X_train_2, y_train)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = dtc.predict(X_train_2)
y_pred_valid = dtc.predict(X_valid_2)
# Out:
# CPU times: user 29.1 ms, sys: 0 ns, total: 29.1 ms
# Wall time: 28.2 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4778
#            1       1.00      1.00      1.00      1222
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88      1592
#            1       0.52      0.53      0.52       408
#
#     accuracy                           0.80      2000
#    macro avg       0.70      0.70      0.70      2000
# weighted avg       0.80      0.80      0.80      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(dtc, X_valid_2, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(dtc, X_valid_2, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['DecisionTreeClassifier', 'X_valid_2'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3
# LogisticRegression      0.332731  0.344704  0.341727
# DecisionTreeClassifier  0.512821  0.521845       NaN

# %% [markdown]
# #### Проверка модели на третьем наборе данных

# %%
# %%time

# Обучение модели.
dtc.fit(X_train_3, y_train)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = dtc.predict(X_train_3)
y_pred_valid = dtc.predict(X_valid_3)
# Out:
# CPU times: user 31.2 ms, sys: 0 ns, total: 31.2 ms
# Wall time: 30.2 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4778
#            1       1.00      1.00      1.00      1222
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88      1592
#            1       0.52      0.54      0.53       408
#
#     accuracy                           0.81      2000
#    macro avg       0.70      0.71      0.70      2000
# weighted avg       0.81      0.81      0.81      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(dtc, X_valid_3, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(dtc, X_valid_3, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['DecisionTreeClassifier', 'X_valid_3'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3
# LogisticRegression      0.332731  0.344704  0.341727
# DecisionTreeClassifier  0.512821  0.521845  0.529625

# %% [markdown]
# #### Выводы

# %% [markdown]
# Выводы:
# - метрики качества сильно отличаются на обучающих и тестовых выборках - модель переобучилась;
# - модель справилась с прогнозом наименьшего класса гораздо лучше, чем логистическая регрессия;
# - наилучшее качество модель продемонстрировала на третьем наборе данных.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Дерево решений исследовано корректно. Выведены все уместные метрики и графики.</div>

# %% [markdown]
# ### Случайный лес

# %% [markdown]
# #### Проверка модели на первом наборе данных

# %%
# %%time

# Инициализация модели.
rfc = RandomForestClassifier(random_state=random_state_global)

# Обучение модели.
rfc.fit(X_train_1, y_train)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = rfc.predict(X_train_1)
y_pred_valid = rfc.predict(X_valid_1)
# Out:
# CPU times: user 625 ms, sys: 1.57 ms, total: 626 ms
# Wall time: 638 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4778
#            1       1.00      1.00      1.00      1222
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.92      1592
#            1       0.76      0.44      0.56       408
#
#     accuracy                           0.86      2000
#    macro avg       0.82      0.70      0.74      2000
# weighted avg       0.85      0.86      0.84      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(rfc, X_valid_1, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(rfc, X_valid_1, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['RandomForestClassifier', 'X_valid_1'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3
# LogisticRegression      0.332731  0.344704  0.341727
# DecisionTreeClassifier  0.512821  0.521845  0.529625
# RandomForestClassifier  0.559006       NaN       NaN

# %% [markdown]
# #### Проверка модели на втором наборе данных

# %%
# %%time

# Обучение модели.
rfc.fit(X_train_2, y_train)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = rfc.predict(X_train_2)
y_pred_valid = rfc.predict(X_valid_2)
# Out:
# CPU times: user 649 ms, sys: 0 ns, total: 649 ms
# Wall time: 652 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4778
#            1       1.00      1.00      1.00      1222
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      1592
#            1       0.79      0.46      0.58       408
#
#     accuracy                           0.86      2000
#    macro avg       0.83      0.72      0.75      2000
# weighted avg       0.86      0.86      0.85      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(rfc, X_valid_2, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(rfc, X_valid_2, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['RandomForestClassifier', 'X_valid_2'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3
# LogisticRegression      0.332731  0.344704  0.341727
# DecisionTreeClassifier  0.512821  0.521845  0.529625
# RandomForestClassifier  0.559006  0.583333       NaN

# %% [markdown]
# #### Проверка модели на третьем наборе данных

# %%
# %%time

# Обучение модели.
rfc.fit(X_train_3, y_train)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = rfc.predict(X_train_3)
y_pred_valid = rfc.predict(X_valid_3)
# Out:
# CPU times: user 618 ms, sys: 0 ns, total: 618 ms
# Wall time: 629 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4778
#            1       1.00      1.00      1.00      1222
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.91      1592
#            1       0.76      0.43      0.55       408
#
#     accuracy                           0.86      2000
#    macro avg       0.82      0.70      0.73      2000
# weighted avg       0.85      0.86      0.84      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(rfc, X_valid_3, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(rfc, X_valid_3, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['RandomForestClassifier', 'X_valid_3'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3
# LogisticRegression      0.332731  0.344704  0.341727
# DecisionTreeClassifier  0.512821  0.521845  0.529625
# RandomForestClassifier  0.559006  0.583333   0.54717

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Случайный лес исследован корректно. Выведены все уместные метрики и графики.</div>

# %% [markdown]
# #### Выводы

# %% [markdown]
# Выводы:
# - метрики качества сильно отличаются на обучающих и тестовых выборках - модель также переобучилась;
# - модель справилась с прогнозом наименьшего класса лучше, чем логистическая регрессия и дерево решений;
# - наилучшее качество модель продемонстрировала на втором наборе данных.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Исследованы три модели на трех наборах данных. Есть выводы.</div>

# %% [markdown]
# ### Выбор модели и набора данных

# %% [markdown]
# Согласно полученным метрикам, наилучшее качество прогнозирования для наименьшего класса продемонстрировал случайный лес на втором наборе данных. Поэтому будем использовать их для дальнейшего улучшения модели.
#
# Также стоить заметить, что несмотря на то, что дерево решений справилось с задачей лучше, чем логистическая регрессия, согласно метрике "f1_score", логистическая регрессия продемонстрировала большую метрику "ROC AUC". Для наилучшего сочетания модели случайный лес и второго набора данных метрика "ROC AUC" имеет наивысший показатель 0.85.
#
# Также было установлено, что второй набор данных является наилучшим для построения моделей. Предположение, что удаление избыточных признаков после категоризации, подтвердилось.

# %% [markdown]
# ## Борьба с дисбалансом

# %% [markdown]
# Для минимизации эффекта дисбаланса классов применим следующие техники:
# - настройка весов моделей;
# - техника "upsampling";
# - техника "downsampling".

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Ок, хороший план.</div>

# %% [markdown]
# ### Настройка весов моделей

# %% [markdown]
# #### Логистическая регрессия

# %%
# %%time

# Инициализация модели.
lr = LogisticRegression(class_weight='balanced', random_state=random_state_global)

# Обучение модели.
lr.fit(X_train_2, y_train)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = lr.predict(X_train_2)
y_pred_valid = lr.predict(X_valid_2)
# Out:
# CPU times: user 87.7 ms, sys: 142 ms, total: 229 ms
# Wall time: 221 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.72      0.80      4778
#            1       0.39      0.69      0.49      1222
#
#     accuracy                           0.71      6000
#    macro avg       0.64      0.70      0.65      6000
# weighted avg       0.80      0.71      0.74      6000

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.70      0.79      1592
#            1       0.37      0.69      0.48       408
#
#     accuracy                           0.70      2000
#    macro avg       0.63      0.69      0.63      2000
# weighted avg       0.79      0.70      0.72      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(lr, X_valid_2, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(lr, X_valid_2, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['LogisticRegression', 'X_valid_2_balanced'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3  X_valid_2_balanced
# LogisticRegression      0.332731  0.344704  0.341727            0.480753
# DecisionTreeClassifier  0.512821  0.521845  0.529625                 NaN
# RandomForestClassifier  0.559006  0.583333   0.54717                 NaN

# %% [markdown]
# #### Дерево решений

# %%
# %%time

# Инициализация модели.
dtc = DecisionTreeClassifier(class_weight='balanced', random_state=random_state_global)

# Обучение модели.
dtc.fit(X_train_2, y_train)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = dtc.predict(X_train_2)
y_pred_valid = dtc.predict(X_valid_2)
# Out:
# CPU times: user 33 ms, sys: 0 ns, total: 33 ms
# Wall time: 31.8 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4778
#            1       1.00      1.00      1.00      1222
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88      1592
#            1       0.53      0.51      0.52       408
#
#     accuracy                           0.81      2000
#    macro avg       0.70      0.70      0.70      2000
# weighted avg       0.80      0.81      0.81      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(dtc, X_valid_2, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(dtc, X_valid_2, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['DecisionTreeClassifier', 'X_valid_2_balanced'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3  X_valid_2_balanced
# LogisticRegression      0.332731  0.344704  0.341727            0.480753
# DecisionTreeClassifier  0.512821  0.521845  0.529625            0.518797
# RandomForestClassifier  0.559006  0.583333   0.54717                 NaN

# %% [markdown]
# #### Случайный лес

# %%
# %%time

# Инициализация модели.
rfc = RandomForestClassifier(class_weight='balanced', random_state=random_state_global)

# Обучение модели.
rfc.fit(X_train_2, y_train)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = rfc.predict(X_train_2)
y_pred_valid = rfc.predict(X_valid_2)
# Out:
# CPU times: user 654 ms, sys: 0 ns, total: 654 ms
# Wall time: 657 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4778
#            1       1.00      1.00      1.00      1222
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1592
#            1       0.76      0.44      0.56       408
#
#     accuracy                           0.86      2000
#    macro avg       0.82      0.70      0.74      2000
# weighted avg       0.85      0.86      0.84      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(rfc, X_valid_2, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(rfc, X_valid_2, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['RandomForestClassifier', 'X_valid_2_balanced'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3  X_valid_2_balanced
# LogisticRegression      0.332731  0.344704  0.341727            0.480753
# DecisionTreeClassifier  0.512821  0.521845  0.529625            0.518797
# RandomForestClassifier  0.559006  0.583333   0.54717            0.557632

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Балансировка классов исследована</div>

# %% [markdown]
# ### Техника "upsampling"

# %% [markdown]
# #### Подготовка данных

# %%
# Функция для выполнения upsampling.
def upsampling(X, y):
    df = X.copy()
    df['y'] = y.copy()
    
    # Если нулевой класс преобладает,
    if len(df[df['y'] == 0]) > len(df[df['y'] == 1]):
        # добавить объектов первого класса,
        df_new = pd.concat([df[df['y'] == 0],
                            df[df['y'] == 1].sample(n=len(df[df['y'] == 0]), replace=True, random_state=random_state_global)])
    else:
        # иначе добавить объектов нулевого класса.
        df_new = pd.concat([df[df['y'] == 1],
                            df[df['y'] == 0].sample(n=len(df[df['y'] == 1]), replace=True, random_state=random_state_global)])
    
    # Перемешивание объектов.
    df_new = df_new.sample(frac=1, random_state=random_state_global)
    
    return df_new.drop(columns=['y']), df_new['y']

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Выделять переиспользуемый код в функции всегда полезно</div>

# %%
# Проверка: вывод размера оригинального набора признаков обучающей выборки.
X_train_2.shape
# Out:
# (6000, 20)

# %%
# Проверка: вывод размера оригинальной целевой переменной.
y_train.shape
# Out:
# (6000,)

# %%
# Проверка: вывод соотношения классов оригинальной целевой переменной.
y_train.value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# 0    79.63%
# 1    20.37%
# Name: Exited, dtype: object

# %%
# Выполнение upsampling.
X_train_2_up, y_train_up = upsampling(X_train_2, y_train)

# %%
# Проверка: вывод размера набора признаков после upsampling.
X_train_2_up.shape
# Out:
# (9556, 20)

# %%
# Проверка: вывод размера целевой переменной после upsampling.
y_train_up.shape
# Out:
# (9556,)

# %%
# Проверка: вывод соотношения классов целевой переменной после upsampling.
y_train_up.value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# 0    50.00%
# 1    50.00%
# Name: y, dtype: object

# %%
# Проверка: Вывод первых пяти значений целевой переменной.
y_train_up.head()
# Out:
# 6999    1
# 3199    1
# 9804    0
# 9082    0
# 3927    0
# Name: y, dtype: int64

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# мне нравится, что ты постоянно всё "исследуешь", смотришь состояние переменных, проверяешь результаты</div>

# %% [markdown]
# #### Логистическая регрессия

# %%
# %%time

# Инициализация модели.
lr = LogisticRegression(random_state=random_state_global)

# Обучение модели.
lr.fit(X_train_2_up, y_train_up)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = lr.predict(X_train_2_up)
y_pred_valid = lr.predict(X_valid_2)
# Out:
# CPU times: user 142 ms, sys: 237 ms, total: 379 ms
# Wall time: 381 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train_up, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.72      0.71      4778
#            1       0.71      0.69      0.70      4778
#
#     accuracy                           0.70      9556
#    macro avg       0.70      0.70      0.70      9556
# weighted avg       0.70      0.70      0.70      9556

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.70      0.79      1592
#            1       0.37      0.68      0.48       408
#
#     accuracy                           0.70      2000
#    macro avg       0.63      0.69      0.63      2000
# weighted avg       0.79      0.70      0.73      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(lr, X_valid_2, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(lr, X_valid_2, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['LogisticRegression', 'X_valid_2_upsampling'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3  X_valid_2_balanced  \
# LogisticRegression      0.332731  0.344704  0.341727            0.480753
# DecisionTreeClassifier  0.512821  0.521845  0.529625            0.518797
# RandomForestClassifier  0.559006  0.583333   0.54717            0.557632
#
#                         X_valid_2_upsampling
# LogisticRegression                  0.481034
# DecisionTreeClassifier                   NaN
# RandomForestClassifier                   NaN

# %% [markdown]
# #### Дерево решений

# %%
# %%time

# Инициализация модели.
dtc = DecisionTreeClassifier(random_state=random_state_global)

# Обучение модели.
dtc.fit(X_train_2_up, y_train_up)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = dtc.predict(X_train_2_up)
y_pred_valid = dtc.predict(X_valid_2)
# Out:
# CPU times: user 36.8 ms, sys: 2.35 ms, total: 39.2 ms
# Wall time: 45.7 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train_up, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4778
#            1       1.00      1.00      1.00      4778
#
#     accuracy                           1.00      9556
#    macro avg       1.00      1.00      1.00      9556
# weighted avg       1.00      1.00      1.00      9556

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88      1592
#            1       0.51      0.49      0.50       408
#
#     accuracy                           0.80      2000
#    macro avg       0.69      0.68      0.69      2000
# weighted avg       0.80      0.80      0.80      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(dtc, X_valid_2, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(dtc, X_valid_2, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['DecisionTreeClassifier', 'X_valid_2_upsampling'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3  X_valid_2_balanced  \
# LogisticRegression      0.332731  0.344704  0.341727            0.480753
# DecisionTreeClassifier  0.512821  0.521845  0.529625            0.518797
# RandomForestClassifier  0.559006  0.583333   0.54717            0.557632
#
#                         X_valid_2_upsampling
# LogisticRegression                  0.481034
# DecisionTreeClassifier              0.498741
# RandomForestClassifier                   NaN

# %% [markdown]
# #### Случайный лес

# %%
# %%time

# Инициализация модели.
rfc = RandomForestClassifier(random_state=random_state_global)

# Обучение модели.
rfc.fit(X_train_2_up, y_train_up)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = rfc.predict(X_train_2_up)
y_pred_valid = rfc.predict(X_valid_2)
# Out:
# CPU times: user 886 ms, sys: 0 ns, total: 886 ms
# Wall time: 901 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train_up, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4778
#            1       1.00      1.00      1.00      4778
#
#     accuracy                           1.00      9556
#    macro avg       1.00      1.00      1.00      9556
# weighted avg       1.00      1.00      1.00      9556

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      1592
#            1       0.69      0.51      0.59       408
#
#     accuracy                           0.85      2000
#    macro avg       0.79      0.73      0.75      2000
# weighted avg       0.84      0.85      0.84      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(rfc, X_valid_2, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(rfc, X_valid_2, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['RandomForestClassifier', 'X_valid_2_upsampling'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3  X_valid_2_balanced  \
# LogisticRegression      0.332731  0.344704  0.341727            0.480753
# DecisionTreeClassifier  0.512821  0.521845  0.529625            0.518797
# RandomForestClassifier  0.559006  0.583333   0.54717            0.557632
#
#                         X_valid_2_upsampling
# LogisticRegression                  0.481034
# DecisionTreeClassifier              0.498741
# RandomForestClassifier              0.587079

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Техника upsampling исследована</div>

# %% [markdown]
# ### Техника "downsampling"

# %% [markdown]
# #### Подготовка данных

# %%
# Функция для выполнения downsampling.
def downsampling(X, y):
    df = X.copy()
    df['y'] = y.copy()
    
    # Если нулевой класс преобладает,
    if len(df[df['y'] == 0]) > len(df[df['y'] == 1]):
        # уменьшить его до размеров первого класса,
        df_new = pd.concat([df[df['y'] == 0].sample(n=len(df[df['y'] == 1]), random_state=random_state_global),
                            df[df['y'] == 1]])
    else:
        # иначе уменьшить первый класс до размеров нулевого.
        df_new = pd.concat([df[df['y'] == 1].sample(n=len(df[df['y'] == 0]), random_state=random_state_global),
                            df[df['y'] == 0]])
    
    # Перемешивание объектов.
    df_new = df_new.sample(frac=1, random_state=random_state_global)
    
    return df_new.drop(columns=['y']), df_new['y']

# %%
# Проверка: вывод размера оригинального набора признаков обучающей выборки.
X_train_2.shape
# Out:
# (6000, 20)

# %%
# Проверка: вывод размера оригинальной целевой переменной.
y_train.shape
# Out:
# (6000,)

# %%
# Проверка: вывод соотношения классов оригинальной целевой переменной.
y_train.value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# 0    79.63%
# 1    20.37%
# Name: Exited, dtype: object

# %%
# Выполнение upsampling.
X_train_2_down, y_train_down = downsampling(X_train_2, y_train)

# %%
# Проверка: вывод размера набора признаков после upsampling.
X_train_2_down.shape
# Out:
# (2444, 20)

# %%
# Проверка: вывод размера целевой переменной после upsampling.
y_train_down.shape
# Out:
# (2444,)

# %%
# Проверка: вывод соотношения классов целевой переменной после upsampling.
y_train_down.value_counts(normalize=True).apply('{:.2%}'.format)
# Out:
# 0    50.00%
# 1    50.00%
# Name: y, dtype: object

# %%
# Проверка: Вывод первых пяти значений целевой переменной.
y_train_down.head()
# Out:
# 6900    0
# 5019    1
# 5834    1
# 9503    0
# 732     0
# Name: y, dtype: int64

# %% [markdown]
# #### Логистическая регрессия

# %%
# %%time

# Инициализация модели.
lr = LogisticRegression(random_state=random_state_global)

# Обучение модели.
lr.fit(X_train_2_down, y_train_down)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = lr.predict(X_train_2_down)
y_pred_valid = lr.predict(X_valid_2)
# Out:
# CPU times: user 61.4 ms, sys: 126 ms, total: 188 ms
# Wall time: 183 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train_down, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.72      0.71      1222
#            1       0.71      0.69      0.70      1222
#
#     accuracy                           0.70      2444
#    macro avg       0.70      0.70      0.70      2444
# weighted avg       0.70      0.70      0.70      2444

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.70      0.78      1592
#            1       0.37      0.68      0.48       408
#
#     accuracy                           0.69      2000
#    macro avg       0.63      0.69      0.63      2000
# weighted avg       0.79      0.69      0.72      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(lr, X_valid_2, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(lr, X_valid_2, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['LogisticRegression', 'X_valid_2_downsampling'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3  X_valid_2_balanced  \
# LogisticRegression      0.332731  0.344704  0.341727            0.480753
# DecisionTreeClassifier  0.512821  0.521845  0.529625            0.518797
# RandomForestClassifier  0.559006  0.583333   0.54717            0.557632
#
#                         X_valid_2_upsampling  X_valid_2_downsampling
# LogisticRegression                  0.481034                 0.47562
# DecisionTreeClassifier              0.498741                     NaN
# RandomForestClassifier              0.587079                     NaN

# %% [markdown]
# #### Дерево решений

# %%
# %%time

# Инициализация модели.
dtc = DecisionTreeClassifier(random_state=random_state_global)

# Обучение модели.
dtc.fit(X_train_2_down, y_train_down)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = dtc.predict(X_train_2_down)
y_pred_valid = dtc.predict(X_valid_2)
# Out:
# CPU times: user 16.8 ms, sys: 0 ns, total: 16.8 ms
# Wall time: 15.1 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train_down, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1222
#            1       1.00      1.00      1.00      1222
#
#     accuracy                           1.00      2444
#    macro avg       1.00      1.00      1.00      2444
# weighted avg       1.00      1.00      1.00      2444

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.67      0.77      1592
#            1       0.36      0.71      0.48       408
#
#     accuracy                           0.68      2000
#    macro avg       0.63      0.69      0.62      2000
# weighted avg       0.79      0.68      0.71      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(dtc, X_valid_2, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(dtc, X_valid_2, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['DecisionTreeClassifier', 'X_valid_2_downsampling'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3  X_valid_2_balanced  \
# LogisticRegression      0.332731  0.344704  0.341727            0.480753
# DecisionTreeClassifier  0.512821  0.521845  0.529625            0.518797
# RandomForestClassifier  0.559006  0.583333   0.54717            0.557632
#
#                         X_valid_2_upsampling  X_valid_2_downsampling
# LogisticRegression                  0.481034                 0.47562
# DecisionTreeClassifier              0.498741                 0.47619
# RandomForestClassifier              0.587079                     NaN

# %% [markdown]
# #### Случайный лес

# %%
# %%time

# Инициализация модели.
rfc = RandomForestClassifier(random_state=random_state_global)

# Обучение модели.
rfc.fit(X_train_2_down, y_train_down)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = rfc.predict(X_train_2_down)
y_pred_valid = rfc.predict(X_valid_2)
# Out:
# CPU times: user 358 ms, sys: 0 ns, total: 358 ms
# Wall time: 373 ms

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train_down, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1222
#            1       1.00      1.00      1.00      1222
#
#     accuracy                           1.00      2444
#    macro avg       1.00      1.00      1.00      2444
# weighted avg       1.00      1.00      1.00      2444

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.85      1592
#            1       0.46      0.70      0.56       408
#
#     accuracy                           0.77      2000
#    macro avg       0.69      0.75      0.70      2000
# weighted avg       0.82      0.77      0.79      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(rfc, X_valid_2, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(rfc, X_valid_2, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['RandomForestClassifier', 'X_valid_2_downsampling'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        X_valid_1 X_valid_2 X_valid_3  X_valid_2_balanced  \
# LogisticRegression      0.332731  0.344704  0.341727            0.480753
# DecisionTreeClassifier  0.512821  0.521845  0.529625            0.518797
# RandomForestClassifier  0.559006  0.583333   0.54717            0.557632
#
#                         X_valid_2_upsampling  X_valid_2_downsampling
# LogisticRegression                  0.481034                0.475620
# DecisionTreeClassifier              0.498741                0.476190
# RandomForestClassifier              0.587079                0.556202

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Техника downsampling исследована</div>

# %% [markdown]
# ### Выводы

# %% [markdown]
# Наиболее существенное улучшение метрик наблюдается у Логистической регрессии. Все три техники позволили достичь лучшего обучения модели.
#
# Для модели Дерево решений произошло снижение метрик качества для всех трёх техник.
#
# Случайный лес незначительно улучшил метрику только при технике "upsampling", однако этого хватило, чтобы эта модель была лидирующей по качеству.

# %% [markdown]
# ## Финальная настройка и тестирование модели

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Не стоит использовать такое название для раздела. Думаю большинство поймет "тестирование" как оценка модели на тестовой выборке. Попробуй использовать другое название.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Исправил, спасибо. Название было в прекоде, не обратил внимание.
# </div>

# %% [markdown]
# По результатам исследования задачи, выбора модели и борьбы с дисбалансом классов было устновлено следующее:
# - модель RandomForestClassifier демонстрирует наилучшую метрику качества <code>f1_score</code> для наименьшего первого класса;
# - для построение данной модели лучше всего подошёл набор данных, подготовленный по второй стратегии;
# - для минимизации эффекта дисбаланса классов наибольшую пользу принесла техника <code>upsampling</code>.
#
# Выполним оценку модели на предмет её дальнейшего улучшения.

# %% [markdown]
# ### Оценка модели

# %% [markdown]
# #### Обучение базовой модели

# %%
# %%time

# Инициализация модели.
rfc = RandomForestClassifier(random_state=random_state_global)

# Обучение модели.
rfc.fit(X_train_2_up, y_train_up)

# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = rfc.predict(X_train_2_up)
y_pred_valid = rfc.predict(X_valid_2)
# Out:
# CPU times: user 930 ms, sys: 0 ns, total: 930 ms
# Wall time: 943 ms

# %% [markdown]
# #### Оценка метрик качества

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train_up, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4778
#            1       1.00      1.00      1.00      4778
#
#     accuracy                           1.00      9556
#    macro avg       1.00      1.00      1.00      9556
# weighted avg       1.00      1.00      1.00      9556

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      1592
#            1       0.69      0.51      0.59       408
#
#     accuracy                           0.85      2000
#    macro avg       0.79      0.73      0.75      2000
# weighted avg       0.84      0.85      0.84      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(rfc, X_valid_2, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(rfc, X_valid_2, y_valid);

# %%
# Таблица для метрик.
df_metrics = pd.DataFrame(columns=['train', 'valid'])

# Вычисление метрики.
df_metrics.loc['Base', 'train'] = f1_score(y_train_up, y_pred_train)
df_metrics.loc['Base', 'valid'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#      train     valid
# Base   1.0  0.587079

# %% [markdown]
# #### Анализ метрик качества

# %% [markdown]
# Выбранная модель демонстрирует идеальные метрики качества на обучающей выборке, гораздо более лучшие, чем метрики при прогнозе на валидационной выборке. Большая разница между метриками сигнализирует о переобучении модели.
#
# Для борьбы с переобучением модели следует выполнить настройку гиперпараметров.

# %% [markdown]
# ### Настройка модели

# %% [markdown]
# #### Подбор гиперпараметров

# %% [markdown]
# Для подбора гиперпараметров использовался инструмент <code>RandomizedSearchCV</code>.
# ***
# ![image.png](attachment:image.png)
# ***
# Наилучшую метрику <code>f1_score</code> со значением 0.623602 продемонстрировала следующая модель:
#
#     RandomForestClassifier(max_depth=20, min_samples_leaf=3, min_samples_split=8,
#                            n_estimators=22, random_state=0)

# %%
# %%time
# Набор гиперпараметров для перебора.
# dict_params = {'n_estimators': range(20, 41, 1),
#                'max_depth': range(20, 41, 1),
#                'min_samples_split': range(3, 21, 1),
#                'min_samples_leaf': range(3, 21, 1),
#                'random_state': [random_state_global]}

# Инициализация инструмента для перебора гиперпараметров.
# rs = RandomizedSearchCV(estimator=RandomForestClassifier(),
#                         param_distributions=dict_params,
#                         n_iter=10,
#                         scoring='f1',
#                         n_jobs=-1,
#                         random_state=random_state_global)

# Обучение модели с перебором гиперпараметров.
# rs.fit(X_train_2_up, y_train_up)

# Инициализация модели с лучшими шиперпараметрами - метрика 0.623602
rf = RandomForestClassifier(max_depth=20,
                            min_samples_leaf=3,
                            min_samples_split=8,
                            n_estimators=22,
                            random_state=random_state_global)

# Обучение модели.
rf.fit(X_train_2_up, y_train_up)
# Out:
# CPU times: user 148 ms, sys: 0 ns, total: 148 ms
# Wall time: 151 ms
# RandomForestClassifier(max_depth=20, min_samples_leaf=3, min_samples_split=8,
#                        n_estimators=22, random_state=0)

# %%
# Прогнозирование на обучающей и валидационной выборках.
y_pred_train = rf.predict(X_train_2_up)
y_pred_valid = rf.predict(X_valid_2)

# %%
# Вывод метрик прогнозирования на обучающей выборке.
print(classification_report(y_train_up, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      4778
#            1       0.96      0.98      0.97      4778
#
#     accuracy                           0.97      9556
#    macro avg       0.97      0.97      0.97      9556
# weighted avg       0.97      0.97      0.97      9556

# %%
# Вывод метрик прогнозирования на валидационной выборке.
print(classification_report(y_valid, y_pred_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91      1592
#            1       0.63      0.62      0.62       408
#
#     accuracy                           0.85      2000
#    macro avg       0.77      0.76      0.76      2000
# weighted avg       0.85      0.85      0.85      2000

# %%
# Вывод матрицы заблуждений.
plot_confusion_matrix(rf, X_valid_2, y_valid);

# %%
# Вывод графика ROC.
plot_roc_curve(rf, X_valid_2, y_valid);

# %%
# Вычисление метрики.
df_metrics.loc['RandomizedSearchCV', 'train'] = f1_score(y_train_up, y_pred_train)
df_metrics.loc['RandomizedSearchCV', 'valid'] = f1_score(y_valid, y_pred_valid)

# Вывод метрик.
df_metrics
# Out:
#                        train     valid
# Base                     1.0  0.587079
# RandomizedSearchCV  0.969132  0.623602

# %% [markdown]
# Подбор гиперпараметров позволил уменьшить переобучение модели и получить более высокую метрику на валидационной выборке.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, лучшая модель выбрана.</div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Ты выбрал лучшую модель по результатам очень серьезного исследования. Рекомендую зафиксировать результат в виде вывода.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Подготовил отдельный вывод для формализации результатов исследования.
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>v2</b> 👍 </div>

# %% [markdown]
# #### Вывод

# %% [markdown]
# В результате рассмотрения различных наборов гиперпараметров, было установлено, что улучшение обобщающей способности модели способствует снижению переобучения. А именно:
# - ограничение глубины деревьев позволило модели уловить общие тенденции, а не запомнить обучающую выборку досконально;
# - ограничение минимального количества объектов в листе устранило подгонку модели под конкретные объекты;
# - ограничение минимального количества объектов для разбиения также позволило лучше определить основные тенденции в данных;
# - выбор оптимального количества деревьев в лесу способствовал устойчивости модели к аномалиям в данных без чрезмерного переобучения.
#
# Таким образом, были установлены гиперпараметры для построения модели эффективной не только на обучающей выборке, но и на незнакомой валидационной выборке.

# %% [markdown]
# ### Финальная оценка модели

# %%
# Прогнозирование на тестовой выборке.
y_pred_test = rf.predict(X_test_2)

# Вывод метрик на тестовой выборке.
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90      1593
#            1       0.61      0.61      0.61       407
#
#     accuracy                           0.84      2000
#    macro avg       0.76      0.76      0.76      2000
# weighted avg       0.84      0.84      0.84      2000

# %%
# Вывод графика ROC.
plot_roc_curve(rf, X_test_2, y_test);

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Тестирование произведено корректно, нужная точность достигнута </div>

# %% [markdown]
# На тестовой выборке удалось достичь значения 0.61 метрики <code>f1-score</code> для наименьшего класса "1". Данный показатель удовлетворяет поставленной задаче достичь порога 0.59.
#
# Модель демонстрирует сильное переобучение для наименьшего класса "1": метрики на обучающей выборке и на тестовой значительно отличаются. Это может быть объяснено тем, что для борьбы с дисбалансом использовалась техника <code>upsampling</code>. При данной технике генерируются объекты дубликаты, которые являются линейно зависимыми и менее информативными.
#
# Метрика <code>AUC</code> построенной модели имеет значение 0.85, что существенно превышает показатель 0.5 "случайной" модели. На графике <code>ROC</code> можно наблюдать, что доля верных положительных классов <code>TPR</code> увеличивается быстрее, чем доля ложных отрицательных <code>FPR</code>. Модель установила корректные пороги для большинства объектов.

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнен шаг 1: данные подготовлены
# - [x]  Выполнен шаг 2: задача исследована
#     - [x]  Исследован баланс классов
#     - [x]  Изучены модели без учёта дисбаланса
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 3: учтён дисбаланс
#     - [x]  Применено несколько способов борьбы с дисбалансом
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 4: проведено тестирование
# - [x]  Удалось достичь *F1*-меры не менее 0.59
# - [x]  Исследована метрика *AUC-ROC*

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий</b>
#
# У тебя очень хороший проект. Вижу что ты очень много материала проработал самостоятельно, мне нравится логика построения исследования.
#
# Все этапы работы выполнены верно, ты достиг поставленной задачи.  Я могу принять проект уже сейчас, возвращаю тебе что бы дать возможность ознакомиться с комментариями, возмжоно у тебя появились вопросы.
#
# Жду проект на повторное ревью!
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий v2</b>
#
# Поздравляю с завершением проекта.
#
# Желаю дальнейших успехов!
#
# </div>
