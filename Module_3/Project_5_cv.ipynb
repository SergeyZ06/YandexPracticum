# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Сергей, привет!👋</b>
#
# Меня зовут Александр Куимов, я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь реагировать на мои комментарии своими, выделяя их цветами и наиболее понравившимся тебе способом оформления, но явно  отличающимся от моих комментариев. Это нужно, чтобы не создавалась путаница😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Здравствуйте, спасибо за ревью!
# <br>Постарался устранить все замечания.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# И вновь, привет! Пожалуйста)

# %% [markdown]
# # Определение возраста покупателей

# %% [markdown]
# ## Постановка задачи и план выполнения работы

# %% [markdown]
# ### Постановка задачи

# %% [markdown]
# Сетевой супермаркет «Хлеб-Соль» внедряет систему компьютерного зрения для обработки фотографий покупателей. Фотофиксация в прикассовой зоне поможет определять возраст клиентов, чтобы:
# * Анализировать покупки и предлагать товары, которые могут заинтересовать покупателей этой возрастной группы;
# * Контролировать добросовестность кассиров при продаже алкоголя.
#
# Необходимо построить модель, которая по фотографии определит приблизительный возраст человека. В распоряжении набор фотографий людей с указанием возраста.

# %% [markdown]
# ### План выполнения работы

# %% [markdown]
# Для выполнения работы планируются следующие шаги:
# 1. Проведение исследовательского анализа набора фотографий.
# 2. Подготовка данных к обучению.
# 3. Обучение нейронной сети и расчёт её качества.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Я бы посоветовал тебе подробнее раскрыть план своей работы. Это поможет тебе расставлять акценты в выводах.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Добавил описание и план выполнения работы!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Супер!

# %% [markdown]
# ## Подготовка к выполнению проекта

# %% [markdown]
# ### Импорт библиотек

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
#  Молодец, что собираешь импорты в одну ячейку и помещаешь ее в начале проекта!

# %% [markdown]
# ### Импорт данных

# %%
# Путь к изображениям.
PATH__DATA_IMAGES = r'/datasets/faces/final_files'

# Путь к целевой переменной.
PATH__DATA_LABELS = r'/datasets/faces/labels.csv'

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Загрузка датасета и анализ возраста

# %%
# Загрузка датасета.
df = pd.read_csv(PATH__DATA_LABELS)

# %%
# Проверка: вывод первых пяти строк.
df.head()
# Out:
#     file_name  real_age
# 0  000000.jpg         4
# 1  000001.jpg        18
# 2  000002.jpg        80
# 3  000003.jpg        50
# 4  000004.jpg        17

# %%
# Проверка: вывод размерности датасета.
df.shape
# Out:
# (7591, 2)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Размер выборки выведен. Выборка относительно небольшая, но мы еще можем нарастить ее, применяя аугментации.

# %%
# Вывод основной информации о целевой переменной.
df.describe().T
# Out:
#            count       mean       std  min   25%   50%   75%    max
# real_age  7591.0  31.201159  17.14506  1.0  20.0  29.0  41.0  100.0

# %%
# Визуализация распределения значений целевой переменной.
sns.displot(df['real_age'], aspect=2, bins=100)

plt.grid(axis='y')
plt.xticks(range(0, 110, 10))

plt.title('График распределения возраста в выборке', fontdict={'size': 16}, pad=20)
plt.xlabel('Возраст, количество лет', fontdict={'size': 14})
plt.ylabel('Количество объектов', fontdict={'size': 14});

# %%
plt.figure(figsize=(16, 1))

sns.boxplot(data=df['real_age'], orient='h')

plt.xticks(range(0, 110, 10))

plt.title('Диаграмма размаха возраста в выборке', fontdict={'size': 16}, pad=20)
plt.xlabel('Возраст, количество лет', fontdict={'size': 14});

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Гистограмма целевого признака выведена. Раз у нас 100 различных возрастов, то и корзин можно указать столько же.
#
# Неплохо тут еще добавить, имеются ли выбросы.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Добавил диаграмму размаха для анализа выбросов.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Выбросы тут могут быть связаны с тем, что настоящий возраст был неизвестен тому, кто размечал датасет, и он его попросту округлял до "юбилейных" лет. Поэтому, некоторые "круглые" года в датасете некорректные.

# %% [markdown]
# ### Загрузка и анализ изображений

# %%
# Инициализация загрузчика данных.
datagen = ImageDataGenerator(rescale=1/255)

# Загрузка данных при помощи датасета.
datagen_flow = datagen.flow_from_dataframe(
    dataframe=df,
    directory=PATH__DATA_IMAGES,
    x_col='file_name',
    y_col='real_age',
    class_mode='raw'
)
# Out:
# Found 7591 validated image filenames.

# %%
# Визуализация изображений.

# fig = plt.figure(figsize=(10, 10))

# for i in range(15):
#     features, target = next(datagen_flow)
    
#     fig.add_subplot(3, 5, i+1)
#     plt.imshow(features[i])
#     plt.xticks([])
#     plt.yticks([])
#     plt.tight_layout()

fig, axes = plt.subplots(3, 8, figsize=(16, 6))
fig.suptitle('Вывод изображений и целевого признака', fontsize=20)

for ax in axes.flat:
    features, target = next(datagen_flow)
    
    ax.set_yticks([])
    ax.set_xticks([])
    ax.imshow(features[0])
    ax.set_xlabel(f'{target[0]}')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Примеры фотографий выведены!
#
# Можно еще поработать над оформлением графика с фото (название самого графика). В названиях каждого фото (title)  можно указать возраст.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Подписал график и указал возраст.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец)

# %% [markdown]
# ### Выводы

# %% [markdown]
# В ходе анализа целевой переменной были установлены следующие особенности:
#
# 1. В датасете присутствуют 7591 объектов, пропуски отсутствуют. Данного количества объектов может быть достаточно для обучения.
#
#
# 2. Значения целевой переменной распределены неравномерно: наибольшая плотность наблюдается в интервале от 20 до 30 лет, затем с увеличением возраста количество объектов снижается. Также наблюдается скопление объектов в околонулевых значениях. Согласно анализу диаграммы размаха, в выборке могут присутствовать потенциальные выбросы со значениями целевой переменной более 72. Однако это вполне могут быть люди с подлинным возрастом.
#
#
# 3. Согласно основным статистикам, медиана и среднее значения расположены близко и равны 31.2 и 29.0 соответственно. Стандартное отклонение имеет значение чуть более 17 лет, что подтверждается рассеянностью объектов на графике распределения.
#
#
# Рассмотрение признаков-изображений показало следующее:
#
# 1. Помимо различных возрастов люди на изображениях отличаются также этнической принадлежностью, полом, эмоциональным состоянием.
#
#
# 2. Фотографии сделаны с разных ракурсов, с разным освещением и аппаратурой различного качества. Присутствуют цветные и чёрно-белые изображения различного качества. Есть как постановочные снимки, также и сиюминутные. На фото могут присутствовать несколько человек одновременно.
#
#
# 3. Помимо различного качества некоторые снимки содержат дефекты и искажения: размытость, артефакты, сепия, сжатие в различных осях. Снимки также отличаются количеством пикселей и размером, что потребует приведение фото к одинаковому размеру.
#
#
# Резюмируя можно заключить, что как характер распределения целевой переменной, так и изображения-признаки представляют собой большое количество различных вариаций. Данная особенность потребует от модели способности к улавливанию сложных тенденций в данных: различного качества снимков, ракурсов, искажений и т.д.
#
# Для увеличения обучающей выборки может быть применена аугментация в виде зеркалирования изображений. Смещение и другие различные искажения изображений не требуются, так как снимки содержат дефекты.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Анализ проведен корректно.
#
# Тут неплохо еще будет указать в выводе, какова общая ориентация фотографий, различается ли размер изображений?
#  </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Скорректировал вывод.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Общая ориентация фотографий примерно одинакова - в некоторых фото их уже повернули за нас, чтобы выровнять положение лица, значит нам их не обязательно поворачивать, а начальный размер изображений отличается, в силу того, что визуально заметно различное качество фото, где-то есть черные рамки (они не несут полезной информации). В итоге, размер изображений мы приведем к единому перед обучением модели.

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# ### Код обучения модели

# %% [raw]
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
#
# from tensorflow.keras.applications.resnet import ResNet50
#
# from tensorflow.keras.models import Sequential
#
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import LeakyReLU
# # from tensorflow.keras.layers import Conv2D
# # from tensorflow.keras.layers import MaxPool2D
# # from tensorflow.keras.layers import Flatten
# from tensorflow.keras.layers import GlobalAveragePooling2D
#
# from tensorflow.keras.optimizers import Adam
#
# # from tensorflow.keras.losses import MeanSquaredError
# # from tensorflow.keras.losses import MeanAbsoluteError
#
# # import numpy as np
# import pandas as pd
#
#
# def load_train(path):
#
#     try:
#
#         labels = pd.read_csv(path + 'labels.csv')
#
#         train_datagen = ImageDataGenerator(
#             validation_split=0.25,
#             rescale=1/255,
#             horizontal_flip=True
#             # vertical_flip=True
#             # width_shift=0.2,
#             # height_shift=0.2
#         )
#
#         train_gen_flow = train_datagen.flow_from_dataframe(
#             dataframe=labels,
#             directory=path+'/final_files',
#             x_col='file_name',
#             y_col='real_age',
#             target_size=(224, 224),
#             batch_size=32,
#             class_mode='raw',
#             seed=12345,
#             subset='training'
#         )
#
#         return train_gen_flow
#
#     except Exception as e:
#         print(e)
#
#
# def load_test(path):
#
#     try:
#
#         labels = pd.read_csv(path + 'labels.csv')
#
#         test_datagen = ImageDataGenerator(
#             validation_split=0.25,
#             rescale=1/255
#         )
#
#         test_gen_flow = test_datagen.flow_from_dataframe(
#             dataframe=labels,
#             directory=path+'/final_files',
#             x_col='file_name',
#             y_col='real_age',
#             target_size=(224, 224),
#             batch_size=32,
#             class_mode='raw',
#             seed=12345,
#             subset='validation'
#         )
#
#         return test_gen_flow
#
#     except Exception as e:
#         print(e)
#
#
# def create_model(input_shape):
#
#     try:
#
#         model = Sequential()
#
#         # model.add(Conv2D(filters=6, kernel_size=(5, 5), activation='tanh', input_shape=input_shape))
#         # model.add(MaxPool2D(pool_size=(2, 2), padding='valid'))
#         # model.add(Conv2D(filters=16, kernel_size=(5, 5), activation='tanh'))
#         # model.add(MaxPool2D(pool_size=(2, 2), padding='valid'))
#
#         resnet = ResNet50(input_shape=input_shape,
#                           # weights='/datasets/keras_models/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5',
#                           weights='imagenet',
#                           include_top=False)
#
#         # resnet.trainable = False
#         resnet.trainable = True
#
#         model.add(resnet)
#
#         # model.add(Flatten())
#         model.add(GlobalAveragePooling2D())
#
#         model.add(Dense(units=80))
#         model.add(LeakyReLU(alpha=0.3))
#         model.add(Dense(units=40))
#         model.add(LeakyReLU(alpha=0.3))
#         model.add(Dense(units=20))
#         model.add(LeakyReLU(alpha=0.3))
#
#         model.add(Dense(units=1, activation='relu'))
#
#         # adam = Adam(lr=0.001)
#         # adam = Adam(lr=0.002)
#         adam = Adam(lr=0.0001)
#
#         # mse = MeanSquaredError()
#         # mae = MeanAbsoluteError()
#
#         # model.compile(optimizer=adam, loss=mse, metrics=[mae])
#         model.compile(optimizer=adam, loss='mean_squared_error', metrics=['mean_absolute_error'])
#
#         return model
#
#     except Exception as e:
#         print(e)
#
#
# def train_model(model,
#                 train_data,
#                 test_data,
#                 batch_size=None,
#                 epochs=10,
#                 steps_per_epoch=None,
#                 validation_steps=None):
#
#     try:
#
#         model.fit(
#             train_data,
#             validation_data=test_data,
#             epochs=epochs,
#             batch_size=batch_size,
#             steps_per_epoch=steps_per_epoch,
#             validation_steps=validation_steps,
#             verbose=2,
#             shuffle=True
#         )
#
#         return model
#
#     except Exception as e:
#         print(e)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Модель определена правильно!
#
# - Желательно еще добавить горизонтальный флип на тренировочной части. По сути это позволило бы увеличить выборку в 2 раза. Причем изображения полученные таким образом были бы неотличимы от настоящих.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Добавил аугментацию для обучающей выборки: горизонтальный флип.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Вижу, хорошо.

# %% [markdown]
# ### Вывод консоли

# %% [raw]
# 2022-08-10 17:48:06.073490: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2022-08-10 17:48:06.281338: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# 2022-08-10 17:48:10.529732: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-08-10 17:48:11.197051: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:8b:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2022-08-10 17:48:11.197136: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-08-10 17:48:11.197168: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-08-10 17:48:11.263439: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-08-10 17:48:11.297775: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-08-10 17:48:11.626158: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-08-10 17:48:11.664429: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-08-10 17:48:11.664537: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-10 17:48:11.669049: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# Using TensorFlow backend.
# 3
# Found 5694 validated image filenames.
# Found 1897 validated image filenames.
# 2022-08-10 17:48:12.076927: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2022-08-10 17:48:12.108832: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100000000 Hz
# 2022-08-10 17:48:12.110696: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x4fc1fd0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-08-10 17:48:12.110728: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-08-10 17:48:12.342260: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x4622130 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-08-10 17:48:12.342306: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2022-08-10 17:48:12.344676: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:8b:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2022-08-10 17:48:12.344733: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-08-10 17:48:12.344742: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-08-10 17:48:12.344768: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-08-10 17:48:12.344777: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-08-10 17:48:12.344786: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-08-10 17:48:12.344794: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-08-10 17:48:12.344801: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-10 17:48:12.349081: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2022-08-10 17:48:12.350699: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-08-10 17:48:15.723145: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-08-10 17:48:15.723193: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2022-08-10 17:48:15.723204: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2022-08-10 17:48:15.727813: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-08-10 17:48:15.727874: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10240 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:8b:00.0, compute capability: 7.0)
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h
# 80945152/94765736 [========================>.....] - ETA: 1s
# 81567744/94765736 [========================>.....] - ETA: 1s
# 82190336/94765736 [=========================>....] - ETA: 1s
# 82812928/94765736 [=========================>....] - ETA: 1s
# 83435520/94765736 [=========================>....] - ETA: 1s
# 83894272/94765736 [=========================>....] - ETA: 1s
# 84516864/94765736 [=========================>....] - ETA: 1s
# 85139456/94765736 [=========================>....] - ETA: 1s
# 85762048/94765736 [==========================>...] - ETA: 1s
# 86384640/94765736 [==========================>...] - ETA: 1s
# 87007232/94765736 [==========================>...] - ETA: 1s
# 87629824/94765736 [==========================>...] - ETA: 0s
# 88088576/94765736 [==========================>...] - ETA: 0s
# 88711168/94765736 [===========================>..] - ETA: 0s
# 89333760/94765736 [===========================>..] - ETA: 0s
# 89956352/94765736 [===========================>..] - ETA: 0s
# 90595328/94765736 [===========================>..] - ETA: 0s
# 91217920/94765736 [===========================>..] - ETA: 0s
# 91840512/94765736 [============================>.] - ETA: 0s
# 92282880/94765736 [============================>.] - ETA: 0s
# 92905472/94765736 [============================>.] - ETA: 0s
# 93528064/94765736 [============================>.] - ETA: 0s
# 94167040/94765736 [============================>.] - ETA: 0s
# 94773248/94765736 [==============================] - 13s 0us/step
# <class 'tensorflow.python.keras.engine.sequential.Sequential'>
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 178 steps, validate for 60 steps
# Epoch 1/10
# 2022-08-10 17:48:50.319919: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-08-10 17:48:52.590077: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 178/178 - 66s - loss: 219.7346 - mean_absolute_error: 10.6969 - val_loss: 640.0631 - val_mean_absolute_error: 20.3081
# Epoch 2/10
# 178/178 - 37s - loss: 55.5121 - mean_absolute_error: 5.6747 - val_loss: 390.4528 - val_mean_absolute_error: 14.5951
# Epoch 3/10
# 178/178 - 37s - loss: 28.7008 - mean_absolute_error: 4.0941 - val_loss: 273.7587 - val_mean_absolute_error: 12.2351
# Epoch 4/10
# 178/178 - 37s - loss: 18.4254 - mean_absolute_error: 3.2666 - val_loss: 115.6267 - val_mean_absolute_error: 8.2705
# Epoch 5/10
# 178/178 - 37s - loss: 12.7872 - mean_absolute_error: 2.6921 - val_loss: 85.3877 - val_mean_absolute_error: 7.1014
# Epoch 6/10
# 178/178 - 37s - loss: 9.8128 - mean_absolute_error: 2.3424 - val_loss: 78.1378 - val_mean_absolute_error: 6.8976
# Epoch 7/10
# 178/178 - 37s - loss: 7.9618 - mean_absolute_error: 2.1215 - val_loss: 67.6040 - val_mean_absolute_error: 6.1685
# Epoch 8/10
# 178/178 - 37s - loss: 6.5931 - mean_absolute_error: 1.9474 - val_loss: 67.4328 - val_mean_absolute_error: 6.3120
# Epoch 9/10
# 178/178 - 37s - loss: 6.6057 - mean_absolute_error: 1.9351 - val_loss: 65.8374 - val_mean_absolute_error: 6.1728
# Epoch 10/10
# 178/178 - 37s - loss: 6.8040 - mean_absolute_error: 1.9243 - val_loss: 66.6968 - val_mean_absolute_error: 6.1961
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 60/60 - 9s - loss: 66.6968 - mean_absolute_error: 6.1961
# Test MAE: 6.1961

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отличный результат по метрике)

# %% [markdown]
# ### Скриншот результатов

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Выводы

# %% [markdown]
# Несмотря на сложность задачи модель смогла продемонстрировать метрику качества <code>mean absolute error</code> не только удовлетворяющую основному требованию - 8 лет, но и преодолела порог отличного результата 7 лет со значением метрики ~6.2 лет.
#
# В результате последней, десятой эпохи метрика качества на обучающей выборке улучшилась, а на валидационной выборке ухудшилась - модель начала переобучаться.
#
# Залогом успеха стали следующие факторы:
#
# 1. Основной backbone слой нейросети базируется на основе мощной предобученной модели ResNet50, состоящей из 50 слоёв и Residual блоков.
#
#
# 2. После подготовки признаков backbone слоем, были использованы полносвязные слои <code>Dense</code> с постепенным понижением размерности и функцией активации <code>LeakyReLU</code>, которая устойчива к затуханию градиента.
#
#
# 3. Для изменения весов модели был использован один из наиболее совершенных алгоритмов оптимизации <code>adam</code> с небольшим шагом обучения, так как основная часть сети уже обучена и требует лишь донастройки.
#
# Всё вышеперечисленное позволило модели справиться с задачей с запасом значения метрики качества. Таким образом, поставленная бизнесом задача была выполнена с лучшей точностью, чем требовалось.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Можно было еще сказать несколько слов о бизнесе. Позволяет ли полученная модель решить поставленные бизнесом задачи?

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Упомянул, что была выполнена задача, поставленная бизнесом.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# - По описанию модели все логично!
# - По бизнес задачам:  не думаю, что модель с такой погрешностью  сможет помочь в определении возраста покупателя для продажи алкоголя. А вот с задачей "Анализировать покупки и предлагать товары, которые могут заинтересовать покупателей этой возрастной группы" модель вполне может справиться.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Могу поделиться такими ссылками для углубленного изучения темы спринта:
#
# - Видеокурс от Stanford University: https://www.youtube.com/watch?v=vT1JzLTH4G4&list=PLC1qU-LWwrF64f4QKQT-Vg5Wr4qEE1Zxk
#
# - Курс от Физтех-школы Прикладной Математики и Информатики МФТИ: https://vk.com/dlschool_mipt
#
# - Курс Нейронные сети и компьютерное зрение от Sumsung: https://stepik.org/course/50352/promo#toc

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера v.1 <a class="tocSkip"> </h2>
#
#
# У меня сложилось хорошее общее впечатление о проекте, тебе удалось неплохо справиться с проектом. Молодец! Загружены данные для анализа, изучен каждый параметр, модель построена и протестирована. Тебе удалось успешно справиться с первой задачей в области компьютерного зрения. Поздравляю!
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - радует, что проект хорошо структурирован, приятно проверять такие работы;
# - есть красивые визуализации в проекте.
#
# Проект может быть зачтен, но я его отправлю назад, чтобы у тебя была возможность задать вопросы и внести правки, при желании. Однако, ты можешь просто вернуть проект в таком же виде и я его зачту.
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
#
#
# Теперь почти идеально, молодец! Принимаю твой проект)
#
#
# В этом проекте все шаги отработаны. С интересом читал твои размышления, код и выводы. Что ещё для дальнейшего улучшения качества возможно сделать?
#
# Опишу здесь некоторые идеи:
#
# 1. Качество данных на входе: оценить еще раз возраст по фото.
# 2. Анализ ошибок: к примеру модель сильно ошибается на сегменте пожилых людей, зато почти идеально работает с детьми. Тогда мы поймем, каких возрастов фото было бы хорошо добавить в выборку для дообучения.
# 3. Дополнительно изучить распределение целевого признака, возможно что выборка была составлена неслучайным образом (видна небольшая бимодальность), посмотреть, каких возрастных групп представлено мало, чтобы их потом добавить в выборку.
#
# Но цель нашего проекта достигнута. Рад был тебе помочь)
#
# Преподаватель в Slack будет рад помочь, если у тебя появятся вопросы. Удачи тебе в финальном проекте!
#
# </div>
